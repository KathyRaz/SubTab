# %% [markdown]
# # In this User study we will see several subtable of the Flights dataset and rank them by How informative are they for the user

# %%
import pandas as pd
import pandas as pd
from Random_baselines.random_util import generate_random_summary, color_random_summary
from Naive_clustering.nc_utils import gen_nc_summary
from SubTab import subTab

num_cols_and_rows = 10 
pd.set_option("display.max_columns", num_cols_and_rows)
pd.set_option("display.max_rows", num_cols_and_rows)


path_sample_df =  'input/flights_dataset.csv'
full_df_a = pd.read_csv(path_sample_df)
if 'Unnamed: 0' in full_df_a.columns:
    full_df_a.drop(['Unnamed: 0'], axis=1, inplace=True)
if 'Unnamed: 0.1' in full_df_a.columns:
    full_df_a.drop([ 'Unnamed: 0.1'], axis=1, inplace=True)
if 'index' in full_df_a.columns:
    full_df_a.drop([ 'index'], axis=1, inplace=True)
# %load_ext autoreload
# %autoreload 2

# %%
#pandas default
full_df_a
# Out:
#        MONTH  DAY  DAY_OF_WEEK AIRLINE ORIGIN_AIRPORT  ... AIR_SYSTEM_DELAY  \
# 0         11   29            7      UA            LAS  ...              NaN
# 1          8    6            4      WN            DAL  ...              NaN
# 2         11   26            4      AA            DFW  ...              NaN
# 3          9   17            4      DL            JFK  ...              NaN
# 4          5   31            7      WN            HOU  ...              NaN
# ...      ...  ...          ...     ...            ...  ...              ...
# 99995      5   27            3      DL            JFK  ...             50.0
# 99996      2    4            3      US            CLT  ...              NaN
# 99997      7   16            4      AA            EWR  ...              0.0
# 99998      1   17            6      US            DEN  ...              NaN
# 99999      4    7            2      DL            LAX  ...              NaN
#
#        SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  WEATHER_DELAY
# 0                 NaN            NaN                  NaN            NaN
# 1                 NaN            NaN                  NaN            NaN
# 2                 NaN            NaN                  NaN            NaN
# 3                 NaN            NaN                  NaN            NaN
# 4                 NaN            NaN                  NaN            NaN
# ...               ...            ...                  ...            ...
# 99995             0.0            0.0                  0.0            0.0
# 99996             NaN            NaN                  NaN            NaN
# 99997             0.0           28.0                  0.0            0.0
# 99998             NaN            NaN                  NaN            NaN
# 99999             NaN            NaN                  NaN            NaN
#
# [100000 rows x 28 columns]

# %%
# random
rand_df = generate_random_summary(full_df_a.copy(), num_cols=num_cols_and_rows, num_rows=num_cols_and_rows)
rand_df
# Out:
#          SCHEDULED_ARRIVAL  DAY  DAY_OF_WEEK  AIR_SYSTEM_DELAY  YEAR  \
# 1825102             1625.0   27            1               NaN  2015
# 1843016             1425.0   28            2               NaN  2015
# 537374              1554.0    5            4               NaN  2015
# 1688020             1700.0   18            6               NaN  2015
# 3763751              916.0   22            6               NaN  2015
# 3969307             2115.0    3            4               NaN  2015
# 3241176              915.0   22            3               NaN  2015
# 3358033              250.0   28            2               4.0  2015
# 3957712             1145.0    3            4               NaN  2015
# 2089253             1630.0   13            3               2.0  2015
#
#         DESTINATION_AIRPORT  DIVERTED  TAXI_IN  WEATHER_DELAY  DISTANCE
# 1825102                 EWR       0.0      7.0            NaN    2402.0
# 1843016                 MSP       0.0      9.0            NaN    1276.0
# 537374                  AUS       0.0      3.0            NaN     775.0
# 1688020                 CMH       0.0      5.0            NaN     409.0
# 3763751                 SBA       0.0      4.0            NaN     455.0
# 3969307                 ORD       0.0      9.0            NaN     177.0
# 3241176                 DTW       0.0      6.0            NaN     363.0
# 3358033                 SJU       0.0      3.0            0.0    1237.0
# 3957712                 DCA       0.0      2.0            NaN     899.0
# 2089253                 MIA       0.0      8.0            0.0     964.0

# %%
# Naive clustering
nc_df = gen_nc_summary(full_df_a.copy(), num_cols_and_rows, num_cols_and_rows)
nc_df
# Out:
#          TAXI_IN  TAIL_NUMBER  YEAR  FLIGHT_NUMBER  DEPARTURE_TIME  \
# 4052923       43         2118  2015            746             376
# 2933371       74         2531  2015           3043             381
# 568398        43         3663  2015           5244             481
# 895063         1         4100  2015           2485             426
# 2546618       43          730  2015           1280             382
# 2197706       23         1522  2015            999            1180
# 1681471       54         4143  2015           1639            1148
# 2282387       43         3967  2015            741             413
# 1849456       65         2849  2015            735             408
# 71589         74          643  2015           4756             425
#
#          SCHEDULED_DEPARTURE  DISTANCE  WHEELS_ON  ORIGIN_AIRPORT  \
# 4052923                 1524     862.0        465             390
# 2933371                 1500     510.0        480             533
# 568398                  1300     737.0        653             583
# 895063                  1540     762.0        531             325
# 2546618                 1530     969.0        487             389
# 2197706                  745     740.0       1351             471
# 1681471                  715     456.0       1249             398
# 2282387                 1600     733.0        503             487
# 1849456                 1555    2176.0        578             543
# 71589                   1411     287.0        573             533
#
#          AIR_SYSTEM_DELAY
# 4052923               241
# 2933371               241
# 568398                  0
# 895063                241
# 2546618               241
# 2197706               241
# 1681471               241
# 2282387               241
# 1849456               241
# 71589                 197

# %%
# Subtable without rules
sdf = subTab(full_df_a)

# %%
# subtable with rules
sdf.display(full_df_a)
# Out:
# for or summary creation, it took 0:00:06.504785
#        DEPARTURE_DELAY  WHEELS_OFF  SCHEDULED_DEPARTURE  AIR_TIME  WHEELS_ON  \
# 66908             -4.0      1709.0                 1645     135.0     2024.0
# 68239             -9.0      1211.0                 1200     138.0     1429.0
# 16853              3.0       817.0                  751     234.0     1011.0
# 63938             -6.0      2100.0                 2030      62.0     2202.0
# 68967             -2.0       629.0                  615      81.0      750.0
# 60663             -5.0      1137.0                 1130     116.0     1333.0
# 36356             14.0      1839.0                 1815      70.0     1949.0
# 84068             -4.0      1435.0                 1400      54.0     1529.0
# 87595             20.0      2049.0                 2007     258.0     2207.0
# 41882              NaN         NaN                 1755       NaN        NaN
#
#        DEPARTURE_TIME  ELAPSED_TIME  SCHEDULED_ARRIVAL  ARRIVAL_TIME  DISTANCE
# 66908          1641.0         167.0               2030        2028.0      1012
# 68239          1151.0         167.0               1450        1438.0      1107
# 16853           754.0         267.0               1027        1021.0      1620
# 63938          2024.0         112.0               2204        2216.0       404
# 68967           613.0         104.0                744         757.0       406
# 60663          1125.0         132.0               1348        1337.0       759
# 36356          1829.0          86.0               1955        1955.0       507
# 84068          1356.0         103.0               1528        1539.0       214
# 87595          2027.0         292.0               2210        2219.0      1979
# 41882             NaN           NaN               2055           NaN       950

# %%
full_df_a
# Out:
#        MONTH  DAY  DAY_OF_WEEK AIRLINE ORIGIN_AIRPORT  ... AIR_SYSTEM_DELAY  \
# 0         11   29            7      UA            LAS  ...              NaN
# 1          8    6            4      WN            DAL  ...              NaN
# 2         11   26            4      AA            DFW  ...              NaN
# 3          9   17            4      DL            JFK  ...              NaN
# 4          5   31            7      WN            HOU  ...              NaN
# ...      ...  ...          ...     ...            ...  ...              ...
# 99995      5   27            3      DL            JFK  ...             50.0
# 99996      2    4            3      US            CLT  ...              NaN
# 99997      7   16            4      AA            EWR  ...              0.0
# 99998      1   17            6      US            DEN  ...              NaN
# 99999      4    7            2      DL            LAX  ...              NaN
#
#        SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  WEATHER_DELAY
# 0                 NaN            NaN                  NaN            NaN
# 1                 NaN            NaN                  NaN            NaN
# 2                 NaN            NaN                  NaN            NaN
# 3                 NaN            NaN                  NaN            NaN
# 4                 NaN            NaN                  NaN            NaN
# ...               ...            ...                  ...            ...
# 99995             0.0            0.0                  0.0            0.0
# 99996             NaN            NaN                  NaN            NaN
# 99997             0.0           28.0                  0.0            0.0
# 99998             NaN            NaN                  NaN            NaN
# 99999             NaN            NaN                  NaN            NaN
#
# [100000 rows x 28 columns]

# %%
# Subtable without rules
sdf = subTab(full_df_a, use_rules=True, subtab_config={'rules':'rules/rules_flights_mod_18.csv'})

# %%
sdf.display(full_df_a)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 28/28 [00:01<00:00, 23.64it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 375.95it/s]
# for or summary creation, it took 0:00:52.181864
# <style type="text/css">
# #T_26441 .pd-t {
#   visibility: hidden;
#   position: absolute;
#   z-index: 1;
#   background-color: black;
#   color: white;
#   transform: translate(-20px, -20px);
# }
# #T_26441 #T_26441_row0_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_26441 #T_26441_row0_col1 .pd-t::after {
#   content: "Rule #313: {(SCHEDULED_ARRIVAL = (1027.0, 1355.0]),(WHEELS_ON = (1008.0, 1339.0]),} ---> {(ARRIVAL_TIME = ARRIVAL_TIME_1),}, support=0.18, confidence = 0.99, lift = 4.97";
# }
# #T_26441 #T_26441_row0_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_26441 #T_26441_row0_col2 .pd-t::after {
#   content: "Rule #313: {(SCHEDULED_ARRIVAL = (1027.0, 1355.0]),(WHEELS_ON = (1008.0, 1339.0]),} ---> {(ARRIVAL_TIME = ARRIVAL_TIME_1),}, support=0.18, confidence = 0.99, lift = 4.97";
# }
# #T_26441 #T_26441_row0_col5:hover .pd-t {
#   visibility: visible;
# }
# #T_26441 #T_26441_row0_col5 .pd-t::after {
#   content: "Rule #313: {(SCHEDULED_ARRIVAL = (1027.0, 1355.0]),(WHEELS_ON = (1008.0, 1339.0]),} ---> {(ARRIVAL_TIME = ARRIVAL_TIME_1),}, support=0.18, confidence = 0.99, lift = 4.97";
# }
# #T_26441 #T_26441_row1_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_26441 #T_26441_row1_col1 .pd-t::after {
#   content: "Rule #59: {(WHEELS_ON = (2024.0, 2400.0]),} ---> {(ARRIVAL_TIME = ARRIVAL_TIME_4),}, support=0.19, confidence = 0.98, lift = 5.05";
# }
# #T_26441 #T_26441_row1_col5:hover .pd-t {
#   visibility: visible;
# }
# #T_26441 #T_26441_row1_col5 .pd-t::after {
#   content: "Rule #59: {(WHEELS_ON = (2024.0, 2400.0]),} ---> {(ARRIVAL_TIME = ARRIVAL_TIME_4),}, support=0.19, confidence = 0.98, lift = 5.05";
# }
# #T_26441 #T_26441_row2_col6:hover .pd-t {
#   visibility: visible;
# }
# #T_26441 #T_26441_row2_col6 .pd-t::after {
#   content: "Rule #182: {(SCHEDULED_DEPARTURE = (1825.0, 2359.0]),} ---> {(DEPARTURE_TIME = DEPARTURE_TIME_4),}, support=0.18, confidence = 0.93, lift = 4.77";
# }
# #T_26441 #T_26441_row2_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_26441 #T_26441_row2_col9 .pd-t::after {
#   content: "Rule #182: {(SCHEDULED_DEPARTURE = (1825.0, 2359.0]),} ---> {(DEPARTURE_TIME = DEPARTURE_TIME_4),}, support=0.18, confidence = 0.93, lift = 4.77";
# }
# #T_26441 #T_26441_row3_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_26441 #T_26441_row3_col3 .pd-t::after {
#   content: "Rule #607: {(SCHEDULED_DEPARTURE = (825.0, 1135.0]),(WHEELS_OFF = (840.0, 1155.0]),} ---> {(DEPARTURE_TIME = DEPARTURE_TIME_1),}, support=0.18, confidence = 0.99, lift = 5.01";
# }
# #T_26441 #T_26441_row3_col6:hover .pd-t {
#   visibility: visible;
# }
# #T_26441 #T_26441_row3_col6 .pd-t::after {
#   content: "Rule #607: {(SCHEDULED_DEPARTURE = (825.0, 1135.0]),(WHEELS_OFF = (840.0, 1155.0]),} ---> {(DEPARTURE_TIME = DEPARTURE_TIME_1),}, support=0.18, confidence = 0.99, lift = 5.01";
# }
# #T_26441 #T_26441_row3_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_26441 #T_26441_row3_col9 .pd-t::after {
#   content: "Rule #607: {(SCHEDULED_DEPARTURE = (825.0, 1135.0]),(WHEELS_OFF = (840.0, 1155.0]),} ---> {(DEPARTURE_TIME = DEPARTURE_TIME_1),}, support=0.18, confidence = 0.99, lift = 5.01";
# }
# #T_26441 #T_26441_row4_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_26441 #T_26441_row4_col1 .pd-t::after {
#   content: "Rule #52: {(WHEELS_ON = (1339.0, 1703.0]),} ---> {(ARRIVAL_TIME = ARRIVAL_TIME_2),}, support=0.19, confidence = 0.99, lift = 5.0";
# }
# #T_26441 #T_26441_row4_col5:hover .pd-t {
#   visibility: visible;
# }
# #T_26441 #T_26441_row4_col5 .pd-t::after {
#   content: "Rule #52: {(WHEELS_ON = (1339.0, 1703.0]),} ---> {(ARRIVAL_TIME = ARRIVAL_TIME_2),}, support=0.19, confidence = 0.99, lift = 5.0";
# }
# #T_26441 #T_26441_row5_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_26441 #T_26441_row5_col4 .pd-t::after {
#   content: "Rule #19: {(ELAPSED_TIME = (224.0, 499.0]),} ---> {(AIR_TIME = AIR_TIME_4),}, support=0.19, confidence = 0.95, lift = 4.79";
# }
# #T_26441 #T_26441_row5_col8:hover .pd-t {
#   visibility: visible;
# }
# #T_26441 #T_26441_row5_col8 .pd-t::after {
#   content: "Rule #19: {(ELAPSED_TIME = (224.0, 499.0]),} ---> {(AIR_TIME = AIR_TIME_4),}, support=0.19, confidence = 0.95, lift = 4.79";
# }
# #T_26441 #T_26441_row6_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_26441 #T_26441_row6_col1 .pd-t::after {
#   content: "Rule #56: {(WHEELS_ON = (1703.0, 2024.0]),} ---> {(ARRIVAL_TIME = ARRIVAL_TIME_3),}, support=0.19, confidence = 0.98, lift = 4.96";
# }
# #T_26441 #T_26441_row6_col5:hover .pd-t {
#   visibility: visible;
# }
# #T_26441 #T_26441_row6_col5 .pd-t::after {
#   content: "Rule #56: {(WHEELS_ON = (1703.0, 2024.0]),} ---> {(ARRIVAL_TIME = ARRIVAL_TIME_3),}, support=0.19, confidence = 0.98, lift = 4.96";
# }
# #T_26441 #T_26441_row7_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_26441 #T_26441_row7_col1 .pd-t::after {
#   content: "Rule #301: {(SCHEDULED_ARRIVAL = (0.0, 1027.0]),(WHEELS_ON = (0.0, 1008.0]),} ---> {(ARRIVAL_TIME = ARRIVAL_TIME_0),}, support=0.18, confidence = 0.99, lift = 5.05";
# }
# #T_26441 #T_26441_row7_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_26441 #T_26441_row7_col2 .pd-t::after {
#   content: "Rule #301: {(SCHEDULED_ARRIVAL = (0.0, 1027.0]),(WHEELS_ON = (0.0, 1008.0]),} ---> {(ARRIVAL_TIME = ARRIVAL_TIME_0),}, support=0.18, confidence = 0.99, lift = 5.05";
# }
# #T_26441 #T_26441_row7_col5:hover .pd-t {
#   visibility: visible;
# }
# #T_26441 #T_26441_row7_col5 .pd-t::after {
#   content: "Rule #301: {(SCHEDULED_ARRIVAL = (0.0, 1027.0]),(WHEELS_ON = (0.0, 1008.0]),} ---> {(ARRIVAL_TIME = ARRIVAL_TIME_0),}, support=0.18, confidence = 0.99, lift = 5.05";
# }
# #T_26441 #T_26441_row9_col7:hover .pd-t {
#   visibility: visible;
# }
# #T_26441 #T_26441_row9_col7 .pd-t::after {
#   content: "Rule #17: {(DISTANCE = (1546.0, 2724.0]),} ---> {(AIR_TIME = AIR_TIME_4),}, support=0.18, confidence = 0.91, lift = 4.62";
# }
# #T_26441 #T_26441_row9_col8:hover .pd-t {
#   visibility: visible;
# }
# #T_26441 #T_26441_row9_col8 .pd-t::after {
#   content: "Rule #17: {(DISTANCE = (1546.0, 2724.0]),} ---> {(AIR_TIME = AIR_TIME_4),}, support=0.18, confidence = 0.91, lift = 4.62";
# }
# #T_26441_row0_col1, #T_26441_row0_col2, #T_26441_row0_col5 {
#   background-color: pink;
# }
# #T_26441_row1_col1, #T_26441_row1_col5 {
#   background-color: blue;
# }
# #T_26441_row2_col6, #T_26441_row2_col9 {
#   background-color: purple;
# }
# #T_26441_row3_col3, #T_26441_row3_col6, #T_26441_row3_col9 {
#   background-color: gray;
# }
# #T_26441_row4_col1, #T_26441_row4_col5 {
#   background-color: red;
# }
# #T_26441_row5_col4, #T_26441_row5_col8 {
#   background-color: darkgrey;
# }
# #T_26441_row6_col1, #T_26441_row6_col5 {
#   background-color: green;
# }
# #T_26441_row7_col1, #T_26441_row7_col2, #T_26441_row7_col5 {
#   background-color: yellow;
# }
# #T_26441_row9_col7, #T_26441_row9_col8 {
#   background-color: lightblue;
# }
# </style>
# <table id="T_26441">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_26441_level0_col0" class="col_heading level0 col0" >DEPARTURE_DELAY</th>
#       <th id="T_26441_level0_col1" class="col_heading level0 col1" >ARRIVAL_TIME</th>
#       <th id="T_26441_level0_col2" class="col_heading level0 col2" >SCHEDULED_ARRIVAL</th>
#       <th id="T_26441_level0_col3" class="col_heading level0 col3" >WHEELS_OFF</th>
#       <th id="T_26441_level0_col4" class="col_heading level0 col4" >ELAPSED_TIME</th>
#       <th id="T_26441_level0_col5" class="col_heading level0 col5" >WHEELS_ON</th>
#       <th id="T_26441_level0_col6" class="col_heading level0 col6" >DEPARTURE_TIME</th>
#       <th id="T_26441_level0_col7" class="col_heading level0 col7" >DISTANCE</th>
#       <th id="T_26441_level0_col8" class="col_heading level0 col8" >AIR_TIME</th>
#       <th id="T_26441_level0_col9" class="col_heading level0 col9" >SCHEDULED_DEPARTURE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_26441_level0_row0" class="row_heading level0 row0" >46658</th>
#       <td id="T_26441_row0_col0" class="data row0 col0" >-5.00<span class="pd-t"></span></td>
#       <td id="T_26441_row0_col1" class="data row0 col1" >1124.00<span class="pd-t"></span></td>
#       <td id="T_26441_row0_col2" class="data row0 col2" >1130<span class="pd-t"></span></td>
#       <td id="T_26441_row0_col3" cla

# %%
df1 = full_df_a[full_df_a['CANCELLED']==1]

# %%
df1
# Out:
#        MONTH  DAY  DAY_OF_WEEK AIRLINE ORIGIN_AIRPORT  ... AIR_SYSTEM_DELAY  \
# 134        3    3            2      WN            MDW  ...              NaN
# 144        1   26            1      B6            DTW  ...              NaN
# 204        2    8            7      B6            LAX  ...              NaN
# 374        5   31            7      US            BOS  ...              NaN
# 470        4   14            2      B6            DCA  ...              NaN
# ...      ...  ...          ...     ...            ...  ...              ...
# 99667      6   25            4      WN            BWI  ...              NaN
# 99678      2    1            7      WN            ATL  ...              NaN
# 99686      2    6            5      OO            SFO  ...              NaN
# 99733      3    2            1      US            LGA  ...              NaN
# 99777      8   20            4      DL            LGA  ...              NaN
#
#        SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  WEATHER_DELAY
# 134               NaN            NaN                  NaN            NaN
# 144               NaN            NaN                  NaN            NaN
# 204               NaN            NaN                  NaN            NaN
# 374               NaN            NaN                  NaN            NaN
# 470               NaN            NaN                  NaN            NaN
# ...               ...            ...                  ...            ...
# 99667             NaN            NaN                  NaN            NaN
# 99678             NaN            NaN                  NaN            NaN
# 99686             NaN            NaN                  NaN            NaN
# 99733             NaN            NaN                  NaN            NaN
# 99777             NaN            NaN                  NaN            NaN
#
# [1482 rows x 28 columns]

# %%
sdf.display(df1, pivot_columns=['CANCELLED'])
# Out:
# for creating new table vectors, it took 0:00:01.060003
# for summary creation, it took 0:00:00.260082
# calculating rules for this dataset
# found 114 rules
# 100%|██████████████████████████████████████████████████████████████████████████████████| 89/89 [00:01<00:00, 83.39it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 477.38it/s]
# for or summary creation, it took 0:00:10.948579
# <style type="text/css">
# #T_8dff7 .pd-t {
#   visibility: hidden;
#   position: absolute;
#   z-index: 1;
#   background-color: black;
#   color: white;
#   transform: translate(-20px, -20px);
# }
# #T_8dff7 #T_8dff7_row0_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_8dff7 #T_8dff7_row0_col3 .pd-t::after {
#   content: "Rule #100: {(SCHEDULED_ARRIVAL = (1027.0, 1355.0]),(SCHEDULED_DEPARTURE = (825.0, 1135.0]),} ---> {(CANCELLED = 1),}, support=0.12, confidence = 1.0, lift = 1.0";
# }
# #T_8dff7 #T_8dff7_row0_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_8dff7 #T_8dff7_row0_col4 .pd-t::after {
#   content: "Rule #100: {(SCHEDULED_ARRIVAL = (1027.0, 1355.0]),(SCHEDULED_DEPARTURE = (825.0, 1135.0]),} ---> {(CANCELLED = 1),}, support=0.12, confidence = 1.0, lift = 1.0";
# }
# #T_8dff7 #T_8dff7_row0_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_8dff7 #T_8dff7_row0_col9 .pd-t::after {
#   content: "Rule #100: {(SCHEDULED_ARRIVAL = (1027.0, 1355.0]),(SCHEDULED_DEPARTURE = (825.0, 1135.0]),} ---> {(CANCELLED = 1),}, support=0.12, confidence = 1.0, lift = 1.0";
# }
# #T_8dff7 #T_8dff7_row1_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_8dff7 #T_8dff7_row1_col3 .pd-t::after {
#   content: "Rule #98: {(SCHEDULED_ARRIVAL = (0.0, 1027.0]),(SCHEDULED_DEPARTURE = (2.0, 825.0]),} ---> {(CANCELLED = 1),}, support=0.17, confidence = 1.0, lift = 1.0";
# }
# #T_8dff7 #T_8dff7_row1_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_8dff7 #T_8dff7_row1_col4 .pd-t::after {
#   content: "Rule #98: {(SCHEDULED_ARRIVAL = (0.0, 1027.0]),(SCHEDULED_DEPARTURE = (2.0, 825.0]),} ---> {(CANCELLED = 1),}, support=0.17, confidence = 1.0, lift = 1.0";
# }
# #T_8dff7 #T_8dff7_row1_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_8dff7 #T_8dff7_row1_col9 .pd-t::after {
#   content: "Rule #98: {(SCHEDULED_ARRIVAL = (0.0, 1027.0]),(SCHEDULED_DEPARTURE = (2.0, 825.0]),} ---> {(CANCELLED = 1),}, support=0.17, confidence = 1.0, lift = 1.0";
# }
# #T_8dff7 #T_8dff7_row2_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_8dff7 #T_8dff7_row2_col3 .pd-t::after {
#   content: "Rule #104: {(CANCELLED = 1),(SCHEDULED_DEPARTURE = (1135.0, 1505.0]),} ---> {(SCHEDULED_ARRIVAL = SCHEDULED_ARRIVAL_2),}, support=0.14, confidence = 0.74, lift = 3.84";
# }
# #T_8dff7 #T_8dff7_row2_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_8dff7 #T_8dff7_row2_col4 .pd-t::after {
#   content: "Rule #104: {(CANCELLED = 1),(SCHEDULED_DEPARTURE = (1135.0, 1505.0]),} ---> {(SCHEDULED_ARRIVAL = SCHEDULED_ARRIVAL_2),}, support=0.14, confidence = 0.74, lift = 3.84";
# }
# #T_8dff7 #T_8dff7_row2_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_8dff7 #T_8dff7_row2_col9 .pd-t::after {
#   content: "Rule #104: {(CANCELLED = 1),(SCHEDULED_DEPARTURE = (1135.0, 1505.0]),} ---> {(SCHEDULED_ARRIVAL = SCHEDULED_ARRIVAL_2),}, support=0.14, confidence = 0.74, lift = 3.84";
# }
# #T_8dff7 #T_8dff7_row3_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_8dff7 #T_8dff7_row3_col3 .pd-t::after {
#   content: "Rule #105: {(SCHEDULED_ARRIVAL = (1714.0, 2030.0]),(SCHEDULED_DEPARTURE = (1505.0, 1825.0]),} ---> {(CANCELLED = 1),}, support=0.16, confidence = 1.0, lift = 1.0";
# }
# #T_8dff7 #T_8dff7_row3_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_8dff7 #T_8dff7_row3_col4 .pd-t::after {
#   content: "Rule #105: {(SCHEDULED_ARRIVAL = (1714.0, 2030.0]),(SCHEDULED_DEPARTURE = (1505.0, 1825.0]),} ---> {(CANCELLED = 1),}, support=0.16, confidence = 1.0, lift = 1.0";
# }
# #T_8dff7 #T_8dff7_row3_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_8dff7 #T_8dff7_row3_col9 .pd-t::after {
#   content: "Rule #105: {(SCHEDULED_ARRIVAL = (1714.0, 2030.0]),(SCHEDULED_DEPARTURE = (1505.0, 1825.0]),} ---> {(CANCELLED = 1),}, support=0.16, confidence = 1.0, lift = 1.0";
# }
# #T_8dff7 #T_8dff7_row4_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_8dff7 #T_8dff7_row4_col1 .pd-t::after {
#   content: "Rule #90: {(DISTANCE = (89.0, 502.0]),(SCHEDULED_TIME = (42.0, 103.0]),} ---> {(CANCELLED = 1),}, support=0.24, confidence = 1.0, lift = 1.0";
# }
# #T_8dff7 #T_8dff7_row4_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_8dff7 #T_8dff7_row4_col2 .pd-t::after {
#   content: "Rule #90: {(DISTANCE = (89.0, 502.0]),(SCHEDULED_TIME = (42.0, 103.0]),} ---> {(CANCELLED = 1),}, support=0.24, confidence = 1.0, lift = 1.0";
# }
# #T_8dff7 #T_8dff7_row4_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_8dff7 #T_8dff7_row4_col9 .pd-t::after {
#   content: "Rule #90: {(DISTANCE = (89.0, 502.0]),(SCHEDULED_TIME = (42.0, 103.0]),} ---> {(CANCELLED = 1),}, support=0.24, confidence = 1.0, lift = 1.0";
# }
# #T_8dff7 #T_8dff7_row5_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_8dff7 #T_8dff7_row5_col3 .pd-t::after {
#   content: "Rule #106: {(SCHEDULED_ARRIVAL = (2030.0, 2359.0]),(SCHEDULED_DEPARTURE = (1825.0, 2359.0]),} ---> {(CANCELLED = 1),}, support=0.17, confidence = 1.0, lift = 1.0";
# }
# #T_8dff7 #T_8dff7_row5_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_8dff7 #T_8dff7_row5_col4 .pd-t::after {
#   content: "Rule #106: {(SCHEDULED_ARRIVAL = (2030.0, 2359.0]),(SCHEDULED_DEPARTURE = (1825.0, 2359.0]),} ---> {(CANCELLED = 1),}, support=0.17, confidence = 1.0, lift = 1.0";
# }
# #T_8dff7 #T_8dff7_row5_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_8dff7 #T_8dff7_row5_col9 .pd-t::after {
#   content: "Rule #106: {(SCHEDULED_ARRIVAL = (2030.0, 2359.0]),(SCHEDULED_DEPARTURE = (1825.0, 2359.0]),} ---> {(CANCELLED = 1),}, support=0.17, confidence = 1.0, lift = 1.0";
# }
# #T_8dff7 #T_8dff7_row6_col5:hover .pd-t {
#   visibility: visible;
# }
# #T_8dff7 #T_8dff7_row6_col5 .pd-t::after {
#   content: "Rule #2: {(AIRLINE = UA),} ---> {(CANCELLED = 1),}, support=0.13, confidence = 1.0, lift = 1.0";
# }
# #T_8dff7 #T_8dff7_row6_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_8dff7 #T_8dff7_row6_col9 .pd-t::after {
#   content: "Rule #2: {(AIRLINE = UA),} ---> {(CANCELLED = 1),}, support=0.13, confidence = 1.0, lift = 1.0";
# }
# #T_8dff7 #T_8dff7_row7_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_8dff7 #T_8dff7_row7_col0 .pd-t::after {
#   content: "Rule #113: {(CANCELLATION_REASON = B),(SCHEDULED_ARRIVAL = (2030.0, 2359.0]),(SCHEDULED_DEPARTURE = (1825.0, 2359.0]),} ---> {(CANCELLED = 1),}, support=0.11, confidence = 1.0, lift = 1.0";
# }
# #T_8dff7 #T_8dff7_row7_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_8dff7 #T_8dff7_row7_col3 .pd-t::after {
#   content: "Rule #113: {(CANCELLATION_REASON = B),(SCHEDULED_ARRIVAL = (2030.0, 2359.0]),(SCHEDULED_DEPARTURE = (1825.0, 2359.0]),} ---> {(CANCELLED = 1),}, support=0.11, confidence = 1.0, lift = 1.0";
# }
# #T_8dff7 #T_8dff7_row7_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_8dff7 #T_8dff7_row7_col4 .pd-t::after {
#   content: "Rule #113: {(CANCELLATION_REASON = B),(SCHEDULED_ARRIVAL = (2030.0, 2359.0]),(SCHEDULED_DEPARTURE = (1825.0, 2359.0]),} ---> {(CANCELLED = 1),}, support=0.11, confidence = 1.0, lift = 1.0";
# }
# #T_8dff7 #T_8dff7_row7_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_8dff7 #T_8dff7_row7_col9 .pd-t::after {
#   content: "Rule #113: {(CANCELLATION_REASON = B),(SCHEDULED_ARRIVAL = (2030.0, 2359.0]),(SCHEDULED_DEPARTURE = (1825.0, 2359.0]),} ---> {(CANCELLED = 1),}, support=0.11, confidence = 1.0, lift = 1.0";
# }
# #T_8dff7 #T_8dff7_row8_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_8dff7 #T_8dff7_row8_col0 .pd-t::after {
#   content: "Rule #63: {(CANCELLED = 1),(DAY_OF_WEEK = 7),} ---> {(CANCELLATION_REASON = B),}, support=0.11, confidence = 0.68, lift = 1.14";
# }
# #T_8dff7 #T_8dff7_row8_col7:hover .pd-t {
#   visibility: visible;
# }
# #T_8dff7 #T_8dff7_row8_col7 .pd-t::after {
#   content: "Rule #63: {(CANCELLED = 1),(DAY_OF_WEEK = 7),} ---> {(CANCELLATION_REASON = B),}, support=0.11, confidence = 0.68, lift = 1.14";
# }
# #T_8dff7 #T_8dff7_row8_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_8dff7 #T_8dff7_row8_col9 .pd-t::after {
#   content: "Rule #63: {(CANCELLED = 1),(DAY_OF_WEEK = 7),} ---> {(CANCELLATION_REASON = B),}, support=0.11, confidence = 0.68, lift = 1.14";
# }
# #T_8dff7 #T_8dff7_row9_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_8dff7 #T_8dff7_row9_col3 .pd-t::after {
#   content: "Rule #99: {(CANCELLED = 1),(SCHEDULED_DEPARTURE = (2.0, 825.0]),} ---> {(SCHEDULED_ARRIVAL = SCHEDULED_ARRIVAL_0),}, support=0.17,
