# %%
import pandas as pd



path_sample_df =  'input/spotify_popularity/dataset.csv'
full_df_a = pd.read_csv(path_sample_df)
if 'Unnamed: 0' in full_df_a.columns:
    full_df_a.drop(['Unnamed: 0'], axis=1, inplace=True)
if 'Unnamed: 0.1' in full_df_a.columns:
    full_df_a.drop([ 'Unnamed: 0.1'], axis=1, inplace=True)
if 'index' in full_df_a.columns:
    full_df_a.drop([ 'index'], axis=1, inplace=True)

# %%
from SubTub import subTub
sdf = subTub(full_df_a,use_rules=True, subtub_config={'rules':'rules_spotify.csv'})
sdf.display(full_df_a)
# Out:
# 100%|████████████████████████████████████████| 249/249 [00:01<00:00, 152.73it/s]
# 100%|███████████████████████████████████████████| 32/32 [00:01<00:00, 16.98it/s]
# 100%|████████████████████████████████████████| 249/249 [00:01<00:00, 195.80it/s]
# 100%|████████████████████████████████████████| 249/249 [00:01<00:00, 166.88it/s]
# 100%|████████████████████████████████████████| 249/249 [00:01<00:00, 176.26it/s]
# 100%|████████████████████████████████████████| 249/249 [00:01<00:00, 160.68it/s]
# 100%|████████████████████████████████████████| 249/249 [00:01<00:00, 179.59it/s]
# 100%|████████████████████████████████████████| 249/249 [00:01<00:00, 166.22it/s]
# 100%|████████████████████████████████████████| 249/249 [00:01<00:00, 146.09it/s]
# 100%|████████████████████████████████████████| 249/249 [00:01<00:00, 161.27it/s]
# 100%|████████████████████████████████████████| 249/249 [00:01<00:00, 171.03it/s]
# 100%|████████████████████████████████████████| 249/249 [00:01<00:00, 167.27it/s]
# {'cell_cov': 0.252, 'jaccard': 0.8}
# for or summary creation, it took 0:00:43.525031
# <style type="text/css">
# #T_ed2b6_ .pd-t {
#   visibility: hidden;
#   position: absolute;
#   z-index: 1;
#   background-color: black;
#   color: white;
#   transform: translate(-20px, -20px);
# }
# #T_ed2b6_ #T_ed2b6_row0_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_ed2b6_ #T_ed2b6_row0_col1 .pd-t::after {
#   content: "Rule #0: {(energy = energy_4),} ---> {(acousticness = acousticness_0),}, support=0.11, confidence = 0.57, lift = 2.85";
# }
# #T_ed2b6_ #T_ed2b6_row0_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_ed2b6_ #T_ed2b6_row0_col9 .pd-t::after {
#   content: "Rule #0: {(energy = energy_4),} ---> {(acousticness = acousticness_0),}, support=0.11, confidence = 0.57, lift = 2.85";
# }
# #T_ed2b6_ #T_ed2b6_row1_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_ed2b6_ #T_ed2b6_row1_col2 .pd-t::after {
#   content: "Rule #35: {(mode = 1),} ---> {(duration_ms = duration_ms_1),}, support=0.15, confidence = 0.21, lift = 1.04";
# }
# #T_ed2b6_ #T_ed2b6_row1_col7:hover .pd-t {
#   visibility: visible;
# }
# #T_ed2b6_ #T_ed2b6_row1_col7 .pd-t::after {
#   content: "Rule #35: {(mode = 1),} ---> {(duration_ms = duration_ms_1),}, support=0.15, confidence = 0.21, lift = 1.04";
# }
# #T_ed2b6_ #T_ed2b6_row3_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_ed2b6_ #T_ed2b6_row3_col1 .pd-t::after {
#   content: "Rule #11: {(mode = 1),} ---> {(acousticness = acousticness_3),}, support=0.15, confidence = 0.21, lift = 1.05";
# }
# #T_ed2b6_ #T_ed2b6_row3_col7:hover .pd-t {
#   visibility: visible;
# }
# #T_ed2b6_ #T_ed2b6_row3_col7 .pd-t::after {
#   content: "Rule #11: {(mode = 1),} ---> {(acousticness = acousticness_3),}, support=0.15, confidence = 0.21, lift = 1.05";
# }
# #T_ed2b6_ #T_ed2b6_row4_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_ed2b6_ #T_ed2b6_row4_col0 .pd-t::after {
#   content: "Rule #4: {(instrumentalness = instrumentalness_0),} ---> {(acousticness = acousticness_1),}, support=0.11, confidence = 0.26, lift = 1.32";
# }
# #T_ed2b6_ #T_ed2b6_row4_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_ed2b6_ #T_ed2b6_row4_col1 .pd-t::after {
#   content: "Rule #4: {(instrumentalness = instrumentalness_0),} ---> {(acousticness = acousticness_1),}, support=0.11, confidence = 0.26, lift = 1.32";
# }
# #T_ed2b6_ #T_ed2b6_row5_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_ed2b6_ #T_ed2b6_row5_col1 .pd-t::after {
#   content: "Rule #2: {(mode = 1),} ---> {(acousticness = acousticness_0),}, support=0.13, confidence = 0.19, lift = 0.94";
# }
# #T_ed2b6_ #T_ed2b6_row5_col7:hover .pd-t {
#   visibility: visible;
# }
# #T_ed2b6_ #T_ed2b6_row5_col7 .pd-t::after {
#   content: "Rule #2: {(mode = 1),} ---> {(acousticness = acousticness_0),}, support=0.13, confidence = 0.19, lift = 0.94";
# }
# #T_ed2b6_ #T_ed2b6_row6_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_ed2b6_ #T_ed2b6_row6_col2 .pd-t::after {
#   content: "Rule #42: {(mode = 1),} ---> {(duration_ms = duration_ms_4),}, support=0.13, confidence = 0.19, lift = 0.93";
# }
# #T_ed2b6_ #T_ed2b6_row6_col7:hover .pd-t {
#   visibility: visible;
# }
# #T_ed2b6_ #T_ed2b6_row6_col7 .pd-t::after {
#   content: "Rule #42: {(mode = 1),} ---> {(duration_ms = duration_ms_4),}, support=0.13, confidence = 0.19, lift = 0.93";
# }
# #T_ed2b6_ #T_ed2b6_row7_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_ed2b6_ #T_ed2b6_row7_col0 .pd-t::after {
#   content: "Rule #108: {(mode = 0),} ---> {(instrumentalness = instrumentalness_0),}, support=0.11, confidence = 0.38, lift = 0.94";
# }
# #T_ed2b6_ #T_ed2b6_row7_col7:hover .pd-t {
#   visibility: visible;
# }
# #T_ed2b6_ #T_ed2b6_row7_col7 .pd-t::after {
#   content: "Rule #108: {(mode = 0),} ---> {(instrumentalness = instrumentalness_0),}, support=0.11, confidence = 0.38, lift = 0.94";
# }
# #T_ed2b6_ #T_ed2b6_row8_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_ed2b6_ #T_ed2b6_row8_col1 .pd-t::after {
#   content: "Rule #15: {(mode = 1),} ---> {(acousticness = acousticness_4),}, support=0.14, confidence = 0.2, lift = 1.0";
# }
# #T_ed2b6_ #T_ed2b6_row8_col7:hover .pd-t {
#   visibility: visible;
# }
# #T_ed2b6_ #T_ed2b6_row8_col7 .pd-t::after {
#   content: "Rule #15: {(mode = 1),} ---> {(acousticness = acousticness_4),}, support=0.14, confidence = 0.2, lift = 1.0";
# }
# #T_ed2b6_ #T_ed2b6_row9_col5:hover .pd-t {
#   visibility: visible;
# }
# #T_ed2b6_ #T_ed2b6_row9_col5 .pd-t::after {
#   content: "Rule #54: {(loudness = loudness_4),} ---> {(energy = energy_4),}, support=0.12, confidence = 0.62, lift = 3.06";
# }
# #T_ed2b6_ #T_ed2b6_row9_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_ed2b6_ #T_ed2b6_row9_col9 .pd-t::after {
#   content: "Rule #54: {(loudness = loudness_4),} ---> {(energy = energy_4),}, support=0.12, confidence = 0.62, lift = 3.06";
# }
# #T_ed2b6_row0_col1, #T_ed2b6_row0_col9 {
#   background-color: yellow;
# }
# #T_ed2b6_row1_col2, #T_ed2b6_row1_col7 {
#   background-color: pink;
# }
# #T_ed2b6_row3_col1, #T_ed2b6_row3_col7 {
#   background-color: blue;
# }
# #T_ed2b6_row4_col0, #T_ed2b6_row4_col1 {
#   background-color: lightblue;
# }
# #T_ed2b6_row5_col1, #T_ed2b6_row5_col7 {
#   background-color: purple;
# }
# #T_ed2b6_row6_col2, #T_ed2b6_row6_col7 {
#   background-color: gray;
# }
# #T_ed2b6_row7_col0, #T_ed2b6_row7_col7 {
#   background-color: red;
# }
# #T_ed2b6_row8_col1, #T_ed2b6_row8_col7 {
#   background-color: green;
# }
# #T_ed2b6_row9_col5, #T_ed2b6_row9_col9 {
#   background-color: darkgrey;
# }
# </style>
# <table id="T_ed2b6_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >instrumentalness</th>
#       <th class="col_heading level0 col1" >acousticness</th>
#       <th class="col_heading level0 col2" >duration_ms</th>
#       <th class="col_heading level0 col3" >release_date</th>
#       <th class="col_heading level0 col4" >key</th>
#       <th class="col_heading level0 col5" >loudness</th>
#       <th class="col_heading level0 col6" >artists</th>
#       <th class="col_heading level0 col7" >mode</th>
#       <th class="col_heading level0 col8" >popularity</th>
#       <th class="col_heading level0 col9" >energy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ed2b6_level0_row0" class="row_heading level0 row0" >20001</th>
#       <td id="T_ed2b6_row0_col0" class="data row0 col0" >0.00<span class="pd-t"></span></td>
#       <td id="T_ed2b6_row0_col1" class="data row0 col1" >0.01<span class="pd-t"></span></td>
#       <td id="T_ed2b6_row0_col2" class="data row0 col2" >199053<span class="pd-t"></span></td>
#       <td id="T_ed2b6_row0_col3" class="data row0 col3" >1978-01-01<span class="pd-t"></span></td>
#       <td id="T_ed2b6_row0_col4" class="data row0 col4" >8<span class="pd-t"></span></td>
#       <td id="T_ed2b6_row0_col5" class="data row0 col5" >-8.39<span class="pd-t"></span></td>
#       <td id="T_ed2b6_row0_col6" class="data row0 col6" >['Paul Stanley']<span class="pd-t"></span></td>
#       <td id="T_ed2b6_row0_col7" class="data row0 col7" >1<span class="pd-t"></span></td>
#       <td id="T_ed2b6_row0_col8" class="data row0 col8" >32<span class="pd-t"></span></td>
#       <td id="T_ed2b6_row0_col9" class="data row0 col9" >0.93<span class="pd-t"></span></td>
#     </tr>
#     <tr>
#       <th id="T_ed2b6_level0_row1" class="row_heading level0 row1" >90151</th>
#       <td id="T_ed2b6_row1_col0" class="data row1 col0" >0.95<span class="pd-t"></span></td>
#       <td id="T_ed2b6_row1_col1" class="data row1 col1" >0.82<span class="pd-t"></span></td>
#       <td id="T_ed2b6_row1_col2" class="data row1 col2" >183160<span class="pd-t"></span></td>
#       <td id="T_ed2b6_row1_col3" class="data row1 col3" >1944-01-01<span class="pd-t"></span></td>
#       <td id="T_ed2b6_row1_col4" class="data row1 col4" >8<span class="pd-t"></span></td>
#       <td id="T_ed2b6_row1_col5" class="data row1 col5" >-9.48<span class="pd-t"></span></td>
#       <td id="T_ed2b6_row1_col6" class="data row1 col6" >['Lester Young']<span class="pd-t"></span></td>
#       <td id="T_ed2b6_row1_col7" class="data row1 col7" >1<span class="pd-t"></span></td>
#       <td id="T_ed2b6_row1_col8" class="data row1 col8" >3<span class="pd-t"></span></td>
#       <td id="T_ed2b6_row1_col9" class="data row1 col9" >0.50<span class="pd-t"></span></td>
#     </tr>
#     <tr>
#       <th id="T_ed2b6_level

# %%
df1 = full_df_a[full_df_a['popularity']>70]

# %%
df1
# Out:
#         acousticness                           artists  danceability  \
# 6754          0.5870                          ['Gala']         0.704
# 7606          0.0251                   ['Mon Laferte']         0.394
# 7845          0.2800               ['Imagine Dragons']         0.301
# 7883          0.0988                         ['TWICE']         0.574
# 7895          0.2390  ['Clean Bandit', 'Zara Larsson']         0.715
# ...              ...                               ...           ...
# 169877        0.0181       ['Agust D', 'Kim Jong Wan']         0.560
# 169885        0.8090                 ['Justin Bieber']         0.566
# 169892        0.1990                      ['CHUNG HA']         0.636
# 169894        0.5920                    ['Noah Cyrus']         0.618
# 169904        0.1730            ['DripReport', 'Tyga']         0.875
#
#         duration_ms  energy  explicit                      id  \
# 6754         213394   0.861         0  3u5N55tHf7hXATSQrjBh2q
# 7606         278547   0.475         0  4skuEIloXWuxxgekKupkEH
# 7845         230289   0.672         0  31VOknKjFrEX47bZXzqcoF
# 7883         208240   0.909         0  1IX47gefluXmKX4PrTBCRM
# 7895         212733   0.605         0  72gv4zhNvRVdQA0eOenCal
# ...             ...     ...       ...                     ...
# 169877       292079   0.735         1  5qJF3xMbNjsPuqQDRkfUl1
# 169885       136907   0.438         0  5Py8zRKGkZvgHniVVtvNCN
# 169892       217239   0.841         0  3As0OA5B06BxLfADvYyG8L
# 169894       190183   0.428         0  0gySkOOewOdZtHG8stPEB8
# 169904       163800   0.443         1  4KppkflX7I3vJQk7urOJaS
#
#         instrumentalness  key  liveness  loudness  mode  \
# 6754            0.061500    2    0.0992    -4.221     0
# 7606            0.007490   10    0.1120    -7.935     1
# 7845            0.000031    2    0.0609    -4.497     1
# 7883            0.000000    8    0.2640    -1.572     1
# 7895            0.000014    0    0.1890    -5.128     0
# ...                  ...  ...       ...       ...   ...
# 169877          0.000009    0    0.0571    -6.344     1
# 169885          0.000000    0    0.2120    -7.564     0
# 169892          0.000395    2    0.0836    -1.927     0
# 169894          0.000000    7    0.1920    -8.500     0
# 169904          0.000032    1    0.0891    -7.461     1
#
#                                                name  popularity release_date  \
# 6754                              Freed From Desire          72   2007-04-18
# 7606                             Tu Falta De Querer          71   2015-08-21
# 7845                                     Next To Me          71   2017-06-23
# 7883                                   What is Love          72   2018-07-09
# 7895                  Symphony (feat. Zara Larsson)          74   2018-11-30
# ...                                             ...         ...          ...
# 169877  Dear my friend (feat. Kim Jong Wan of NELL)          72   2020-05-22
# 169885                                All Around Me          72   2020-02-14
# 169892                                 Stay Tonight          74   2020-04-27
# 169894                                  Young & Sad          71   2020-05-15
# 169904                Skechers (feat. Tyga) - Remix          75   2020-05-15
#
#         speechiness    tempo  valence  year
# 6754         0.0493  128.990    0.636  2007
# 7606         0.0280  129.995    0.441  2015
# 7845         0.0623  169.497    0.384  2017
# 7883         0.0655  169.964    0.565  2018
# 7895         0.0428  122.956    0.454  2018
# ...             ...      ...      ...   ...
# 169877       0.0638  148.026    0.270  2020
# 169885       0.0367  117.127    0.692  2020
# 169892       0.0548  121.022    0.506  2020
# 169894       0.0380  142.021    0.359  2020
# 169904       0.1430  100.012    0.306  2020
#
# [3816 rows x 19 columns]

# %%
sdf.display(df1)
# Out:
# for creating new table vectors, it took 0:00:00.996040
# for summary creation, it took 0:00:01.284254
# 100%|████████████████████████████████████████| 249/249 [00:02<00:00, 111.17it/s]
# 100%|███████████████████████████████████████████| 89/89 [00:01<00:00, 63.89it/s]
# 100%|████████████████████████████████████████| 249/249 [00:01<00:00, 138.94it/s]
# 100%|████████████████████████████████████████| 249/249 [00:01<00:00, 136.83it/s]
# 100%|████████████████████████████████████████| 249/249 [00:01<00:00, 161.42it/s]
# 100%|████████████████████████████████████████| 249/249 [00:01<00:00, 199.03it/s]
# 100%|████████████████████████████████████████| 249/249 [00:01<00:00, 204.74it/s]
# 100%|████████████████████████████████████████| 249/249 [00:01<00:00, 159.37it/s]
# 100%|████████████████████████████████████████| 249/249 [00:01<00:00, 148.03it/s]
# 100%|████████████████████████████████████████| 249/249 [00:01<00:00, 130.71it/s]
# 100%|████████████████████████████████████████| 249/249 [00:02<00:00, 117.83it/s]
# 100%|████████████████████████████████████████| 249/249 [00:01<00:00, 131.86it/s]
# couldn't find matching rule for row number  107075
# {'cell_cov': 0.508, 'jaccard': 0.69}
# for or summary creation, it took 0:00:23.160076
# /specific/disk1/home/kathyr/table_summarization_baselines/associations_rules_summary/utils_code.py:872: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   display(df.style.apply(style_spec, axis=None).set_precision(2).set_tooltips(create_tooltips_df(df)))
# <style type="text/css">
# #T_304c2_ .pd-t {
#   visibility: hidden;
#   position: absolute;
#   z-index: 1;
#   background-color: black;
#   color: white;
#   transform: translate(-20px, -20px);
# }
# #T_304c2_ #T_304c2_row0_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_304c2_ #T_304c2_row0_col2 .pd-t::after {
#   content: "Rule #129: {(year = year_4),} ---> {(loudness = loudness_4),}, support=0.11, confidence = 0.54, lift = 2.7";
# }
# #T_304c2_ #T_304c2_row0_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_304c2_ #T_304c2_row0_col4 .pd-t::after {
#   content: "Rule #129: {(year = year_4),} ---> {(loudness = loudness_4),}, support=0.11, confidence = 0.54, lift = 2.7";
# }
# #T_304c2_ #T_304c2_row1_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_304c2_ #T_304c2_row1_col1 .pd-t::after {
#   content: "Rule #232: {(mode = 1),(valence = valence_1),} ---> {(explicit = 0),}, support=0.13, confidence = 0.92, lift = 1.0";
# }
# #T_304c2_ #T_304c2_row1_col6:hover .pd-t {
#   visibility: visible;
# }
# #T_304c2_ #T_304c2_row1_col6 .pd-t::after {
#   content: "Rule #232: {(mode = 1),(valence = valence_1),} ---> {(explicit = 0),}, support=0.13, confidence = 0.92, lift = 1.0";
# }
# #T_304c2_ #T_304c2_row1_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_304c2_ #T_304c2_row1_col9 .pd-t::after {
#   content: "Rule #232: {(mode = 1),(valence = valence_1),} ---> {(explicit = 0),}, support=0.13, confidence = 0.92, lift = 1.0";
# }
# #T_304c2_ #T_304c2_row2_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_304c2_ #T_304c2_row2_col1 .pd-t::after {
#   content: "Rule #28: {(explicit = 0),} ---> {(danceability = danceability_4),}, support=0.16, confidence = 0.17, lift = 0.85";
# }
# #T_304c2_ #T_304c2_row2_col7:hover .pd-t {
#   visibility: visible;
# }
# #T_304c2_ #T_304c2_row2_col7 .pd-t::after {
#   content: "Rule #28: {(explicit = 0),} ---> {(danceability = danceability_4),}, support=0.16, confidence = 0.17, lift = 0.85";
# }
# #T_304c2_ #T_304c2_row3_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_304c2_ #T_304c2_row3_col1 .pd-t::after {
#   content: "Rule #10: {(explicit = 0),} ---> {(acousticness = acousticness_3),}, support=0.2, confidence = 0.22, lift = 1.07";
# }
# #T_304c2_ #T_304c2_row3_col5:hover .pd-t {
#   visibility: visible;
# }
# #T_304c2_ #T_304c2_row3_col5 .pd-t::after {
#   content: "Rule #10: {(explicit = 0),} ---> {(acousticness = acousticness_3),}, support=0.2, confidence = 0.22, lift = 1.07";
# }
# #T_304c2_ #T_304c2_row4_col5:hover .pd-t {
#   visibility: visible;
# }
# #T_304c2_ #T_304c2_row4_col5 .pd-t::after {
#   content: "Rule #2: {(mode = 1),} ---> {(acousticness = acousticness_0),}, support=0.13, confidence = 0.19, lift = 0.94";
# }
# #T_304c2_ #T_304c2_row4_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_304c2_ #T_304c2_row4_col9 .pd-t::after {
#   content: "Rule #2: {(mode = 1),} ---> {(acousticness = acousticness_0),}, support=0.13, confidence = 0.19, lift = 0.94";
# }
# #T_304c2_ #T_304c2_row5_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_304c2_ #T_304c2_row5_col1 .pd-t::after {
#   content: "Rule #239: {(mode = 1),(year = year_2),} ---> {(explicit = 0),}, support=0.14, confidence = 0.99, lift = 1.08";
# }
# #T_304c2_ #T_304c2_row5_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_304c2_ #T_304c2_row5_col4 .pd-t::after {
#   content: "Rule #239: {(mode = 1),(year = year_2),} ---> {(explicit = 0),}, support=0.14, confidence = 0.99, lift = 1.08";
# }
# #T_304c2_ #T_304c2_row5_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_304c2_ #T_304c2_row5_col9 .pd-t::after {
#   content: "Rule #239: {(mode = 1),(year = year_2),} ---> {(explicit = 0),}, support=0.14, confidence = 0.99, lift = 1.08";
# }
# #T_304c2_ #T_304c2_row6_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_304c2_ #T_304c2_row6_col1 .pd-t::after {
#   content: "Rule #3: {(explicit = 0),} ---> {(acousticness = acousticness_1),}, support=0.17, confidence = 0.18, lift = 0.91";
# }
# #T_304c2_ #T_304c2_row6_col5:hover .pd-t {
#   visibility: visible;
# }
# #T_304c2_ #T_304c2_row6_col5 .pd-t::after {
#   content: "Rule #3: {(explicit = 0),} ---> {(acousticness = acousticness_1),}, support=0.17, confidence = 0.18, lift = 0.91";
# }
# #T_304c2_ #T_304c2_row7_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_304c2_ #T_304c2_row7_col1 .pd-t::after {
#   content: "Rule #241: {(mode = 1),(year = year_4),} ---> {(explicit = 0),}, support=0.1, confidence = 0.79, lift = 0.86";
# }
# #T_304c2_ #T_304c2_row7_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_304c2_ #T_304c2_row7_col4 .pd-t::after {
#   content: "Rule #241: {(mode = 1),(year = year_4),} ---> {(explicit = 0),}, support=0.1, confidence = 0.79, lift = 0.86";
# }
# #T_304c2_ #T_304c2_row7_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_304c2_ #T_304c2_row7_col9 .pd-t::after {
#   content: "Rule #241: {(mode = 1),(year = year_4),} ---> {(explicit = 0),}, support=0.1, confidence = 0.79, lift = 0.86";
# }
# #T_304c2_ #T_304c2_row8_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_304c2_ #T_304c2_row8_col1 .pd-t::after {
#   content: "Rule #242: {(explicit = 0),(year = year_4),} ---> {(mode = 1),}, support=0.1, confidence = 0.69, lift = 0.98";
# }
# #T_304c2_ #T_304c2_row8_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_304c2_ #T_304c2_row8_col4 .pd-t::after {
#   content: "Rule #242: {(explicit = 0),(year = year_4),} ---> {(mode = 1),}, support=0.1, confidence = 0.69, lift = 0.98";
# }
# #T_304c2_ #T_304c2_row8_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_304c2_ #T_304c2_row8_col9 .pd-t::after {
#   content: "Rule #242: {(explicit = 0),(year = year_4),} ---> {(mode = 1),}, support=0.1, confidence = 0.69, lift = 0.98";
# }
# #T_304c2_row0_col2, #T_304c2_row0_col4 {
#   background-color: green;
# }
# #T_304c2_row1_col1, #T_304c2_row1_col6, #T_304c2_row1_col9 {
#   background-color: blue;
# }
# #T_304c2_row2_col1, #T_304c2_row2_col7 {
#   background-color: purple;
# }
# #T_304c2_row3_col1, #T_304c2_row3_col5 {
#   background-color: yellow;
# }
# #T_304c2_row4_col5, #T_304c2_row4_col9 {
#   background-color: gray;
# }
# #T_304c2_row5_col1, #T_304c2_row5_col4, #T_304c2_row5_col9 {
#   background-color: darkgrey;
# }
# #T_304c2_row6_col1, #T_304c2_row6_col5 {
#   background-color: orange;
# }
# #T_304c2_row7_col1, #T_304c2_row7_col4, #T_304c2_row7_col9 {
#   background-color: lightblue;
# }
# #T_304c2_row8_col1, #T_304c2_row8_col4, #T_304c2_row8_col9 {
#   background-color: red;
# }
# </style>
# <table id="T_304c2_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >liveness</th>
#       <th class="col_heading level0 col1" >explicit</th>
#       <th class="col_heading level0 col2" >loudness</th>
#       <th class="col_heading level0 col3" >energy</th>
#       <th class="col_heading level0 col4" >year</th>
#       <th class="col_heading level0 col5" >acousticness</th>
#       <th class="col_heading level0 col6" >valence</th>
#       <th class="col_heading level0 col7" >danceability</th>
#       <th class="col_heading level0 col8" >speechiness</th>
#       <th class="col_heading level0 col9" >mode</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_304c2_level0_row0" class="row_heading level0 row0" >116552</th>
#       <td id="T_304c2_row0_col0" class="data row0 col0" >0.17<span class="pd-t"></span></td>
#       <td id="T_304c2_row0_col1" class="data row0 col1" >1<span class="pd-t"></span></td>
#       <td id="T_304c2_row0_col2" class="data row0 col2" >-5.67<span class="pd-t"></span></td>
#       <td id="T_304c2_row0_col3" class="data row0 col3" >0.76<span class="pd-t"></span></td>
#       <td id="T_304c2_row0_col4" class="data row0 col4" >2019<span class="pd-t"></span></td>
#       <td id="T_304c2_row0_col5" class="data row0 col5" >0.14<span class="pd-t"></span></td>
#       <td id="T_304c2_row0_col6" class="data row0 col6" >0.77<span class="pd-t"></span></td>
#       <td id="T_304c2_row0_col7" class="data row0 col7" >0.69<span class="pd-t"></span></td>
#       <td id="T_304c2_row0_col8" class="data row0 col8" >0.40<span class="pd-t"></span></td>
#       <td id="T_304c2_row0_col9" class="data row0 col9" >0<span class="pd-t"></span></td>
#     </tr>
#     <tr>
#       <th id="T_304c2_level0_row1" class="row_heading level0 row1" >86445</th>
#       <td id="T_304c2_row1_col0" clas
