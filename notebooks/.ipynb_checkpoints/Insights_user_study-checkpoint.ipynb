# %%
import pandas as pd
from Random_baselines.random_util import generate_random_summary, color_random_summary
from Naive_clustering.nc_utils import gen_nc_summary
from SubTab import subTab

path_sample_df =  'input/spotify_dataset.csv'
rules_path = 'rules/0_8sup_1list_rules.csv'
full_df_a = pd.read_csv(path_sample_df)
if 'Unnamed: 0' in full_df_a.columns:
    full_df_a.drop(['Unnamed: 0'], axis=1, inplace=True)
if 'Unnamed: 0.1' in full_df_a.columns:
    full_df_a.drop([ 'Unnamed: 0.1'], axis=1, inplace=True)
if 'index' in full_df_a.columns:
    full_df_a.drop([ 'index'], axis=1, inplace=True)
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
num_cols_and_rows = 10 
pd.set_option("display.max_columns", num_cols_and_rows)
pd.set_option("display.max_rows", num_cols_and_rows)

# %% [markdown]
# # In this Session we would like to learn what are the features that are relevant to the popularity of a song in Spotify

# %% [markdown]
# ## Initial exploration - How our dataset looks like?

# %%
full_df_a
# Out:
#         acousticness                                   artists  danceability  \
# 0             0.9950                       ['Carl Woitschach']         0.708
# 1             0.9940  ['Robert Schumann', 'Vladimir Horowitz']         0.379
# 2             0.6040                   ['Seweryn Goszczyński']         0.749
# 3             0.9950                      ['Francisco Canaro']         0.781
# 4             0.9900  ['Frédéric Chopin', 'Vladimir Horowitz']         0.210
# ...              ...                                       ...           ...
# 169904        0.1730                    ['DripReport', 'Tyga']         0.875
# 169905        0.0167        ['Leon Bridges', 'Terrace Martin']         0.719
# 169906        0.5380                     ['Kygo', 'Oh Wonder']         0.514
# 169907        0.0714             ['Cash Cash', 'Andy Grammer']         0.646
# 169908        0.1090                        ['Ingrid Andress']         0.512
#
#         duration_ms  energy  ...  release_date speechiness    tempo  valence  \
# 0            158648  0.1950  ...          1928      0.0506  118.469   0.7790
# 1            282133  0.0135  ...          1928      0.0462   83.972   0.0767
# 2            104300  0.2200  ...          1928      0.9290  107.177   0.8800
# 3            180760  0.1300  ...    1928-09-25      0.0926  108.003   0.7200
# 4            687733  0.2040  ...          1928      0.0424   62.149   0.0693
# ...             ...     ...  ...           ...         ...      ...      ...
# 169904       163800  0.4430  ...    2020-05-15      0.1430  100.012   0.3060
# 169905       167468  0.3850  ...    2020-06-08      0.0403  128.000   0.2700
# 169906       180700  0.5390  ...    2020-05-29      0.1050  123.700   0.1530
# 169907       167308  0.7610  ...    2020-02-28      0.0385  129.916   0.4720
# 169908       214787  0.4280  ...    2020-03-27      0.0271   80.588   0.3660
#
#         year
# 0       1928
# 1       1928
# 2       1928
# 3       1928
# 4       1928
# ...      ...
# 169904  2020
# 169905  2020
# 169906  2020
# 169907  2020
# 169908  2020
#
# [169909 rows x 19 columns]

# %%
rand_df = generate_random_summary(full_df_a, num_cols=num_cols_and_rows, num_rows=num_cols_and_rows)
rand_df
# Out:
#         loudness  duration_ms  \
# 79184    -15.915       184907
# 105060    -5.190       261133
# 44467    -11.944       303800
# 135130    -6.519       160097
# 63736    -14.133       291333
# 55511     -7.466       162400
# 147183   -12.045       117773
# 74218     -3.634       194480
# 143961   -10.263       115000
# 24260     -8.582       152869
#
#                                                      name  acousticness  mode  \
# 79184            Something's Gotta Give - Daddy Long Legs       0.92500     0
# 105060                                      Mary-Go-Round       0.21500     0
# 44467                                   Sign of the Times       0.00914     1
# 135130                                            Ophelia       0.61300     1
# 63736   Verdi : Il trovatore : Part 2 - La Gitana "Con...       0.96800     1
# 55511              Mannequin Challenge (feat. Juice WRLD)       0.08990     0
# 147183                Main Title (Love Theme from Lolita)       0.97300     0
# 74218                               Violence In Our Minds       0.53700     1
# 143961                                            Edition       0.80700     1
# 24260                               Como Si Fuera un Niño       0.99500     0
#
#         instrumentalness                                            artists  \
# 79184           0.000070                                   ['Fred Astaire']
# 105060          0.000000                             ['South Park Mexican']
# 44467           0.001370                                     ['Quiet Riot']
# 135130          0.000363                                  ['The Lumineers']
# 63736           0.000000  ['Giuseppe Verdi', 'Fernando Previtali', 'Orch...
# 55511           0.000000                       ['Young Thug', 'Juice WRLD']
# 147183          0.923000                                  ['Nelson Riddle']
# 74218           0.001320                                ['The Last Resort']
# 143961          0.000000                              ['Rex Orange County']
# 24260           0.000000                ['Margarita Cueto', 'Carlos Mejía']
#
#         key  energy  explicit
# 79184     7   0.176         0
# 105060    4   0.655         1
# 44467     4   0.745         0
# 135130    5   0.573         0
# 63736     4   0.142         0
# 55511     1   0.583         1
# 147183    4   0.244         0
# 74218     2   0.948         0
# 143961    1   0.332         1
# 24260    11   0.338         0

# %%
nc_df = gen_nc_summary(full_df_a, num_cols_and_rows, num_cols_and_rows)
nc_df
# Out:
#         danceability  duration_ms      id    name  artists  release_date  \
# 12819          0.689       182293  121636   32907    15277          4273
# 86816          0.760       270307   42298   65396    16167          7932
# 40978          0.654       657093   81178   70767     6010           483
# 59359          0.606      1269520   90919   80264     9312          3491
# 33112          0.560       109280   73100   78830    17411           483
# 164596         0.655       186467   34234   61601    15114          1749
# 132048         0.715       286827  130640   69111    17710          4349
# 148313         0.621       191027  122349  105302    17281          2685
# 32742          0.423      2819985  155870   38436    30971           403
# 73116          0.444       423625   80273   72003    14316          2212
#
#         year    tempo  popularity  loudness
# 12819   1986  177.745          31   -15.878
# 86816   2008  119.603          67    -7.670
# 40978   1949   90.712           0   -19.801
# 59359   1981  128.804          20    -5.871
# 33112   1949   59.924           0   -10.456
# 164596  1967   87.167          27    -9.782
# 132048  1986  104.419          38   -14.752
# 148313  1974   81.231          47    -6.770
# 32742   1946  111.337           0   -11.066
# 73116   1971   82.182          19   -11.587

# %%
sdf = subTab(full_df_a,use_rules=True)
# Out:
# print no rules were provided

# %%
sdf.display(full_df_a)
# Out:
# for or summary creation, it took 0:00:13.536538
#         loudness  instrumentalness  year  energy  popularity  acousticness  \
# 142390     -6.62              0.00  2001    0.68          48          0.15
# 117967    -21.05              0.16  1938    0.13           0          0.96
# 135316     -4.06              0.00  2018    0.81          78          0.19
# 72953     -18.31              0.95  1969    0.13          19          0.97
# 49400      -7.04              0.00  1958    0.65          12          0.67
# 24871     -21.92              0.00  1947    0.21           0          0.81
# 32166      -5.46              0.00  2020    0.72          65          0.04
# 113036     -5.54              0.01  1983    0.94          44          0.01
# 154388     -9.39              0.29  1949    0.26           0          0.99
# 122026    -14.02              0.00  1979    0.41          38          0.19
#
#         liveness  danceability  valence  speechiness
# 142390      0.08          0.62     0.34         0.03
# 117967      0.14          0.28     0.17         0.03
# 135316      0.16          0.65     0.55         0.05
# 72953       0.10          0.06     0.04         0.04
# 49400       0.30          0.46     0.89         0.04
# 24871       0.13          0.73     0.56         0.92
# 32166       0.12          0.95     0.76         0.19
# 113036      0.36          0.58     0.68         0.06
# 154388      0.18          0.50     0.47         0.06
# 122026      0.08          0.76     0.78         0.04

# %% [markdown]
# # does coloring association rules helps?
# lets go back to the previous subtables, now with highlighting the rules that are represented there:

# %%
rules = pd.read_csv(rules_path)

# %%
color_random_summary(rand_df, rules, sdf.mapping_bins_to_values, full_df_a)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 48/48 [00:04<00:00, 11.91it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 445.67it/s]
# <style type="text/css">
# #T_a6964 .pd-t {
#   visibility: hidden;
#   position: absolute;
#   z-index: 1;
#   background-color: black;
#   color: white;
#   transform: translate(-20px, -20px);
# }
# #T_a6964 #T_a6964_row0_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_a6964 #T_a6964_row0_col3 .pd-t::after {
#   content: "Rule #145: {(energy = (-0.1, 0.2]),(explicit = 0),} ---> {(acousticness = acousticness_4),}, support=0.12, confidence = 0.62, lift = 3.12";
# }
# #T_a6964 #T_a6964_row0_col8:hover .pd-t {
#   visibility: visible;
# }
# #T_a6964 #T_a6964_row0_col8 .pd-t::after {
#   content: "Rule #145: {(energy = (-0.1, 0.2]),(explicit = 0),} ---> {(acousticness = acousticness_4),}, support=0.12, confidence = 0.62, lift = 3.12";
# }
# #T_a6964 #T_a6964_row0_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_a6964 #T_a6964_row0_col9 .pd-t::after {
#   content: "Rule #145: {(energy = (-0.1, 0.2]),(explicit = 0),} ---> {(acousticness = acousticness_4),}, support=0.12, confidence = 0.62, lift = 3.12";
# }
# #T_a6964 #T_a6964_row2_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_a6964 #T_a6964_row2_col1 .pd-t::after {
#   content: "Rule #170: {(duration_ms = (279908.0, 5403500.0]),(mode = 1),} ---> {(explicit = 0),}, support=0.12, confidence = 0.94, lift = 1.03";
# }
# #T_a6964 #T_a6964_row2_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_a6964 #T_a6964_row2_col4 .pd-t::after {
#   content: "Rule #170: {(duration_ms = (279908.0, 5403500.0]),(mode = 1),} ---> {(explicit = 0),}, support=0.12, confidence = 0.94, lift = 1.03";
# }
# #T_a6964 #T_a6964_row2_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_a6964 #T_a6964_row2_col9 .pd-t::after {
#   content: "Rule #170: {(duration_ms = (279908.0, 5403500.0]),(mode = 1),} ---> {(explicit = 0),}, support=0.12, confidence = 0.94, lift = 1.03";
# }
# #T_a6964 #T_a6964_row3_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_a6964 #T_a6964_row3_col4 .pd-t::after {
#   content: "Rule #182: {(energy = (0.4, 0.6]),(mode = 1),} ---> {(explicit = 0),}, support=0.14, confidence = 0.94, lift = 1.02";
# }
# #T_a6964 #T_a6964_row3_col8:hover .pd-t {
#   visibility: visible;
# }
# #T_a6964 #T_a6964_row3_col8 .pd-t::after {
#   content: "Rule #182: {(energy = (0.4, 0.6]),(mode = 1),} ---> {(explicit = 0),}, support=0.14, confidence = 0.94, lift = 1.02";
# }
# #T_a6964 #T_a6964_row3_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_a6964 #T_a6964_row3_col9 .pd-t::after {
#   content: "Rule #182: {(energy = (0.4, 0.6]),(mode = 1),} ---> {(explicit = 0),}, support=0.14, confidence = 0.94, lift = 1.02";
# }
# #T_a6964 #T_a6964_row4_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_a6964 #T_a6964_row4_col3 .pd-t::after {
#   content: "Rule #263: {(acousticness = (0.9, 1.0]),(explicit = 0),(mode = 1),} ---> {(energy = energy_0),}, support=0.08, confidence = 0.6, lift = 3.01";
# }
# #T_a6964 #T_a6964_row4_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_a6964 #T_a6964_row4_col4 .pd-t::after {
#   content: "Rule #263: {(acousticness = (0.9, 1.0]),(explicit = 0),(mode = 1),} ---> {(energy = energy_0),}, support=0.08, confidence = 0.6, lift = 3.01";
# }
# #T_a6964 #T_a6964_row4_col8:hover .pd-t {
#   visibility: visible;
# }
# #T_a6964 #T_a6964_row4_col8 .pd-t::after {
#   content: "Rule #263: {(acousticness = (0.9, 1.0]),(explicit = 0),(mode = 1),} ---> {(energy = energy_0),}, support=0.08, confidence = 0.6, lift = 3.01";
# }
# #T_a6964 #T_a6964_row4_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_a6964 #T_a6964_row4_col9 .pd-t::after {
#   content: "Rule #263: {(acousticness = (0.9, 1.0]),(explicit = 0),(mode = 1),} ---> {(energy = energy_0),}, support=0.08, confidence = 0.6, lift = 3.01";
# }
# #T_a6964 #T_a6964_row6_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_a6964 #T_a6964_row6_col3 .pd-t::after {
#   content: "Rule #149: {(acousticness = (0.9, 1.0]),(instrumentalness = (0.3, 1.0]),} ---> {(explicit = 0),}, support=0.1, confidence = 1.0, lift = 1.09";
# }
# #T_a6964 #T_a6964_row6_col5:hover .pd-t {
#   visibility: visible;
# }
# #T_a6964 #T_a6964_row6_col5 .pd-t::after {
#   content: "Rule #149: {(acousticness = (0.9, 1.0]),(instrumentalness = (0.3, 1.0]),} ---> {(explicit = 0),}, support=0.1, confidence = 1.0, lift = 1.09";
# }
# #T_a6964 #T_a6964_row6_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_a6964 #T_a6964_row6_col9 .pd-t::after {
#   content: "Rule #149: {(acousticness = (0.9, 1.0]),(instrumentalness = (0.3, 1.0]),} ---> {(explicit = 0),}, support=0.1, confidence = 1.0, lift = 1.09";
# }
# #T_a6964 #T_a6964_row7_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_a6964 #T_a6964_row7_col3 .pd-t::after {
#   content: "Rule #141: {(acousticness = (0.3, 0.7]),(mode = 1),} ---> {(explicit = 0),}, support=0.14, confidence = 0.95, lift = 1.04";
# }
# #T_a6964 #T_a6964_row7_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_a6964 #T_a6964_row7_col4 .pd-t::after {
#   content: "Rule #141: {(acousticness = (0.3, 0.7]),(mode = 1),} ---> {(explicit = 0),}, support=0.14, confidence = 0.95, lift = 1.04";
# }
# #T_a6964 #T_a6964_row7_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_a6964 #T_a6964_row7_col9 .pd-t::after {
#   content: "Rule #141: {(acousticness = (0.3, 0.7]),(mode = 1),} ---> {(explicit = 0),}, support=0.14, confidence = 0.95, lift = 1.04";
# }
# #T_a6964 #T_a6964_row8_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_a6964 #T_a6964_row8_col3 .pd-t::after {
#   content: "Rule #7: {(acousticness = (0.7, 0.9]),} ---> {(mode = 1),}, support=0.15, confidence = 0.75, lift = 1.05";
# }
# #T_a6964 #T_a6964_row8_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_a6964 #T_a6964_row8_col4 .pd-t::after {
#   content: "Rule #7: {(acousticness = (0.7, 0.9]),} ---> {(mode = 1),}, support=0.15, confidence = 0.75, lift = 1.05";
# }
# #T_a6964 #T_a6964_row9_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_a6964 #T_a6964_row9_col3 .pd-t::after {
#   content: "Rule #8: {(acousticness = (0.9, 1.0]),} ---> {(explicit = 0),}, support=0.2, confidence = 1.0, lift = 1.09";
# }
# #T_a6964 #T_a6964_row9_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_a6964 #T_a6964_row9_col9 .pd-t::after {
#   content: "Rule #8: {(acousticness = (0.9, 1.0]),} ---> {(explicit = 0),}, support=0.2, confidence = 1.0, lift = 1.09";
# }
# #T_a6964_row0_col3, #T_a6964_row0_col8, #T_a6964_row0_col9 {
#   background-color: lightblue;
# }
# #T_a6964_row2_col1, #T_a6964_row2_col4, #T_a6964_row2_col9 {
#   background-color: gray;
# }
# #T_a6964_row3_col4, #T_a6964_row3_col8, #T_a6964_row3_col9 {
#   background-color: blue;
# }
# #T_a6964_row4_col3, #T_a6964_row4_col4, #T_a6964_row4_col8, #T_a6964_row4_col9 {
#   background-color: pink;
# }
# #T_a6964_row6_col3, #T_a6964_row6_col5, #T_a6964_row6_col9 {
#   background-color: red;
# }
# #T_a6964_row7_col3, #T_a6964_row7_col4, #T_a6964_row7_col9 {
#   background-color: green;
# }
# #T_a6964_row8_col3, #T_a6964_row8_col4 {
#   background-color: orange;
# }
# #T_a6964_row9_col3, #T_a6964_row9_col9 {
#   background-color: yellow;
# }
# </style>
# <table id="T_a6964">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a6964_level0_col0" class="col_heading level0 col0" >loudness</th>
#       <th id="T_a6964_level0_col1" class="col_heading level0 col1" >duration_ms</th>
#       <th id="T_a6964_level0_col2" class="col_heading level0 col2" >name</th>
#       <th id="T_a6964_level0_col3" class="col_heading level0 col3" >acousticness</th>
#       <th id="T_a6964_level0_col4" class="col_heading level0 col4" >mode</th>
#       <th id="T_a6964_level0_col5" class="col_heading level0 col5" >instrumentalness</th>
#       <th id="T_a6964_level0_col6" class="col_heading level0 col6" >artists</th>
#       <th id="T_a6964_level0_col7" class="col_heading level0 col7" >key</th>
#       <th id="T_a6964_level0_col8" class="col_heading level0 col8" >energy</th>
#       <th id="T_a6964_level0_col9" class="col_heading level0 col9" >explicit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a6964_level0_row0" class="row_heading level0 row0" >79184</th>
#       <td id="T_a6964_row0_col0" class="data row0 col0" >-15.92<span class="pd-t"></span></td>
#       <td id="T_a6964_row0_col1" class="data row0 col1" >184907<span class="pd-t"></span></td>
#       <td id="T_a6964_row0_col2" class="data row0 col2" >Someth

# %%
color_random_summary(nc_df, rules, sdf.mapping_bins_to_values, full_df_a)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 18.41it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 455.56it/s]
# <style type="text/css">
# #T_e1483 .pd-t {
#   visibility: hidden;
#   position: absolute;
#   z-index: 1;
#   background-color: black;
#   color: white;
#   transform: translate(-20px, -20px);
# }
# #T_e1483 #T_e1483_row1_col6:hover .pd-t {
#   visibility: visible;
# }
# #T_e1483 #T_e1483_row1_col6 .pd-t::after {
#   content: "Rule #136: {(year = (2003.0, 2020.0]),} ---> {(popularity = popularity_4),}, support=0.13, confidence = 0.65, lift = 3.32";
# }
# #T_e1483 #T_e1483_row1_col8:hover .pd-t {
#   visibility: visible;
# }
# #T_e1483 #T_e1483_row1_col8 .pd-t::after {
#   content: "Rule #136: {(year = (2003.0, 2020.0]),} ---> {(popularity = popularity_4),}, support=0.13, confidence = 0.65, lift = 3.32";
# }
# #T_e1483 #T_e1483_row2_col6:hover .pd-t {
#   visibility: visible;
# }
# #T_e1483 #T_e1483_row2_col6 .pd-t::after {
#   content: "Rule #133: {(year = (1920.0, 1952.0]),} ---> {(popularity = popularity_0),}, support=0.18, confidence = 0.88, lift = 4.37";
# }
# #T_e1483 #T_e1483_row2_col8:hover .pd-t {
#   visibility: visible;
# }
# #T_e1483 #T_e1483_row2_col8 .pd-t::after {
#   content: "Rule #133: {(year = (1920.0, 1952.0]),} ---> {(popularity = popularity_0),}, support=0.18, confidence = 0.88, lift = 4.37";
# }
# #T_e1483 #T_e1483_row4_col6:hover .pd-t {
#   visibility: visible;
# }
# #T_e1483 #T_e1483_row4_col6 .pd-t::after {
#   content: "Rule #134: {(popularity = (-1.0, 5.0]),} ---> {(year = year_0),}, support=0.18, confidence = 0.88, lift = 4.37";
# }
# #T_e1483 #T_e1483_row4_col8:hover .pd-t {
#   visibility: visible;
# }
# #T_e1483 #T_e1483_row4_col8 .pd-t::after {
#   content: "Rule #134: {(popularity = (-1.0, 5.0]),} ---> {(year = year_0),}, support=0.18, confidence = 0.88, lift = 4.37";
# }
# #T_e1483 #T_e1483_row5_col6:hover .pd-t {
#   visibility: visible;
# }
# #T_e1483 #T_e1483_row5_col6 .pd-t::after {
#   content: "Rule #135: {(year = (1952.0, 1969.0]),} ---> {(popularity = popularity_1),}, support=0.12, confidence = 0.63, lift = 3.07";
# }
# #T_e1483 #T_e1483_row5_col8:hover .pd-t {
#   visibility: visible;
# }
# #T_e1483 #T_e1483_row5_col8 .pd-t::after {
#   content: "Rule #135: {(year = (1952.0, 1969.0]),} ---> {(popularity = popularity_1),}, support=0.12, confidence = 0.63, lift = 3.07";
# }
# #T_e1483_row1_col6, #T_e1483_row1_col8 {
#   background-color: darkgrey;
# }
# #T_e1483_row2_col6, #T_e1483_row2_col8 {
#   background-color: gray;
# }
# #T_e1483_row4_col6, #T_e1483_row4_col8 {
#   background-color: lightblue;
# }
# #T_e1483_row5_col6, #T_e1483_row5_col8 {
#   background-color: orange;
# }
# </style>
# <table id="T_e1483">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e1483_level0_col0" class="col_heading level0 col0" >danceability</th>
#       <th id="T_e1483_level0_col1" class="col_heading level0 col1" >duration_ms</th>
#       <th id="T_e1483_level0_col2" class="col_heading level0 col2" >id</th>
#       <th id="T_e1483_level0_col3" class="col_heading level0 col3" >name</th>
#       <th id="T_e1483_level0_col4" class="col_heading level0 col4" >artists</th>
#       <th id="T_e1483_level0_col5" class="col_heading level0 col5" >release_date</th>
#       <th id="T_e1483_level0_col6" class="col_heading level0 col6" >year</th>
#       <th id="T_e1483_level0_col7" class="col_heading level0 col7" >tempo</th>
#       <th id="T_e1483_level0_col8" class="col_heading level0 col8" >popularity</th>
#       <th id="T_e1483_level0_col9" class="col_heading level0 col9" >loudness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e1483_level0_row0" class="row_heading level0 row0" >12819</th>
#       <td id="T_e1483_row0_col0" class="data row0 col0" >0.69<span class="pd-t"></span></td>
#       <td id="T_e1483_row0_col1" class="data row0 col1" >182293<span class="pd-t"></span></td>
#       <td id="T_e1483_row0_col2" class="data row0 col2" >121636<span class="pd-t"></span></td>
#       <td id="T_e1483_row0_col3" class="data row0 col3" >32907<span class="pd-t"></span></td>
#       <td id="T_e1483_row0_col4" class="data row0 col4" >15277<span class="pd-t"></span></td>
#       <td id="T_e1483_row0_col5" class="data row0 col5" >4273<span class="pd-t"></span></td>
#       <td id="T_e1483_row0_col6" class="data row0 col6" >1986<span class="pd-t"></span></td>
#       <td id="T_e1483_row0_col7" class="data row0 col7" >177.74<span class="pd-t"></span></td>
#       <td id="T_e1483_row0_col8" class="data row0 col8" >31<span class="pd-t"></span></td>
#       <td id="T_e1483_row0_col9" class="data row0 col9" >-15.88<span class="pd-t"></span></td>
#     </tr>
#     <tr>
#       <th id="T_e1483_level0_row1" class="row_heading level0 row1" >86816</th>
#       <td id="T_e1483_row1_col0" class="data row1 col0" >0.76<span class="pd-t"></span></td>
#       <td id="T_e1483_row1_col1" class="data row1 col1" >270307<span class="pd-t"></span></td>
#       <td id="T_e1483_row1_col2" class="data row1 col2" >42298<span class="pd-t"></span></td>
#       <td id="T_e1483_row1_col3" class="data row1 col3" >65396<span class="pd-t"></span></td>
#       <td id="T_e1483_row1_col4" class="data row1 col4" >16167<span class="pd-t"></span></td>
#       <td id="T_e1483_row1_col5" class="data row1 col5" >7932<span class="pd-t"></span></td>
#       <td id="T_e1483_row1_col6" class="data row1 col6" >2008<span class="pd-t"></span></td>
#       <td id="T_e1483_row1_col7" class="data row1 col7" >119.60<span class="pd-t"></span></td>
#       <td id="T_e1483_row1_col8" class="data row1 col8" >67<span class="pd-t"></span></td>
#       <td id="T_e1483_row1_col9" class="data row1 col9" >-7.67<span class="pd-t"></span></td>
#     </tr>
#     <tr>
#       <th id="T_e1483_level0_row2" class="row_heading level0 row2" >40978</th>
#       <td id="T_e1483_row2_col0" class="data row2 col0" >0.65<span class="pd-t"></span></td>
#       <td id="T_e1483_row2_col1" class="data row2 col1" >657093<span class="pd-t"></span></td>
#       <td id="T_e1483_row2_col2" class="data row2 col2" >81178<span class="pd-t"></span></td>
#       <td id="T_e1483_row2_col3" class="data row2 col3" >70767<span class="pd-t"></span></td>
#       <td id="T_e1483_row2_col4" class="data row2 col4" >6010<span class="pd-t"></span></td>
#       <td id="T_e1483_row2_col5" class="data row2 col5" >483<span class="pd-t"></span></td>
#       <td id="T_e1483_row2_col6" class="data row2 col6" >1949<span class="pd-t"></span></td>
#       <td id="T_e1483_row2_col7" class="data row2 col7" >90.71<span class="pd-t"></span></td>
#       <td id="T_e1483_row2_col8" class="data row2 col8" >0<span class="pd-t"></span></td>
#       <td id="T_e1483_row2_col9" class="data row2 col9" >-19.80<span class="pd-t"></span></td>
#     </tr>
#     <tr>
#       <th id="T_e1483_level0_row3" class="row_heading level0 row3" >59359</th>
#       <td id="T_e1483_row3_col0" class="data row3 col0" >0.61<span class="pd-t"></span></td>
#       <td id="T_e1483_row3_col1" class="data row3 col1" >1269520<span class="pd-t"></span></td>
#       <td id="T_e1483_row3_col2" class="data row3 col2" >90919<span class="pd-t"></span></td>
#       <td id="T_e1483_row3_col3" class="data row3 col3" >80264<span class="pd-t"></span></td>
#       <td id="T_e1483_row3_col4" class="data row3 col4" >9312<span class="pd-t"></span></td>
#       <td id="T_e1483_row3_col5" class="data row3 col5" >3491<span class="pd-t"></span></td>
#       <td id="T_e1483_row3_col6" class="data row3 col6" >1981<span class="pd-t"></span></td>
#       <td id="T_e1483_row3_col7" class="data row3 col7" >128.80<span class="pd-t"></span></td>
#       <td id="T_e1483_row3_col8" class="data row3 col8" >20<span class="pd-t"></span></td>
#       <td id="T_e1483_row3_col9" class="data row3 col9" >-5.87<span class="pd-t"></span></td>
#     </tr>
#     <tr>
#       <th id="T_e1483_level0_row4" class="row_heading level0 row4" >33112</th>
#       <td id="T_e1483_row4_col0" class="data row4 col0" >0.56<span class="pd-t"></span></td>
#       <td id="T_e1483_row4_col1" class="data row4 col1" >109280<span class="pd-t"></span></td>
#       <td id="T_e1483_row4_col2" class="data row4 col2" >73100<span class="pd-t"></span></td>
#       <td id="T_e1483_row4_col3" class="data row4 col3" >78830<span class="pd-t"></span></td>
#       <td id="T_e1483_row4_col4

# %%
sdf = subTab(full_df_a,use_rules=True, subtab_config={'rules':'rules/0_8sup_1list_rules.csv'})

# %%
sdf.display(full_df_a)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 14/14 [00:01<00:00, 11.91it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 392.29it/s]
# for or summary creation, it took 0:00:21.758688
# <style type="text/css">
# #T_5222a .pd-t {
#   visibility: hidden;
#   position: absolute;
#   z-index: 1;
#   background-color: black;
#   color: white;
#   transform: translate(-20px, -20px);
# }
# #T_5222a #T_5222a_row0_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_5222a #T_5222a_row0_col1 .pd-t::after {
#   content: "Rule #88: {(energy = (-0.1, 0.2]),(loudness = (-61.0, -16.0]),} ---> {(acousticness = acousticness_4),}, support=0.09, confidence = 0.61, lift = 3.06";
# }
# #T_5222a #T_5222a_row0_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_5222a #T_5222a_row0_col3 .pd-t::after {
#   content: "Rule #88: {(energy = (-0.1, 0.2]),(loudness = (-61.0, -16.0]),} ---> {(acousticness = acousticness_4),}, support=0.09, confidence = 0.61, lift = 3.06";
# }
# #T_5222a #T_5222a_row0_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_5222a #T_5222a_row0_col4 .pd-t::after {
#   content: "Rule #88: {(energy = (-0.1, 0.2]),(loudness = (-61.0, -16.0]),} ---> {(acousticness = acousticness_4),}, support=0.09, confidence = 0.61, lift = 3.06";
# }
# #T_5222a #T_5222a_row1_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_5222a #T_5222a_row1_col1 .pd-t::after {
#   content: "Rule #26: {(loudness = (-6.0, 4.0]),} ---> {(energy = energy_4),}, support=0.12, confidence = 0.62, lift = 3.09";
# }
# #T_5222a #T_5222a_row1_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_5222a #T_5222a_row1_col3 .pd-t::after {
#   content: "Rule #26: {(loudness = (-6.0, 4.0]),} ---> {(energy = energy_4),}, support=0.12, confidence = 0.62, lift = 3.09";
# }
# #T_5222a #T_5222a_row2_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_5222a #T_5222a_row2_col2 .pd-t::after {
#   content: "Rule #170: {(popularity = (51.0, 100.0]),(year = (2003.0, 2020.0]),} ---> {(instrumentalness = instrumentalness_0),}, support=0.08, confidence = 0.64, lift = 1.59";
# }
# #T_5222a #T_5222a_row2_col5:hover .pd-t {
#   visibility: visible;
# }
# #T_5222a #T_5222a_row2_col5 .pd-t::after {
#   content: "Rule #170: {(popularity = (51.0, 100.0]),(year = (2003.0, 2020.0]),} ---> {(instrumentalness = instrumentalness_0),}, support=0.08, confidence = 0.64, lift = 1.59";
# }
# #T_5222a #T_5222a_row2_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_5222a #T_5222a_row2_col9 .pd-t::after {
#   content: "Rule #170: {(popularity = (51.0, 100.0]),(year = (2003.0, 2020.0]),} ---> {(instrumentalness = instrumentalness_0),}, support=0.08, confidence = 0.64, lift = 1.59";
# }
# #T_5222a #T_5222a_row3_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_5222a #T_5222a_row3_col1 .pd-t::after {
#   content: "Rule #20: {(loudness = (-61.0, -16.0]),} ---> {(energy = energy_0),}, support=0.14, confidence = 0.72, lift = 3.59";
# }
# #T_5222a #T_5222a_row3_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_5222a #T_5222a_row3_col3 .pd-t::after {
#   content: "Rule #20: {(loudness = (-61.0, -16.0]),} ---> {(energy = energy_0),}, support=0.14, confidence = 0.72, lift = 3.59";
# }
# #T_5222a #T_5222a_row4_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_5222a #T_5222a_row4_col2 .pd-t::after {
#   content: "Rule #115: {(energy = (-0.1, 0.2]),(year = (1920.0, 1952.0]),} ---> {(popularity = popularity_0),}, support=0.08, confidence = 0.88, lift = 4.39";
# }
# #T_5222a #T_5222a_row4_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_5222a #T_5222a_row4_col3 .pd-t::after {
#   content: "Rule #115: {(energy = (-0.1, 0.2]),(year = (1920.0, 1952.0]),} ---> {(popularity = popularity_0),}, support=0.08, confidence = 0.88, lift = 4.39";
# }
# #T_5222a #T_5222a_row4_col5:hover .pd-t {
#   visibility: visible;
# }
# #T_5222a #T_5222a_row4_col5 .pd-t::after {
#   content: "Rule #115: {(energy = (-0.1, 0.2]),(year = (1920.0, 1952.0]),} ---> {(popularity = popularity_0),}, support=0.08, confidence = 0.88, lift = 4.39";
# }
# #T_5222a #T_5222a_row7_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_5222a #T_5222a_row7_col2 .pd-t::after {
#   content: "Rule #99: {(popularity = (-1.0, 5.0]),(year = (1920.0, 1952.0]),} ---> {(acousticness = acousticness_4),}, support=0.12, confidence = 0.67, lift = 3.41";
# }
# #T_5222a #T_5222a_row7_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_5222a #T_5222a_row7_col4 .pd-t::after {
#   content: "Rule #99: {(popularity = (-1.0, 5.0]),(year = (1920.0, 1952.0]),} ---> {(acousticness = acousticness_4),}, support=0.12, confidence = 0.67, lift = 3.41";
# }
# #T_5222a #T_5222a_row7_col5:hover .pd-t {
#   visibility: visible;
# }
# #T_5222a #T_5222a_row7_col5 .pd-t::after {
#   content: "Rule #99: {(popularity = (-1.0, 5.0]),(year = (1920.0, 1952.0]),} ---> {(acousticness = acousticness_4),}, support=0.12, confidence = 0.67, lift = 3.41";
# }
# #T_5222a #T_5222a_row8_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_5222a #T_5222a_row8_col2 .pd-t::after {
#   content: "Rule #80: {(year = (1952.0, 1969.0]),} ---> {(popularity = popularity_1),}, support=0.12, confidence = 0.63, lift = 3.07";
# }
# #T_5222a #T_5222a_row8_col5:hover .pd-t {
#   visibility: visible;
# }
# #T_5222a #T_5222a_row8_col5 .pd-t::after {
#   content: "Rule #80: {(year = (1952.0, 1969.0]),} ---> {(popularity = popularity_1),}, support=0.12, confidence = 0.63, lift = 3.07";
# }
# #T_5222a #T_5222a_row9_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_5222a #T_5222a_row9_col2 .pd-t::after {
#   content: "Rule #58: {(year = (2003.0, 2020.0]),} ---> {(instrumentalness = instrumentalness_0),}, support=0.12, confidence = 0.61, lift = 1.52";
# }
# #T_5222a #T_5222a_row9_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_5222a #T_5222a_row9_col9 .pd-t::after {
#   content: "Rule #58: {(year = (2003.0, 2020.0]),} ---> {(instrumentalness = instrumentalness_0),}, support=0.12, confidence = 0.61, lift = 1.52";
# }
# #T_5222a_row0_col1, #T_5222a_row0_col3, #T_5222a_row0_col4 {
#   background-color: gray;
# }
# #T_5222a_row1_col1, #T_5222a_row1_col3 {
#   background-color: blue;
# }
# #T_5222a_row2_col2, #T_5222a_row2_col5, #T_5222a_row2_col9 {
#   background-color: red;
# }
# #T_5222a_row3_col1, #T_5222a_row3_col3 {
#   background-color: darkgrey;
# }
# #T_5222a_row4_col2, #T_5222a_row4_col3, #T_5222a_row4_col5 {
#   background-color: yellow;
# }
# #T_5222a_row7_col2, #T_5222a_row7_col4, #T_5222a_row7_col5 {
#   background-color: pink;
# }
# #T_5222a_row8_col2, #T_5222a_row8_col5 {
#   background-color: purple;
# }
# #T_5222a_row9_col2, #T_5222a_row9_col9 {
#   background-color: orange;
# }
# </style>
# <table id="T_5222a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5222a_level0_col0" class="col_heading level0 col0" >key</th>
#       <th id="T_5222a_level0_col1" class="col_heading level0 col1" >loudness</th>
#       <th id="T_5222a_level0_col2" class="col_heading level0 col2" >year</th>
#       <th id="T_5222a_level0_col3" class="col_heading level0 col3" >energy</th>
#       <th id="T_5222a_level0_col4" class="col_heading level0 col4" >acousticness</th>
#       <th id="T_5222a_level0_col5" class="col_heading level0 col5" >popularity</th>
#       <th id="T_5222a_level0_col6" class="col_heading level0 col6" >danceability</th>
#       <th id="T_5222a_level0_col7" class="col_heading level0 col7" >speechiness</th>
#       <th id="T_5222a_level0_col8" class="col_heading level0 col8" >valence</th>
#       <th id="T_5222a_level0_col9" class="col_heading level0 col9" >instrumentalness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5222a_level0_row0" class="row_heading level0 row0" >154085</th>
#       <td id="T_5222a_row0_col0" class="data row0 col0" >8<span class="pd-t"></span></td>
#       <td id="T_5222a_row0_col1" class="data row0 col1" >-16.79<span class="pd-t"></span></td>
#       <td id="T_5222a_row0_col2" class="data row0 col2" >1946<span class="pd-t"></span></td>
#       <td id="T_5222a_row0_col3" class="data row0 col3" >0.11<span class="pd-t"></span></td>
#       <td id="T_5222a_row0_col4" class="data row0 col4" >1.00<span class="pd-t"></span></td>
#       <td id="T_5222a_row0_col5" class="data row0 col5" >0<span class="pd-t"></span></td>
#       <td id="T_5222a_row0_col6" class="data row0 col6" >0.46<span class="pd-t"></span></td>
#       <td id="T_5222a_row0_col7" class="data row0 col7" >0.05<span class="pd-t"></span></td>
#       <td id="T_5222a_row0_col8" class="data row0 col8" >0.38<span class="pd-t"></s

# %% [markdown]
# ## What cause a song to be very popular (above 55) ?

# %%
df1 = full_df_a[full_df_a['popularity']>55]

# %%
df1
# Out:
#         acousticness                                      artists  \
# 3366          0.7280                              ['Mia Martini']
# 4192          0.0414                         ['Australian Crawl']
# 4558          0.7240                               ['Roupa Nova']
# 4561          0.3200                            ['Legião Urbana']
# 4617          0.0506  ['Patricio Rey y sus Redonditos de Ricota']
# ...              ...                                          ...
# 169904        0.1730                       ['DripReport', 'Tyga']
# 169905        0.0167           ['Leon Bridges', 'Terrace Martin']
# 169906        0.5380                        ['Kygo', 'Oh Wonder']
# 169907        0.0714                ['Cash Cash', 'Andy Grammer']
# 169908        0.1090                           ['Ingrid Andress']
#
#         danceability  duration_ms  energy  ...  release_date speechiness  \
# 3366           0.248       283893   0.483  ...    1973-06-23      0.0678
# 4192           0.613       210720   0.772  ...    1981-01-01      0.0422
# 4558           0.489       242733   0.475  ...    1985-08-22      0.0343
# 4561           0.612       237733   0.675  ...    1985-01-01      0.0388
# 4617           0.641       247067   0.677  ...    1985-04-22      0.0327
# ...              ...          ...     ...  ...           ...         ...
# 169904         0.875       163800   0.443  ...    2020-05-15      0.1430
# 169905         0.719       167468   0.385  ...    2020-06-08      0.0403
# 169906         0.514       180700   0.539  ...    2020-05-29      0.1050
# 169907         0.646       167308   0.761  ...    2020-02-28      0.0385
# 169908         0.512       214787   0.428  ...    2020-03-27      0.0271
#
#           tempo  valence  year
# 3366    191.107    0.439  1973
# 4192    164.825    0.785  1981
# 4558    139.213    0.307  1985
# 4561    148.336    0.803  1985
# 4617    120.666    0.896  1985
# ...         ...      ...   ...
# 169904  100.012    0.306  2020
# 169905  128.000    0.270  2020
# 169906  123.700    0.153  2020
# 169907  129.916    0.472  2020
# 169908   80.588    0.366  2020
#
# [24372 rows x 19 columns]

# %%
rand_df = generate_random_summary(df1, num_cols=num_cols_and_rows, num_rows=num_cols_and_rows)
color_random_summary(rand_df, rules, sdf.mapping_bins_to_values, df1)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 32/32 [00:00<00:00, 42.28it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 311.15it/s]
# <style type="text/css">
# #T_b10a6 .pd-t {
#   visibility: hidden;
#   position: absolute;
#   z-index: 1;
#   background-color: black;
#   color: white;
#   transform: translate(-20px, -20px);
# }
# #T_b10a6 #T_b10a6_row0_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_b10a6 #T_b10a6_row0_col3 .pd-t::after {
#   content: "Rule #150: {(acousticness = (0.9, 1.0]),(loudness = (-61.0, -16.0]),} ---> {(explicit = 0),}, support=0.1, confidence = 1.0, lift = 1.09";
# }
# #T_b10a6 #T_b10a6_row0_col5:hover .pd-t {
#   visibility: visible;
# }
# #T_b10a6 #T_b10a6_row0_col5 .pd-t::after {
#   content: "Rule #150: {(acousticness = (0.9, 1.0]),(loudness = (-61.0, -16.0]),} ---> {(explicit = 0),}, support=0.1, confidence = 1.0, lift = 1.09";
# }
# #T_b10a6 #T_b10a6_row0_col8:hover .pd-t {
#   visibility: visible;
# }
# #T_b10a6 #T_b10a6_row0_col8 .pd-t::after {
#   content: "Rule #150: {(acousticness = (0.9, 1.0]),(loudness = (-61.0, -16.0]),} ---> {(explicit = 0),}, support=0.1, confidence = 1.0, lift = 1.09";
# }
# #T_b10a6 #T_b10a6_row1_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_b10a6 #T_b10a6_row1_col2 .pd-t::after {
#   content: "Rule #45: {(instrumentalness = (2e-05, 0.002]),} ---> {(explicit = 0),}, support=0.19, confidence = 0.94, lift = 1.02";
# }
# #T_b10a6 #T_b10a6_row1_col5:hover .pd-t {
#   visibility: visible;
# }
# #T_b10a6 #T_b10a6_row1_col5 .pd-t::after {
#   content: "Rule #45: {(instrumentalness = (2e-05, 0.002]),} ---> {(explicit = 0),}, support=0.19, confidence = 0.94, lift = 1.02";
# }
# #T_b10a6 #T_b10a6_row2_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_b10a6 #T_b10a6_row2_col2 .pd-t::after {
#   content: "Rule #92: {(instrumentalness = (2e-05, 0.002]),} ---> {(mode = 1),}, support=0.14, confidence = 0.72, lift = 1.01";
# }
# #T_b10a6 #T_b10a6_row2_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_b10a6 #T_b10a6_row2_col4 .pd-t::after {
#   content: "Rule #92: {(instrumentalness = (2e-05, 0.002]),} ---> {(mode = 1),}, support=0.14, confidence = 0.72, lift = 1.01";
# }
# #T_b10a6 #T_b10a6_row3_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_b10a6 #T_b10a6_row3_col0 .pd-t::after {
#   content: "Rule #168: {(duration_ms = (193387.0, 227347.0]),(mode = 1),} ---> {(explicit = 0),}, support=0.13, confidence = 0.93, lift = 1.01";
# }
# #T_b10a6 #T_b10a6_row3_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_b10a6 #T_b10a6_row3_col4 .pd-t::after {
#   content: "Rule #168: {(duration_ms = (193387.0, 227347.0]),(mode = 1),} ---> {(explicit = 0),}, support=0.13, confidence = 0.93, lift = 1.01";
# }
# #T_b10a6 #T_b10a6_row3_col5:hover .pd-t {
#   visibility: visible;
# }
# #T_b10a6 #T_b10a6_row3_col5 .pd-t::after {
#   content: "Rule #168: {(duration_ms = (193387.0, 227347.0]),(mode = 1),} ---> {(explicit = 0),}, support=0.13, confidence = 0.93, lift = 1.01";
# }
# #T_b10a6 #T_b10a6_row5_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_b10a6 #T_b10a6_row5_col2 .pd-t::after {
#   content: "Rule #90: {(instrumentalness = (-0.1, 2e-05]),} ---> {(mode = 1),}, support=0.29, confidence = 0.73, lift = 1.02";
# }
# #T_b10a6 #T_b10a6_row5_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_b10a6 #T_b10a6_row5_col4 .pd-t::after {
#   content: "Rule #90: {(instrumentalness = (-0.1, 2e-05]),} ---> {(mode = 1),}, support=0.29, confidence = 0.73, lift = 1.02";
# }
# #T_b10a6 #T_b10a6_row6_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_b10a6 #T_b10a6_row6_col3 .pd-t::after {
#   content: "Rule #141: {(acousticness = (0.3, 0.7]),(mode = 1),} ---> {(explicit = 0),}, support=0.14, confidence = 0.95, lift = 1.04";
# }
# #T_b10a6 #T_b10a6_row6_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_b10a6 #T_b10a6_row6_col4 .pd-t::after {
#   content: "Rule #141: {(acousticness = (0.3, 0.7]),(mode = 1),} ---> {(explicit = 0),}, support=0.14, confidence = 0.95, lift = 1.04";
# }
# #T_b10a6 #T_b10a6_row6_col5:hover .pd-t {
#   visibility: visible;
# }
# #T_b10a6 #T_b10a6_row6_col5 .pd-t::after {
#   content: "Rule #141: {(acousticness = (0.3, 0.7]),(mode = 1),} ---> {(explicit = 0),}, support=0.14, confidence = 0.95, lift = 1.04";
# }
# #T_b10a6 #T_b10a6_row7_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_b10a6 #T_b10a6_row7_col2 .pd-t::after {
#   content: "Rule #192: {(instrumentalness = (-0.1, 2e-05]),(speechiness = (-0.1, 0.03]),} ---> {(explicit = 0),}, support=0.09, confidence = 0.99, lift = 1.08";
# }
# #T_b10a6 #T_b10a6_row7_col5:hover .pd-t {
#   visibility: visible;
# }
# #T_b10a6 #T_b10a6_row7_col5 .pd-t::after {
#   content: "Rule #192: {(instrumentalness = (-0.1, 2e-05]),(speechiness = (-0.1, 0.03]),} ---> {(explicit = 0),}, support=0.09, confidence = 0.99, lift = 1.08";
# }
# #T_b10a6 #T_b10a6_row7_col7:hover .pd-t {
#   visibility: visible;
# }
# #T_b10a6 #T_b10a6_row7_col7 .pd-t::after {
#   content: "Rule #192: {(instrumentalness = (-0.1, 2e-05]),(speechiness = (-0.1, 0.03]),} ---> {(explicit = 0),}, support=0.09, confidence = 0.99, lift = 1.08";
# }
# #T_b10a6 #T_b10a6_row8_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_b10a6 #T_b10a6_row8_col2 .pd-t::after {
#   content: "Rule #196: {(instrumentalness = (0.3, 1.0]),(loudness = (-61.0, -16.0]),} ---> {(explicit = 0),}, support=0.09, confidence = 1.0, lift = 1.09";
# }
# #T_b10a6 #T_b10a6_row8_col5:hover .pd-t {
#   visibility: visible;
# }
# #T_b10a6 #T_b10a6_row8_col5 .pd-t::after {
#   content: "Rule #196: {(instrumentalness = (0.3, 1.0]),(loudness = (-61.0, -16.0]),} ---> {(explicit = 0),}, support=0.09, confidence = 1.0, lift = 1.09";
# }
# #T_b10a6 #T_b10a6_row8_col8:hover .pd-t {
#   visibility: visible;
# }
# #T_b10a6 #T_b10a6_row8_col8 .pd-t::after {
#   content: "Rule #196: {(instrumentalness = (0.3, 1.0]),(loudness = (-61.0, -16.0]),} ---> {(explicit = 0),}, support=0.09, confidence = 1.0, lift = 1.09";
# }
# #T_b10a6 #T_b10a6_row9_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_b10a6 #T_b10a6_row9_col4 .pd-t::after {
#   content: "Rule #228: {(mode = 1),(speechiness = (0.05, 0.09]),} ---> {(explicit = 0),}, support=0.13, confidence = 0.95, lift = 1.03";
# }
# #T_b10a6 #T_b10a6_row9_col5:hover .pd-t {
#   visibility: visible;
# }
# #T_b10a6 #T_b10a6_row9_col5 .pd-t::after {
#   content: "Rule #228: {(mode = 1),(speechiness = (0.05, 0.09]),} ---> {(explicit = 0),}, support=0.13, confidence = 0.95, lift = 1.03";
# }
# #T_b10a6 #T_b10a6_row9_col7:hover .pd-t {
#   visibility: visible;
# }
# #T_b10a6 #T_b10a6_row9_col7 .pd-t::after {
#   content: "Rule #228: {(mode = 1),(speechiness = (0.05, 0.09]),} ---> {(explicit = 0),}, support=0.13, confidence = 0.95, lift = 1.03";
# }
# #T_b10a6_row0_col3, #T_b10a6_row0_col5, #T_b10a6_row0_col8 {
#   background-color: lightblue;
# }
# #T_b10a6_row1_col2, #T_b10a6_row1_col5 {
#   background-color: gray;
# }
# #T_b10a6_row2_col2, #T_b10a6_row2_col4 {
#   background-color: red;
# }
# #T_b10a6_row3_col0, #T_b10a6_row3_col4, #T_b10a6_row3_col5 {
#   background-color: purple;
# }
# #T_b10a6_row5_col2, #T_b10a6_row5_col4 {
#   background-color: darkgrey;
# }
# #T_b10a6_row6_col3, #T_b10a6_row6_col4, #T_b10a6_row6_col5 {
#   background-color: yellow;
# }
# #T_b10a6_row7_col2, #T_b10a6_row7_col5, #T_b10a6_row7_col7 {
#   background-color: orange;
# }
# #T_b10a6_row8_col2, #T_b10a6_row8_col5, #T_b10a6_row8_col8 {
#   background-color: blue;
# }
# #T_b10a6_row9_col4, #T_b10a6_row9_col5, #T_b10a6_row9_col7 {
#   background-color: pink;
# }
# </style>
# <table id="T_b10a6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b10a6_level0_col0" class="col_heading level0 col0" >duration_ms</th>
#       <th id="T_b10a6_level0_col1" class="col_heading level0 col1" >artists</th>
#       <th id="T_b10a6_level0_col2" class="col_heading level0 col2" >instrumentalness</th>
#       <th id="T_b10a6_level0_col3" class="col_heading level0 col3" >acousticness</th>
#       <th id="T_b10a6_level0_col4" class="col_heading level0 col4" >mode</th>
#       <th id="T_b10a6_level0_col5" class="col_heading level0 col5" >explicit</th>
#       <th id="T_b10a6_level0_col6" class="col_heading level0 col6" >release_date</th>
#       <th id="T_b10a6_level0_col7" class="col_heading level0 col7" >speechiness</th>
#       <th id="T_b10a6_level0_col8" class="col_heading level0 col8" >loudness</th>
#       <th id="T_b10a6_level0_col9" class="col_heading level0 col9" >popularity</th>
#     </tr>

# %%
nc_df = gen_nc_summary(df1, num_cols_and_rows, num_cols_and_rows)
color_random_summary(nc_df, rules, sdf.mapping_bins_to_values, df1)
# Out:
# C:\Users\user\OneDrive - mail.tau.ac.il\PhD\SubTub\Naive_clustering\nc_utils.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[c] = labelencoder.fit_transform(df[c])
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 37.10it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 1336.40it/s]
# <style type="text/css">
# #T_99006 .pd-t {
#   visibility: hidden;
#   position: absolute;
#   z-index: 1;
#   background-color: black;
#   color: white;
#   transform: translate(-20px, -20px);
# }
# #T_99006 #T_99006_row4_col5:hover .pd-t {
#   visibility: visible;
# }
# #T_99006 #T_99006_row4_col5 .pd-t::after {
#   content: "Rule #136: {(year = (2003.0, 2020.0]),} ---> {(popularity = popularity_4),}, support=0.13, confidence = 0.65, lift = 3.32";
# }
# #T_99006 #T_99006_row4_col8:hover .pd-t {
#   visibility: visible;
# }
# #T_99006 #T_99006_row4_col8 .pd-t::after {
#   content: "Rule #136: {(year = (2003.0, 2020.0]),} ---> {(popularity = popularity_4),}, support=0.13, confidence = 0.65, lift = 3.32";
# }
# #T_99006_row4_col5, #T_99006_row4_col8 {
#   background-color: lightblue;
# }
# </style>
# <table id="T_99006">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_99006_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_99006_level0_col1" class="col_heading level0 col1" >duration_ms</th>
#       <th id="T_99006_level0_col2" class="col_heading level0 col2" >danceability</th>
#       <th id="T_99006_level0_col3" class="col_heading level0 col3" >id</th>
#       <th id="T_99006_level0_col4" class="col_heading level0 col4" >artists</th>
#       <th id="T_99006_level0_col5" class="col_heading level0 col5" >year</th>
#       <th id="T_99006_level0_col6" class="col_heading level0 col6" >release_date</th>
#       <th id="T_99006_level0_col7" class="col_heading level0 col7" >tempo</th>
#       <th id="T_99006_level0_col8" class="col_heading level0 col8" >popularity</th>
#       <th id="T_99006_level0_col9" class="col_heading level0 col9" >loudness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_99006_level0_row0" class="row_heading level0 row0" >95935</th>
#       <td id="T_99006_row0_col0" class="data row0 col0" >9860<span class="pd-t"></span></td>
#       <td id="T_99006_row0_col1" class="data row0 col1" >165360<span class="pd-t"></span></td>
#       <td id="T_99006_row0_col2" class="data row0 col2" >0.82<span class="pd-t"></span></td>
#       <td id="T_99006_row0_col3" class="data row0 col3" >13356<span class="pd-t"></span></td>
#       <td id="T_99006_row0_col4" class="data row0 col4" >5412<span class="pd-t"></span></td>
#       <td id="T_99006_row0_col5" class="data row0 col5" >2001<span class="pd-t"></span></td>
#       <td id="T_99006_row0_col6" class="data row0 col6" >1772<span class="pd-t"></span></td>
#       <td id="T_99006_row0_col7" class="data row0 col7" >114.50<span class="pd-t"></span></td>
#       <td id="T_99006_row0_col8" class="data row0 col8" >56<span class="pd-t"></span></td>
#       <td id="T_99006_row0_col9" class="data row0 col9" >-7.05<span class="pd-t"></span></td>
#     </tr>
#     <tr>
#       <th id="T_99006_level0_row1" class="row_heading level0 row1" >83807</th>
#       <td id="T_99006_row1_col0" class="data row1 col0" >9919<span class="pd-t"></span></td>
#       <td id="T_99006_row1_col1" class="data row1 col1" >297800<span class="pd-t"></span></td>
#       <td id="T_99006_row1_col2" class="data row1 col2" >0.46<span class="pd-t"></span></td>
#       <td id="T_99006_row1_col3" class="data row1 col3" >11515<span class="pd-t"></span></td>
#       <td id="T_99006_row1_col4" class="data row1 col4" >5299<span class="pd-t"></span></td>
#       <td id="T_99006_row1_col5" class="data row1 col5" >1978<span class="pd-t"></span></td>
#       <td id="T_99006_row1_col6" class="data row1 col6" >526<span class="pd-t"></span></td>
#       <td id="T_99006_row1_col7" class="data row1 col7" >121.19<span class="pd-t"></span></td>
#       <td id="T_99006_row1_col8" class="data row1 col8" >57<span class="pd-t"></span></td>
#       <td id="T_99006_row1_col9" class="data row1 col9" >-11.93<span class="pd-t"></span></td>
#     </tr>
#     <tr>
#       <th id="T_99006_level0_row2" class="row_heading level0 row2" >92848</th>
#       <td id="T_99006_row2_col0" class="data row2 col0" >11007<span class="pd-t"></span></td>
#       <td id="T_99006_row2_col1" class="data row2 col1" >621107<span class="pd-t"></span></td>
#       <td id="T_99006_row2_col2" class="data row2 col2" >0.30<span class="pd-t"></span></td>
#       <td id="T_99006_row2_col3" class="data row2 col3" >12249<span class="pd-t"></span></td>
#       <td id="T_99006_row2_col4" class="data row2 col4" >3158<span class="pd-t"></span></td>
#       <td id="T_99006_row2_col5" class="data row2 col5" >1971<span class="pd-t"></span></td>
#       <td id="T_99006_row2_col6" class="data row2 col6" >296<span class="pd-t"></span></td>
#       <td id="T_99006_row2_col7" class="data row2 col7" >134.91<span class="pd-t"></span></td>
#       <td id="T_99006_row2_col8" class="data row2 col8" >60<span class="pd-t"></span></td>
#       <td id="T_99006_row2_col9" class="data row2 col9" >-15.59<span class="pd-t"></span></td>
#     </tr>
#     <tr>
#       <th id="T_99006_level0_row3" class="row_heading level0 row3" >104435</th>
#       <td id="T_99006_row3_col0" class="data row3 col0" >9828<span class="pd-t"></span></td>
#       <td id="T_99006_row3_col1" class="data row3 col1" >226493<span class="pd-t"></span></td>
#       <td id="T_99006_row3_col2" class="data row3 col2" >0.38<span class="pd-t"></span></td>
#       <td id="T_99006_row3_col3" class="data row3 col3" >12339<span class="pd-t"></span></td>
#       <td id="T_99006_row3_col4" class="data row3 col4" >5531<span class="pd-t"></span></td>
#       <td id="T_99006_row3_col5" class="data row3 col5" >1991<span class="pd-t"></span></td>
#       <td id="T_99006_row3_col6" class="data row3 col6" >1132<span class="pd-t"></span></td>
#       <td id="T_99006_row3_col7" class="data row3 col7" >163.97<span class="pd-t"></span></td>
#       <td id="T_99006_row3_col8" class="data row3 col8" >61<span class="pd-t"></span></td>
#       <td id="T_99006_row3_col9" class="data row3 col9" >-11.79<span class="pd-t"></span></td>
#     </tr>
#     <tr>
#       <th id="T_99006_level0_row4" class="row_heading level0 row4" >97667</th>
#       <td id="T_99006_row4_col0" class="data row4 col0" >10753<span class="pd-t"></span></td>
#       <td id="T_99006_row4_col1" class="data row4 col1" >117013<span class="pd-t"></span></td>
#       <td id="T_99006_row4_col2" class="data row4 col2" >0.72<span class="pd-t"></span></td>
#       <td id="T_99006_row4_col3" class="data row4 col3" >14465<span class="pd-t"></span></td>
#       <td id="T_99006_row4_col4" class="data row4 col4" >5178<span class="pd-t"></span></td>
#       <td id="T_99006_row4_col5" class="data row4 col5" >2019<span class="pd-t"></span></td>
#       <td id="T_99006_row4_col6" class="data row4 col6" >4662<span class="pd-t"></span></td>
#       <td id="T_99006_row4_col7" class="data row4 col7" >204.13<span class="pd-t"></span></td>
#       <td id="T_99006_row4_col8" class="data row4 col8" >79<span class="pd-t"></span></td>
#       <td id="T_99006_row4_col9" class="data row4 col9" >-6.90<span class="pd-t"></span></td>
#     </tr>
#     <tr>
#       <th id="T_99006_level0_row5" class="row_heading level0 row5" >83134</th>
#       <td id="T_99006_row5_col0" class="data row5 col0" >5011<span class="pd-t"></span></td>
#       <td id="T_99006_row5_col1" class="data row5 col1" >1412451<span class="pd-t"></span></td>
#       <td id="T_99006_row5_col2" class="data row5 col2" >0.28<span class="pd-t"></span></td>
#       <td id="T_99006_row5_col3" class="data row5 col3" >23604<span class="pd-t"></span></td>
#       <td id="T_99006_row5_col4" class="data row5 col4" >6935<span class="pd-t"></span></td>
#       <td id="T_99006_row5_col5" class="data row5 col5" >1971<span class="pd-t"></span></td>
#       <td id="T_99006_row5_col6" class="data row5 col6" >308<span class="pd-t"></span></td>
#       <td id="T_99006_row5_col7" class="data row5 col7" >134.04<span class="pd-t"></span></td>
#       <td id="T_99006_row5_col8" class="data row5 col8" >58<span class="pd-t"></span></td>
#       <td id="T_99006_row5_col9" class="data row5 col9" >-16.58<span class="pd-t"></span></td>
#     </tr>
#     <tr>
#       <th id="T_99006_level0_row6" class="row_heading level0 row6" >135141</th>
#       <td id="T_99006_r

# %%
sdf.display(df1,pivot_columns=['popularity'])
# Out:
# for creating new table vectors, it took 0:00:04.898166
# for summary creation, it took 0:00:01.963754
# calculating rules for this dataset
# found 133 rules
# 100%|██████████████████████████████████████████████████████████████████████████████████| 53/53 [00:01<00:00, 45.27it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 286.47it/s]
# for or summary creation, it took 0:00:23.156070
# added the following columns instead of the previously displayed as they are more informative for this dataset
# {'popularity'}
# <style type="text/css">
# #T_4c656 .pd-t {
#   visibility: hidden;
#   position: absolute;
#   z-index: 1;
#   background-color: black;
#   color: white;
#   transform: translate(-20px, -20px);
# }
# #T_4c656 #T_4c656_row0_col5:hover .pd-t {
#   visibility: visible;
# }
# #T_4c656 #T_4c656_row0_col5 .pd-t::after {
#   content: "Rule #117: {(speechiness = (0.09, 1.0]),(year = (2003.0, 2020.0]),} ---> {(popularity = popularity_4),}, support=0.23, confidence = 1.0, lift = 1.0";
# }
# #T_4c656 #T_4c656_row0_col8:hover .pd-t {
#   visibility: visible;
# }
# #T_4c656 #T_4c656_row0_col8 .pd-t::after {
#   content: "Rule #117: {(speechiness = (0.09, 1.0]),(year = (2003.0, 2020.0]),} ---> {(popularity = popularity_4),}, support=0.23, confidence = 1.0, lift = 1.0";
# }
# #T_4c656 #T_4c656_row0_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_4c656 #T_4c656_row0_col9 .pd-t::after {
#   content: "Rule #117: {(speechiness = (0.09, 1.0]),(year = (2003.0, 2020.0]),} ---> {(popularity = popularity_4),}, support=0.23, confidence = 1.0, lift = 1.0";
# }
# #T_4c656 #T_4c656_row1_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_4c656 #T_4c656_row1_col3 .pd-t::after {
#   content: "Rule #93: {(loudness = (-6.0, 4.0]),(popularity = (51.0, 100.0]),} ---> {(explicit = 0),}, support=0.34, confidence = 0.73, lift = 0.97";
# }
# #T_4c656 #T_4c656_row1_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_4c656 #T_4c656_row1_col4 .pd-t::after {
#   content: "Rule #93: {(loudness = (-6.0, 4.0]),(popularity = (51.0, 100.0]),} ---> {(explicit = 0),}, support=0.34, confidence = 0.73, lift = 0.97";
# }
# #T_4c656 #T_4c656_row1_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_4c656 #T_4c656_row1_col9 .pd-t::after {
#   content: "Rule #93: {(loudness = (-6.0, 4.0]),(popularity = (51.0, 100.0]),} ---> {(explicit = 0),}, support=0.34, confidence = 0.73, lift = 0.97";
# }
# #T_4c656 #T_4c656_row2_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_4c656 #T_4c656_row2_col3 .pd-t::after {
#   content: "Rule #124: {(loudness = (-6.0, 4.0]),(popularity = (51.0, 100.0]),(year = (2003.0, 2020.0]),} ---> {(explicit = 0),}, support=0.27, confidence = 0.71, lift = 0.93";
# }
# #T_4c656 #T_4c656_row2_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_4c656 #T_4c656_row2_col4 .pd-t::after {
#   content: "Rule #124: {(loudness = (-6.0, 4.0]),(popularity = (51.0, 100.0]),(year = (2003.0, 2020.0]),} ---> {(explicit = 0),}, support=0.27, confidence = 0.71, lift = 0.93";
# }
# #T_4c656 #T_4c656_row2_col5:hover .pd-t {
#   visibility: visible;
# }
# #T_4c656 #T_4c656_row2_col5 .pd-t::after {
#   content: "Rule #124: {(loudness = (-6.0, 4.0]),(popularity = (51.0, 100.0]),(year = (2003.0, 2020.0]),} ---> {(explicit = 0),}, support=0.27, confidence = 0.71, lift = 0.93";
# }
# #T_4c656 #T_4c656_row2_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_4c656 #T_4c656_row2_col9 .pd-t::after {
#   content: "Rule #124: {(loudness = (-6.0, 4.0]),(popularity = (51.0, 100.0]),(year = (2003.0, 2020.0]),} ---> {(explicit = 0),}, support=0.27, confidence = 0.71, lift = 0.93";
# }
# #T_4c656 #T_4c656_row3_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_4c656 #T_4c656_row3_col3 .pd-t::after {
#   content: "Rule #35: {(popularity = (51.0, 100.0]),} ---> {(explicit = 0),}, support=0.76, confidence = 0.76, lift = 1.0";
# }
# #T_4c656 #T_4c656_row3_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_4c656 #T_4c656_row3_col9 .pd-t::after {
#   content: "Rule #35: {(popularity = (51.0, 100.0]),} ---> {(explicit = 0),}, support=0.76, confidence = 0.76, lift = 1.0";
# }
# #T_4c656 #T_4c656_row4_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_4c656 #T_4c656_row4_col3 .pd-t::after {
#   content: "Rule #99: {(explicit = 1),(year = (2003.0, 2020.0]),} ---> {(popularity = popularity_4),}, support=0.22, confidence = 1.0, lift = 1.0";
# }
# #T_4c656 #T_4c656_row4_col5:hover .pd-t {
#   visibility: visible;
# }
# #T_4c656 #T_4c656_row4_col5 .pd-t::after {
#   content: "Rule #99: {(explicit = 1),(year = (2003.0, 2020.0]),} ---> {(popularity = popularity_4),}, support=0.22, confidence = 1.0, lift = 1.0";
# }
# #T_4c656 #T_4c656_row4_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_4c656 #T_4c656_row4_col9 .pd-t::after {
#   content: "Rule #99: {(explicit = 1),(year = (2003.0, 2020.0]),} ---> {(popularity = popularity_4),}, support=0.22, confidence = 1.0, lift = 1.0";
# }
# #T_4c656 #T_4c656_row5_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_4c656 #T_4c656_row5_col3 .pd-t::after {
#   content: "Rule #69: {(acousticness = (0.05, 0.3]),(popularity = (51.0, 100.0]),} ---> {(explicit = 0),}, support=0.23, confidence = 0.7, lift = 0.92";
# }
# #T_4c656 #T_4c656_row5_col7:hover .pd-t {
#   visibility: visible;
# }
# #T_4c656 #T_4c656_row5_col7 .pd-t::after {
#   content: "Rule #69: {(acousticness = (0.05, 0.3]),(popularity = (51.0, 100.0]),} ---> {(explicit = 0),}, support=0.23, confidence = 0.7, lift = 0.92";
# }
# #T_4c656 #T_4c656_row5_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_4c656 #T_4c656_row5_col9 .pd-t::after {
#   content: "Rule #69: {(acousticness = (0.05, 0.3]),(popularity = (51.0, 100.0]),} ---> {(explicit = 0),}, support=0.23, confidence = 0.7, lift = 0.92";
# }
# #T_4c656 #T_4c656_row6_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_4c656 #T_4c656_row6_col4 .pd-t::after {
#   content: "Rule #111: {(loudness = (-9.0, -6.0]),(year = (2003.0, 2020.0]),} ---> {(popularity = popularity_4),}, support=0.21, confidence = 1.0, lift = 1.0";
# }
# #T_4c656 #T_4c656_row6_col5:hover .pd-t {
#   visibility: visible;
# }
# #T_4c656 #T_4c656_row6_col5 .pd-t::after {
#   content: "Rule #111: {(loudness = (-9.0, -6.0]),(year = (2003.0, 2020.0]),} ---> {(popularity = popularity_4),}, support=0.21, confidence = 1.0, lift = 1.0";
# }
# #T_4c656 #T_4c656_row6_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_4c656 #T_4c656_row6_col9 .pd-t::after {
#   content: "Rule #111: {(loudness = (-9.0, -6.0]),(year = (2003.0, 2020.0]),} ---> {(popularity = popularity_4),}, support=0.21, confidence = 1.0, lift = 1.0";
# }
# #T_4c656 #T_4c656_row7_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_4c656 #T_4c656_row7_col3 .pd-t::after {
#   content: "Rule #98: {(popularity = (51.0, 100.0]),(year = (2003.0, 2020.0]),} ---> {(explicit = 0),}, support=0.49, confidence = 0.69, lift = 0.91";
# }
# #T_4c656 #T_4c656_row7_col5:hover .pd-t {
#   visibility: visible;
# }
# #T_4c656 #T_4c656_row7_col5 .pd-t::after {
#   content: "Rule #98: {(popularity = (51.0, 100.0]),(year = (2003.0, 2020.0]),} ---> {(explicit = 0),}, support=0.49, confidence = 0.69, lift = 0.91";
# }
# #T_4c656 #T_4c656_row7_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_4c656 #T_4c656_row7_col9 .pd-t::after {
#   content: "Rule #98: {(popularity = (51.0, 100.0]),(year = (2003.0, 2020.0]),} ---> {(explicit = 0),}, support=0.49, confidence = 0.69, lift = 0.91";
# }
# #T_4c656 #T_4c656_row8_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_4c656 #T_4c656_row8_col3 .pd-t::after {
#   content: "Rule #91: {(loudness = (-9.0, -6.0]),(popularity = (51.0, 100.0]),} ---> {(explicit = 0),}, support=0.2, confidence = 0.71, lift = 0.94";
# }
# #T_4c656 #T_4c656_row8_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_4c656 #T_4c656_row8_col4 .pd-t::after {
#   content: "Rule #91: {(loudness = (-9.0, -6.0]),(popularity = (51.0, 100.0]),} ---> {(explicit = 0),}, support=0.2, confidence = 0.71, lift = 0.94";
# }
# #T_4c656 #T_4c656_row8_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_4c656 #T_4c656_row8_col9 .pd-t::after {
#   content: "Rule #91: {(loudness = (-9.0, -6.0]),(popularity = (51.0, 100.0]),} ---> {(explicit = 0),}, support=0.2, confidence = 0.71, lift = 0.94";
# }
# #T_4c656 #T_4c656_row9_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_4c656 #T_4c656_row9_col2 .pd-t::after {
#   content: "Rule #79: {(energy = (0.6, 0.8]),(popularity = (51.0, 100.0]),} ---> {(explicit = 0),}, support=0.23, confidence = 0.69, lift = 0.92";
# }
# #T_4c656 #T_4c656_row9_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_4c656 #T_4c656_row9_col3 .pd-t::after {
#   content: "Rule #79: {(energy = (0.6, 0.8]),(popularity = (51.0, 100.0]),} ---> {(explicit = 0),}, support=0.23, confidence = 0.69, lift = 0.92";
# }
# #T_4c656 #T_4c656_row9_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_4c656 #T_4c656_row9_col9 .pd

# %% [markdown]
# ## What cause a song to be very unpopular (below 5) ?

# %%
df2 = full_df_a[full_df_a['popularity']<5]

# %%
df2
# Out:
#         acousticness                                   artists  danceability  \
# 0              0.995                       ['Carl Woitschach']         0.708
# 1              0.994  ['Robert Schumann', 'Vladimir Horowitz']         0.379
# 2              0.604                   ['Seweryn Goszczyński']         0.749
# 3              0.995                      ['Francisco Canaro']         0.781
# 4              0.990  ['Frédéric Chopin', 'Vladimir Horowitz']         0.210
# ...              ...                                       ...           ...
# 169848         0.262                        ['Ellie Goulding']         0.453
# 169849         0.262                        ['Ellie Goulding']         0.453
# 169850         0.932                        ['Ellie Goulding']         0.491
# 169851         0.973                        ['Ellie Goulding']         0.415
# 169872         0.106                             ['Sean Paul']         0.951
#
#         duration_ms  energy  ...  release_date speechiness    tempo  valence  \
# 0            158648  0.1950  ...          1928      0.0506  118.469   0.7790
# 1            282133  0.0135  ...          1928      0.0462   83.972   0.0767
# 2            104300  0.2200  ...          1928      0.9290  107.177   0.8800
# 3            180760  0.1300  ...    1928-09-25      0.0926  108.003   0.7200
# 4            687733  0.2040  ...          1928      0.0424   62.149   0.0693
# ...             ...     ...  ...           ...         ...      ...      ...
# 169848       148689  0.3160  ...    2020-06-12      0.0316  125.628   0.1770
# 169849       148689  0.3160  ...    2020-06-05      0.0316  125.628   0.1770
# 169850       188733  0.3670  ...    2020-06-05      0.0308  134.105   0.4550
# 169851       207373  0.2620  ...    2020-06-05      0.0333  105.861   0.3110
# 169872       218573  0.6000  ...    2020-06-12      0.0686  125.040   0.8220
#
#         year
# 0       1928
# 1       1928
# 2       1928
# 3       1928
# 4       1928
# ...      ...
# 169848  2020
# 169849  2020
# 169850  2020
# 169851  2020
# 169872  2020
#
# [33334 rows x 19 columns]

# %%
rand_df = generate_random_summary(df2, num_cols=num_cols_and_rows, num_rows=num_cols_and_rows)
color_random_summary(rand_df, rules, sdf.mapping_bins_to_values, df2)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 57/57 [00:02<00:00, 19.82it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 270.98it/s]
# <style type="text/css">
# #T_e0dc2 .pd-t {
#   visibility: hidden;
#   position: absolute;
#   z-index: 1;
#   background-color: black;
#   color: white;
#   transform: translate(-20px, -20px);
# }
# #T_e0dc2 #T_e0dc2_row0_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_e0dc2 #T_e0dc2_row0_col1 .pd-t::after {
#   content: "Rule #152: {(explicit = 0),(popularity = (-1.0, 5.0]),} ---> {(acousticness = acousticness_4),}, support=0.13, confidence = 0.7, lift = 3.52";
# }
# #T_e0dc2 #T_e0dc2_row0_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_e0dc2 #T_e0dc2_row0_col4 .pd-t::after {
#   content: "Rule #152: {(explicit = 0),(popularity = (-1.0, 5.0]),} ---> {(acousticness = acousticness_4),}, support=0.13, confidence = 0.7, lift = 3.52";
# }
# #T_e0dc2 #T_e0dc2_row0_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_e0dc2 #T_e0dc2_row0_col9 .pd-t::after {
#   content: "Rule #152: {(explicit = 0),(popularity = (-1.0, 5.0]),} ---> {(acousticness = acousticness_4),}, support=0.13, confidence = 0.7, lift = 3.52";
# }
# #T_e0dc2 #T_e0dc2_row1_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_e0dc2 #T_e0dc2_row1_col4 .pd-t::after {
#   content: "Rule #6: {(acousticness = (0.7, 0.9]),} ---> {(explicit = 0),}, support=0.2, confidence = 0.98, lift = 1.07";
# }
# #T_e0dc2 #T_e0dc2_row1_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_e0dc2 #T_e0dc2_row1_col9 .pd-t::after {
#   content: "Rule #6: {(acousticness = (0.7, 0.9]),} ---> {(explicit = 0),}, support=0.2, confidence = 0.98, lift = 1.07";
# }
# #T_e0dc2 #T_e0dc2_row2_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_e0dc2 #T_e0dc2_row2_col1 .pd-t::after {
#   content: "Rule #265: {(acousticness = (0.9, 1.0]),(mode = 1),(popularity = (-1.0, 5.0]),} ---> {(explicit = 0),}, support=0.09, confidence = 1.0, lift = 1.09";
# }
# #T_e0dc2 #T_e0dc2_row2_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_e0dc2 #T_e0dc2_row2_col4 .pd-t::after {
#   content: "Rule #265: {(acousticness = (0.9, 1.0]),(mode = 1),(popularity = (-1.0, 5.0]),} ---> {(explicit = 0),}, support=0.09, confidence = 1.0, lift = 1.09";
# }
# #T_e0dc2 #T_e0dc2_row2_col6:hover .pd-t {
#   visibility: visible;
# }
# #T_e0dc2 #T_e0dc2_row2_col6 .pd-t::after {
#   content: "Rule #265: {(acousticness = (0.9, 1.0]),(mode = 1),(popularity = (-1.0, 5.0]),} ---> {(explicit = 0),}, support=0.09, confidence = 1.0, lift = 1.09";
# }
# #T_e0dc2 #T_e0dc2_row2_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_e0dc2 #T_e0dc2_row2_col9 .pd-t::after {
#   content: "Rule #265: {(acousticness = (0.9, 1.0]),(mode = 1),(popularity = (-1.0, 5.0]),} ---> {(explicit = 0),}, support=0.09, confidence = 1.0, lift = 1.09";
# }
# #T_e0dc2 #T_e0dc2_row3_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_e0dc2 #T_e0dc2_row3_col2 .pd-t::after {
#   content: "Rule #160: {(danceability = (-0.1, 0.4]),(valence = (-0.1, 0.3]),} ---> {(explicit = 0),}, support=0.11, confidence = 0.98, lift = 1.07";
# }
# #T_e0dc2 #T_e0dc2_row3_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_e0dc2 #T_e0dc2_row3_col3 .pd-t::after {
#   content: "Rule #160: {(danceability = (-0.1, 0.4]),(valence = (-0.1, 0.3]),} ---> {(explicit = 0),}, support=0.11, confidence = 0.98, lift = 1.07";
# }
# #T_e0dc2 #T_e0dc2_row3_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_e0dc2 #T_e0dc2_row3_col9 .pd-t::after {
#   content: "Rule #160: {(danceability = (-0.1, 0.4]),(valence = (-0.1, 0.3]),} ---> {(explicit = 0),}, support=0.11, confidence = 0.98, lift = 1.07";
# }
# #T_e0dc2 #T_e0dc2_row4_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_e0dc2 #T_e0dc2_row4_col4 .pd-t::after {
#   content: "Rule #143: {(acousticness = (0.7, 0.9]),(mode = 1),} ---> {(explicit = 0),}, support=0.15, confidence = 0.98, lift = 1.08";
# }
# #T_e0dc2 #T_e0dc2_row4_col6:hover .pd-t {
#   visibility: visible;
# }
# #T_e0dc2 #T_e0dc2_row4_col6 .pd-t::after {
#   content: "Rule #143: {(acousticness = (0.7, 0.9]),(mode = 1),} ---> {(explicit = 0),}, support=0.15, confidence = 0.98, lift = 1.08";
# }
# #T_e0dc2 #T_e0dc2_row4_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_e0dc2 #T_e0dc2_row4_col9 .pd-t::after {
#   content: "Rule #143: {(acousticness = (0.7, 0.9]),(mode = 1),} ---> {(explicit = 0),}, support=0.15, confidence = 0.98, lift = 1.08";
# }
# #T_e0dc2 #T_e0dc2_row5_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_e0dc2 #T_e0dc2_row5_col4 .pd-t::after {
#   content: "Rule #149: {(acousticness = (0.9, 1.0]),(instrumentalness = (0.3, 1.0]),} ---> {(explicit = 0),}, support=0.1, confidence = 1.0, lift = 1.09";
# }
# #T_e0dc2 #T_e0dc2_row5_col8:hover .pd-t {
#   visibility: visible;
# }
# #T_e0dc2 #T_e0dc2_row5_col8 .pd-t::after {
#   content: "Rule #149: {(acousticness = (0.9, 1.0]),(instrumentalness = (0.3, 1.0]),} ---> {(explicit = 0),}, support=0.1, confidence = 1.0, lift = 1.09";
# }
# #T_e0dc2 #T_e0dc2_row5_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_e0dc2 #T_e0dc2_row5_col9 .pd-t::after {
#   content: "Rule #149: {(acousticness = (0.9, 1.0]),(instrumentalness = (0.3, 1.0]),} ---> {(explicit = 0),}, support=0.1, confidence = 1.0, lift = 1.09";
# }
# #T_e0dc2 #T_e0dc2_row6_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_e0dc2 #T_e0dc2_row6_col4 .pd-t::after {
#   content: "Rule #145: {(energy = (-0.1, 0.2]),(explicit = 0),} ---> {(acousticness = acousticness_4),}, support=0.12, confidence = 0.62, lift = 3.12";
# }
# #T_e0dc2 #T_e0dc2_row6_col5:hover .pd-t {
#   visibility: visible;
# }
# #T_e0dc2 #T_e0dc2_row6_col5 .pd-t::after {
#   content: "Rule #145: {(energy = (-0.1, 0.2]),(explicit = 0),} ---> {(acousticness = acousticness_4),}, support=0.12, confidence = 0.62, lift = 3.12";
# }
# #T_e0dc2 #T_e0dc2_row6_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_e0dc2 #T_e0dc2_row6_col9 .pd-t::after {
#   content: "Rule #145: {(energy = (-0.1, 0.2]),(explicit = 0),} ---> {(acousticness = acousticness_4),}, support=0.12, confidence = 0.62, lift = 3.12";
# }
# #T_e0dc2 #T_e0dc2_row7_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_e0dc2 #T_e0dc2_row7_col2 .pd-t::after {
#   content: "Rule #159: {(danceability = (-0.1, 0.4]),(mode = 1),} ---> {(explicit = 0),}, support=0.14, confidence = 0.98, lift = 1.07";
# }
# #T_e0dc2 #T_e0dc2_row7_col6:hover .pd-t {
#   visibility: visible;
# }
# #T_e0dc2 #T_e0dc2_row7_col6 .pd-t::after {
#   content: "Rule #159: {(danceability = (-0.1, 0.4]),(mode = 1),} ---> {(explicit = 0),}, support=0.14, confidence = 0.98, lift = 1.07";
# }
# #T_e0dc2 #T_e0dc2_row7_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_e0dc2 #T_e0dc2_row7_col9 .pd-t::after {
#   content: "Rule #159: {(danceability = (-0.1, 0.4]),(mode = 1),} ---> {(explicit = 0),}, support=0.14, confidence = 0.98, lift = 1.07";
# }
# #T_e0dc2 #T_e0dc2_row8_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_e0dc2 #T_e0dc2_row8_col1 .pd-t::after {
#   content: "Rule #153: {(acousticness = (0.9, 1.0]),(popularity = (-1.0, 5.0]),} ---> {(explicit = 0),}, support=0.13, confidence = 1.0, lift = 1.09";
# }
# #T_e0dc2 #T_e0dc2_row8_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_e0dc2 #T_e0dc2_row8_col4 .pd-t::after {
#   content: "Rule #153: {(acousticness = (0.9, 1.0]),(popularity = (-1.0, 5.0]),} ---> {(explicit = 0),}, support=0.13, confidence = 1.0, lift = 1.09";
# }
# #T_e0dc2 #T_e0dc2_row8_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_e0dc2 #T_e0dc2_row8_col9 .pd-t::after {
#   content: "Rule #153: {(acousticness = (0.9, 1.0]),(popularity = (-1.0, 5.0]),} ---> {(explicit = 0),}, support=0.13, confidence = 1.0, lift = 1.09";
# }
# #T_e0dc2 #T_e0dc2_row9_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_e0dc2 #T_e0dc2_row9_col1 .pd-t::after {
#   content: "Rule #264: {(explicit = 0),(mode = 1),(popularity = (-1.0, 5.0]),} ---> {(acousticness = acousticness_4),}, support=0.09, confidence = 0.7, lift = 3.51";
# }
# #T_e0dc2 #T_e0dc2_row9_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_e0dc2 #T_e0dc2_row9_col4 .pd-t::after {
#   content: "Rule #264: {(explicit = 0),(mode = 1),(popularity = (-1.0, 5.0]),} ---> {(acousticness = acousticness_4),}, support=0.09, confidence = 0.7, lift = 3.51";
# }
# #T_e0dc2 #T_e0dc2_row9_col6:hover .pd-t {
#   visibility: visible;
# }
# #T_e0dc2 #T_e0dc2_row9_col6 .pd-t::after {
#   content: "Rule #264: {(explicit = 0),(mode = 1),(popularity = (-1.0, 5.0]),} ---> {(acousticness = acousticness_4),}, support=

# %%
nc_df = gen_nc_summary(df2, num_cols_and_rows, num_cols_and_rows)
color_random_summary(nc_df, rules, sdf.mapping_bins_to_values, df2)
# Out:
# C:\Users\user\OneDrive - mail.tau.ac.il\PhD\SubTub\Naive_clustering\nc_utils.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[c] = labelencoder.fit_transform(df[c])
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_7bf14">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7bf14_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_7bf14_level0_col1" class="col_heading level0 col1" >duration_ms</th>
#       <th id="T_7bf14_level0_col2" class="col_heading level0 col2" >danceability</th>
#       <th id="T_7bf14_level0_col3" class="col_heading level0 col3" >id</th>
#       <th id="T_7bf14_level0_col4" class="col_heading level0 col4" >artists</th>
#       <th id="T_7bf14_level0_col5" class="col_heading level0 col5" >year</th>
#       <th id="T_7bf14_level0_col6" class="col_heading level0 col6" >release_date</th>
#       <th id="T_7bf14_level0_col7" class="col_heading level0 col7" >tempo</th>
#       <th id="T_7bf14_level0_col8" class="col_heading level0 col8" >loudness</th>
#       <th id="T_7bf14_level0_col9" class="col_heading level0 col9" >key</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7bf14_level0_row0" class="row_heading level0 row0" >136940</th>
#       <td id="T_7bf14_row0_col0" class="data row0 col0" >15045</td>
#       <td id="T_7bf14_row0_col1" class="data row0 col1" >196807</td>
#       <td id="T_7bf14_row0_col2" class="data row0 col2" >0.59</td>
#       <td id="T_7bf14_row0_col3" class="data row0 col3" >15950</td>
#       <td id="T_7bf14_row0_col4" class="data row0 col4" >4804</td>
#       <td id="T_7bf14_row0_col5" class="data row0 col5" >1947</td>
#       <td id="T_7bf14_row0_col6" class="data row0 col6" >440</td>
#       <td id="T_7bf14_row0_col7" class="data row0 col7" >67.38</td>
#       <td id="T_7bf14_row0_col8" class="data row0 col8" >-12.69</td>
#       <td id="T_7bf14_row0_col9" class="data row0 col9" >5</td>
#     </tr>
#     <tr>
#       <th id="T_7bf14_level0_row1" class="row_heading level0 row1" >56506</th>
#       <td id="T_7bf14_row1_col0" class="data row1 col0" >11413</td>
#       <td id="T_7bf14_row1_col1" class="data row1 col1" >1118786</td>
#       <td id="T_7bf14_row1_col2" class="data row1 col2" >0.66</td>
#       <td id="T_7bf14_row1_col3" class="data row1 col3" >14359</td>
#       <td id="T_7bf14_row1_col4" class="data row1 col4" >7278</td>
#       <td id="T_7bf14_row1_col5" class="data row1 col5" >1953</td>
#       <td id="T_7bf14_row1_col6" class="data row1 col6" >609</td>
#       <td id="T_7bf14_row1_col7" class="data row1 col7" >76.64</td>
#       <td id="T_7bf14_row1_col8" class="data row1 col8" >-22.39</td>
#       <td id="T_7bf14_row1_col9" class="data row1 col9" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7bf14_level0_row2" class="row_heading level0 row2" >48725</th>
#       <td id="T_7bf14_row2_col0" class="data row2 col0" >17516</td>
#       <td id="T_7bf14_row2_col1" class="data row2 col1" >536227</td>
#       <td id="T_7bf14_row2_col2" class="data row2 col2" >0.22</td>
#       <td id="T_7bf14_row2_col3" class="data row2 col3" >16707</td>
#       <td id="T_7bf14_row2_col4" class="data row2 col4" >5865</td>
#       <td id="T_7bf14_row2_col5" class="data row2 col5" >1951</td>
#       <td id="T_7bf14_row2_col6" class="data row2 col6" >534</td>
#       <td id="T_7bf14_row2_col7" class="data row2 col7" >134.48</td>
#       <td id="T_7bf14_row2_col8" class="data row2 col8" >-12.16</td>
#       <td id="T_7bf14_row2_col9" class="data row2 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7bf14_level0_row3" class="row_heading level0 row3" >8646</th>
#       <td id="T_7bf14_row3_col0" class="data row3 col0" >18542</td>
#       <td id="T_7bf14_row3_col1" class="data row3 col1" >88200</td>
#       <td id="T_7bf14_row3_col2" class="data row3 col2" >0.59</td>
#       <td id="T_7bf14_row3_col3" class="data row3 col3" >17834</td>
#       <td id="T_7bf14_row3_col4" class="data row3 col4" >4783</td>
#       <td id="T_7bf14_row3_col5" class="data row3 col5" >1945</td>
#       <td id="T_7bf14_row3_col6" class="data row3 col6" >377</td>
#       <td id="T_7bf14_row3_col7" class="data row3 col7" >93.50</td>
#       <td id="T_7bf14_row3_col8" class="data row3 col8" >-20.05</td>
#       <td id="T_7bf14_row3_col9" class="data row3 col9" >11</td>
#     </tr>
#     <tr>
#       <th id="T_7bf14_level0_row4" class="row_heading level0 row4" >118729</th>
#       <td id="T_7bf14_row4_col0" class="data row4 col0" >8394</td>
#       <td id="T_7bf14_row4_col1" class="data row4 col1" >2593268</td>
#       <td id="T_7bf14_row4_col2" class="data row4 col2" >0.42</td>
#       <td id="T_7bf14_row4_col3" class="data row4 col3" >9481</td>
#       <td id="T_7bf14_row4_col4" class="data row4 col4" >6895</td>
#       <td id="T_7bf14_row4_col5" class="data row4 col5" >1946</td>
#       <td id="T_7bf14_row4_col6" class="data row4 col6" >395</td>
#       <td id="T_7bf14_row4_col7" class="data row4 col7" >119.71</td>
#       <td id="T_7bf14_row4_col8" class="data row4 col8" >-11.30</td>
#       <td id="T_7bf14_row4_col9" class="data row4 col9" >8</td>
#     </tr>
#     <tr>
#       <th id="T_7bf14_level0_row5" class="row_heading level0 row5" >99576</th>
#       <td id="T_7bf14_row5_col0" class="data row5 col0" >16228</td>
#       <td id="T_7bf14_row5_col1" class="data row5 col1" >272893</td>
#       <td id="T_7bf14_row5_col2" class="data row5 col2" >0.62</td>
#       <td id="T_7bf14_row5_col3" class="data row5 col3" >15766</td>
#       <td id="T_7bf14_row5_col4" class="data row5 col4" >2297</td>
#       <td id="T_7bf14_row5_col5" class="data row5 col5" >1943</td>
#       <td id="T_7bf14_row5_col6" class="data row5 col6" >358</td>
#       <td id="T_7bf14_row5_col7" class="data row5 col7" >113.70</td>
#       <td id="T_7bf14_row5_col8" class="data row5 col8" >-11.13</td>
#       <td id="T_7bf14_row5_col9" class="data row5 col9" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7bf14_level0_row6" class="row_heading level0 row6" >99023</th>
#       <td id="T_7bf14_row6_col0" class="data row6 col0" >12520</td>
#       <td id="T_7bf14_row6_col1" class="data row6 col1" >156640</td>
#       <td id="T_7bf14_row6_col2" class="data row6 col2" >0.40</td>
#       <td id="T_7bf14_row6_col3" class="data row6 col3" >17152</td>
#       <td id="T_7bf14_row6_col4" class="data row6 col4" >2994</td>
#       <td id="T_7bf14_row6_col5" class="data row6 col5" >1937</td>
#       <td id="T_7bf14_row6_col6" class="data row6 col6" >217</td>
#       <td id="T_7bf14_row6_col7" class="data row6 col7" >202.27</td>
#       <td id="T_7bf14_row6_col8" class="data row6 col8" >-9.60</td>
#       <td id="T_7bf14_row6_col9" class="data row6 col9" >6</td>
#     </tr>
#     <tr>
#       <th id="T_7bf14_level0_row7" class="row_heading level0 row7" >41029</th>
#       <td id="T_7bf14_row7_col0" class="data row7 col0" >7896</td>
#       <td id="T_7bf14_row7_col1" class="data row7 col1" >1709218</td>
#       <td id="T_7bf14_row7_col2" class="data row7 col2" >0.65</td>
#       <td id="T_7bf14_row7_col3" class="data row7 col3" >10836</td>
#       <td id="T_7bf14_row7_col4" class="data row7 col4" >5393</td>
#       <td id="T_7bf14_row7_col5" class="data row7 col5" >1950</td>
#       <td id="T_7bf14_row7_col6" class="data row7 col6" >510</td>
#       <td id="T_7bf14_row7_col7" class="data row7 col7" >89.14</td>
#       <td id="T_7bf14_row7_col8" class="data row7 col8" >-13.31</td>
#       <td id="T_7bf14_row7_col9" class="data row7 col9" >6</td>
#     </tr>
#     <tr>
#       <th id="T_7bf14_level0_row8" class="row_heading level0 row8" >48835</th>
#       <td id="T_7bf14_row8_col0" class="data row8 col0" >20192</td>
#       <td id="T_7bf14_row8_col1" class="data row8 col1" >763952</td>
#       <td id="T_7bf14_row8_col2" class="data row8 col2" >0.50</td>
#       <td id="T_7bf14_row8_col3" class="data row8 col3" >15350</td>
#       <td id="T_7bf14_row8_col4" class="data row8 col4" >101</td>
#       <td id="T_7bf14_row8_col5" class="data row8 col5" >1952</td>
#       <td id="T_7bf14_row8_col6" class="data row8 col6" >573</td>
#       <td id="T_7bf14_row8_col7" class="data row8 col7" >124.12</td>
#       <td id="T_7bf14_row8_col8" class="data row8 col8" >-11.72</td>
#       <td id="T_7bf14_row8_col9" class="data row8 col9" >2</td>
#     </tr>
#     <tr>
#       <th id="T_7bf14_level0_row9" class="row_heading level0 row9" >78128</th>
#       <td id=

# %%
sdf.display(df2,pivot_columns=['popularity'])
# Out:
# for creating new table vectors, it took 0:00:09.640151
# for summary creation, it took 0:00:03.248407
# calculating rules for this dataset
# found 93 rules
# 100%|██████████████████████████████████████████████████████████████████████████████████| 28/28 [00:00<00:00, 39.43it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 286.23it/s]
# for or summary creation, it took 0:00:34.584150
# added the following columns instead of the previously displayed as they are more informative for this dataset
# {'instrumentalness'}
# <style type="text/css">
# #T_41eac .pd-t {
#   visibility: hidden;
#   position: absolute;
#   z-index: 1;
#   background-color: black;
#   color: white;
#   transform: translate(-20px, -20px);
# }
# #T_41eac #T_41eac_row0_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_41eac #T_41eac_row0_col2 .pd-t::after {
#   content: "Rule #39: {(instrumentalness = (0.3, 1.0]),(popularity = (-1.0, 5.0]),} ---> {(acousticness = acousticness_4),}, support=0.33, confidence = 0.8, lift = 1.2";
# }
# #T_41eac #T_41eac_row0_col7:hover .pd-t {
#   visibility: visible;
# }
# #T_41eac #T_41eac_row0_col7 .pd-t::after {
#   content: "Rule #39: {(instrumentalness = (0.3, 1.0]),(popularity = (-1.0, 5.0]),} ---> {(acousticness = acousticness_4),}, support=0.33, confidence = 0.8, lift = 1.2";
# }
# #T_41eac #T_41eac_row0_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_41eac #T_41eac_row0_col9 .pd-t::after {
#   content: "Rule #39: {(instrumentalness = (0.3, 1.0]),(popularity = (-1.0, 5.0]),} ---> {(acousticness = acousticness_4),}, support=0.33, confidence = 0.8, lift = 1.2";
# }
# #T_41eac #T_41eac_row1_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_41eac #T_41eac_row1_col2 .pd-t::after {
#   content: "Rule #43: {(popularity = (-1.0, 5.0]),(year = (1920.0, 1952.0]),} ---> {(acousticness = acousticness_4),}, support=0.6, confidence = 0.68, lift = 1.03";
# }
# #T_41eac #T_41eac_row1_col6:hover .pd-t {
#   visibility: visible;
# }
# #T_41eac #T_41eac_row1_col6 .pd-t::after {
#   content: "Rule #43: {(popularity = (-1.0, 5.0]),(year = (1920.0, 1952.0]),} ---> {(acousticness = acousticness_4),}, support=0.6, confidence = 0.68, lift = 1.03";
# }
# #T_41eac #T_41eac_row1_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_41eac #T_41eac_row1_col9 .pd-t::after {
#   content: "Rule #43: {(popularity = (-1.0, 5.0]),(year = (1920.0, 1952.0]),} ---> {(acousticness = acousticness_4),}, support=0.6, confidence = 0.68, lift = 1.03";
# }
# #T_41eac #T_41eac_row2_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_41eac #T_41eac_row2_col3 .pd-t::after {
#   content: "Rule #49: {(loudness = (-61.0, -16.0]),(popularity = (-1.0, 5.0]),} ---> {(energy = energy_0),}, support=0.34, confidence = 0.77, lift = 1.66";
# }
# #T_41eac #T_41eac_row2_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_41eac #T_41eac_row2_col4 .pd-t::after {
#   content: "Rule #49: {(loudness = (-61.0, -16.0]),(popularity = (-1.0, 5.0]),} ---> {(energy = energy_0),}, support=0.34, confidence = 0.77, lift = 1.66";
# }
# #T_41eac #T_41eac_row2_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_41eac #T_41eac_row2_col9 .pd-t::after {
#   content: "Rule #49: {(loudness = (-61.0, -16.0]),(popularity = (-1.0, 5.0]),} ---> {(energy = energy_0),}, support=0.34, confidence = 0.77, lift = 1.66";
# }
# #T_41eac #T_41eac_row3_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_41eac #T_41eac_row3_col2 .pd-t::after {
#   content: "Rule #31: {(energy = (-0.1, 0.2]),(popularity = (-1.0, 5.0]),} ---> {(acousticness = acousticness_4),}, support=0.35, confidence = 0.76, lift = 1.14";
# }
# #T_41eac #T_41eac_row3_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_41eac #T_41eac_row3_col4 .pd-t::after {
#   content: "Rule #31: {(energy = (-0.1, 0.2]),(popularity = (-1.0, 5.0]),} ---> {(acousticness = acousticness_4),}, support=0.35, confidence = 0.76, lift = 1.14";
# }
# #T_41eac #T_41eac_row3_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_41eac #T_41eac_row3_col9 .pd-t::after {
#   content: "Rule #31: {(energy = (-0.1, 0.2]),(popularity = (-1.0, 5.0]),} ---> {(acousticness = acousticness_4),}, support=0.35, confidence = 0.76, lift = 1.14";
# }
# #T_41eac #T_41eac_row4_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_41eac #T_41eac_row4_col2 .pd-t::after {
#   content: "Rule #80: {(instrumentalness = (0.3, 1.0]),(popularity = (-1.0, 5.0]),(year = (1920.0, 1952.0]),} ---> {(acousticness = acousticness_4),}, support=0.31, confidence = 0.82, lift = 1.23";
# }
# #T_41eac #T_41eac_row4_col6:hover .pd-t {
#   visibility: visible;
# }
# #T_41eac #T_41eac_row4_col6 .pd-t::after {
#   content: "Rule #80: {(instrumentalness = (0.3, 1.0]),(popularity = (-1.0, 5.0]),(year = (1920.0, 1952.0]),} ---> {(acousticness = acousticness_4),}, support=0.31, confidence = 0.82, lift = 1.23";
# }
# #T_41eac #T_41eac_row4_col7:hover .pd-t {
#   visibility: visible;
# }
# #T_41eac #T_41eac_row4_col7 .pd-t::after {
#   content: "Rule #80: {(instrumentalness = (0.3, 1.0]),(popularity = (-1.0, 5.0]),(year = (1920.0, 1952.0]),} ---> {(acousticness = acousticness_4),}, support=0.31, confidence = 0.82, lift = 1.23";
# }
# #T_41eac #T_41eac_row4_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_41eac #T_41eac_row4_col9 .pd-t::after {
#   content: "Rule #80: {(instrumentalness = (0.3, 1.0]),(popularity = (-1.0, 5.0]),(year = (1920.0, 1952.0]),} ---> {(acousticness = acousticness_4),}, support=0.31, confidence = 0.82, lift = 1.23";
# }
# #T_41eac #T_41eac_row5_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_41eac #T_41eac_row5_col2 .pd-t::after {
#   content: "Rule #40: {(instrumentalness = (0.3, 1.0]),(year = (1920.0, 1952.0]),} ---> {(acousticness = acousticness_4),}, support=0.31, confidence = 0.82, lift = 1.23";
# }
# #T_41eac #T_41eac_row5_col6:hover .pd-t {
#   visibility: visible;
# }
# #T_41eac #T_41eac_row5_col6 .pd-t::after {
#   content: "Rule #40: {(instrumentalness = (0.3, 1.0]),(year = (1920.0, 1952.0]),} ---> {(acousticness = acousticness_4),}, support=0.31, confidence = 0.82, lift = 1.23";
# }
# #T_41eac #T_41eac_row5_col7:hover .pd-t {
#   visibility: visible;
# }
# #T_41eac #T_41eac_row5_col7 .pd-t::after {
#   content: "Rule #40: {(instrumentalness = (0.3, 1.0]),(year = (1920.0, 1952.0]),} ---> {(acousticness = acousticness_4),}, support=0.31, confidence = 0.82, lift = 1.23";
# }
# #T_41eac #T_41eac_row6_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_41eac #T_41eac_row6_col2 .pd-t::after {
#   content: "Rule #71: {(acousticness = (0.9, 1.0]),(energy = (-0.1, 0.2]),(year = (1920.0, 1952.0]),} ---> {(popularity = popularity_0),}, support=0.31, confidence = 1.0, lift = 1.0";
# }
# #T_41eac #T_41eac_row6_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_41eac #T_41eac_row6_col4 .pd-t::after {
#   content: "Rule #71: {(acousticness = (0.9, 1.0]),(energy = (-0.1, 0.2]),(year = (1920.0, 1952.0]),} ---> {(popularity = popularity_0),}, support=0.31, confidence = 1.0, lift = 1.0";
# }
# #T_41eac #T_41eac_row6_col6:hover .pd-t {
#   visibility: visible;
# }
# #T_41eac #T_41eac_row6_col6 .pd-t::after {
#   content: "Rule #71: {(acousticness = (0.9, 1.0]),(energy = (-0.1, 0.2]),(year = (1920.0, 1952.0]),} ---> {(popularity = popularity_0),}, support=0.31, confidence = 1.0, lift = 1.0";
# }
# #T_41eac #T_41eac_row6_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_41eac #T_41eac_row6_col9 .pd-t::after {
#   content: "Rule #71: {(acousticness = (0.9, 1.0]),(energy = (-0.1, 0.2]),(year = (1920.0, 1952.0]),} ---> {(popularity = popularity_0),}, support=0.31, confidence = 1.0, lift = 1.0";
# }
# #T_41eac #T_41eac_row7_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_41eac #T_41eac_row7_col2 .pd-t::after {
#   content: "Rule #4: {(popularity = (-1.0, 5.0]),} ---> {(acousticness = acousticness_4),}, support=0.66, confidence = 0.66, lift = 1.0";
# }
# #T_41eac #T_41eac_row7_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_41eac #T_41eac_row7_col9 .pd-t::after {
#   content: "Rule #4: {(popularity = (-1.0, 5.0]),} ---> {(acousticness = acousticness_4),}, support=0.66, confidence = 0.66, lift = 1.0";
# }
# #T_41eac #T_41eac_row8_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_41eac #T_41eac_row8_col2 .pd-t::after {
#   content: "Rule #70: {(energy = (-0.1, 0.2]),(popularity = (-1.0, 5.0]),(year = (1920.0, 1952.0]),} ---> {(acousticness = acousticness_4),}, support=0.31, confidence = 0.76, lift = 1.15";
# }
# #T_41eac #T_41eac_row8_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_41eac #T_41eac_row8_col4 .pd-t::after {
#   content: "Rule #70: {(energy = (-0.1, 0.2]),(popularity = (-1.0, 5.0]),(year = (1920.0, 1952.0]),} ---> {(acousticness = acousticness_4),}, support=0.31, confidence = 0.76, lift = 1.15";
# }
# #T_41eac #T_41eac_row8_col6:hover .pd-t {
#   visibility: visible;
# }
# #T_41eac #T_41eac_row8_col6 .pd-t::after {
#   content: "Rule #70: {(ene
