# %%
import pandas as pd



path_sample_df =  'input/spotify_popularity/dataset.csv'
full_df_a = pd.read_csv(path_sample_df)
if 'Unnamed: 0' in full_df_a.columns:
    full_df_a.drop(['Unnamed: 0'], axis=1, inplace=True)
if 'Unnamed: 0.1' in full_df_a.columns:
    full_df_a.drop([ 'Unnamed: 0.1'], axis=1, inplace=True)
if 'index' in full_df_a.columns:
    full_df_a.drop([ 'index'], axis=1, inplace=True)

# %%
from SubTub import Subtub
sdf = Subtub(full_df_a,use_rules=True, subtub_config={'rules':'rules_spotify.csv'})
sdf.display(full_df_a)
# Out:
# the location of provided rules or mapping_bins_to_values is incorrect
# for or summary creation, it took 0:00:20.015221
#        instrumentalness  loudness  duration_ms release_date  key  \
# 82015              0.00    -16.20       152733         1960    7
# 11192              0.00     -6.57       513463   1970-01-01    2
# 97659              0.00     -2.20       177670   2019-04-05   11
# 69138              0.13     -7.85       215040         2005   10
# 46295              0.66     -9.68       191333   2003-01-01    0
# 42020              0.82     -5.80       708220   1960-01-01    1
# 55720              0.00     -6.08       187481   1930-01-01    7
# 88107              0.00    -15.50       182440         1923    7
# 13459              0.00    -23.88       167733   1993-01-01    1
# 34662              0.00     -9.81       127360   1965-06-21    4
#
#        acousticness  popularity  explicit  \
# 82015          0.72          40         0
# 11192          0.93          35         0
# 97659          0.08          77         0
# 69138          0.66          44         0
# 46295          0.08          38         0
# 42020          0.97          10         0
# 55720          0.67           0         0
# 88107          0.98           0         0
# 13459          0.98          39         0
# 34662          0.46          17         0
#
#                                                  artists  energy
# 82015                                    ['Dean Martin']    0.14
# 11192                                         ['Fairuz']    0.28
# 97659                              ['MAX', 'Quinn XCII']    0.86
# 69138                                    ['Leela James']    0.31
# 46295                                            ['War']    0.68
# 42020  ['Manna Dey', 'Asha Bhosle', 'Sudha Malhotra',...    0.80
# 55720                                   ['Sir Lancelot']    0.65
# 88107                                       ['Georgius']    0.46
# 13459                                 ['The Fleetwoods']    0.02
# 34662                                      ['The Byrds']    0.59

# %%
df1 = full_df_a[full_df_a['popularity']>70]

# %%
df1
# Out:
#         acousticness                           artists  danceability  \
# 6754          0.5870                          ['Gala']         0.704
# 7606          0.0251                   ['Mon Laferte']         0.394
# 7845          0.2800               ['Imagine Dragons']         0.301
# 7883          0.0988                         ['TWICE']         0.574
# 7895          0.2390  ['Clean Bandit', 'Zara Larsson']         0.715
# ...              ...                               ...           ...
# 169877        0.0181       ['Agust D', 'Kim Jong Wan']         0.560
# 169885        0.8090                 ['Justin Bieber']         0.566
# 169892        0.1990                      ['CHUNG HA']         0.636
# 169894        0.5920                    ['Noah Cyrus']         0.618
# 169904        0.1730            ['DripReport', 'Tyga']         0.875
#
#         duration_ms  energy  explicit                      id  \
# 6754         213394   0.861         0  3u5N55tHf7hXATSQrjBh2q
# 7606         278547   0.475         0  4skuEIloXWuxxgekKupkEH
# 7845         230289   0.672         0  31VOknKjFrEX47bZXzqcoF
# 7883         208240   0.909         0  1IX47gefluXmKX4PrTBCRM
# 7895         212733   0.605         0  72gv4zhNvRVdQA0eOenCal
# ...             ...     ...       ...                     ...
# 169877       292079   0.735         1  5qJF3xMbNjsPuqQDRkfUl1
# 169885       136907   0.438         0  5Py8zRKGkZvgHniVVtvNCN
# 169892       217239   0.841         0  3As0OA5B06BxLfADvYyG8L
# 169894       190183   0.428         0  0gySkOOewOdZtHG8stPEB8
# 169904       163800   0.443         1  4KppkflX7I3vJQk7urOJaS
#
#         instrumentalness  key  liveness  loudness  mode  \
# 6754            0.061500    2    0.0992    -4.221     0
# 7606            0.007490   10    0.1120    -7.935     1
# 7845            0.000031    2    0.0609    -4.497     1
# 7883            0.000000    8    0.2640    -1.572     1
# 7895            0.000014    0    0.1890    -5.128     0
# ...                  ...  ...       ...       ...   ...
# 169877          0.000009    0    0.0571    -6.344     1
# 169885          0.000000    0    0.2120    -7.564     0
# 169892          0.000395    2    0.0836    -1.927     0
# 169894          0.000000    7    0.1920    -8.500     0
# 169904          0.000032    1    0.0891    -7.461     1
#
#                                                name  popularity release_date  \
# 6754                              Freed From Desire          72   2007-04-18
# 7606                             Tu Falta De Querer          71   2015-08-21
# 7845                                     Next To Me          71   2017-06-23
# 7883                                   What is Love          72   2018-07-09
# 7895                  Symphony (feat. Zara Larsson)          74   2018-11-30
# ...                                             ...         ...          ...
# 169877  Dear my friend (feat. Kim Jong Wan of NELL)          72   2020-05-22
# 169885                                All Around Me          72   2020-02-14
# 169892                                 Stay Tonight          74   2020-04-27
# 169894                                  Young & Sad          71   2020-05-15
# 169904                Skechers (feat. Tyga) - Remix          75   2020-05-15
#
#         speechiness    tempo  valence  year
# 6754         0.0493  128.990    0.636  2007
# 7606         0.0280  129.995    0.441  2015
# 7845         0.0623  169.497    0.384  2017
# 7883         0.0655  169.964    0.565  2018
# 7895         0.0428  122.956    0.454  2018
# ...             ...      ...      ...   ...
# 169877       0.0638  148.026    0.270  2020
# 169885       0.0367  117.127    0.692  2020
# 169892       0.0548  121.022    0.506  2020
# 169894       0.0380  142.021    0.359  2020
# 169904       0.1430  100.012    0.306  2020
#
# [3816 rows x 19 columns]

# %%
sdf.display(df1)
# Out:
# for creating new table vectors, it took 0:00:00.631594
# for summary creation, it took 0:00:00.322303
# 100%|████████████████████████████████████████| 249/249 [00:01<00:00, 154.14it/s]
# 100%|███████████████████████████████████████████| 80/80 [00:01<00:00, 76.68it/s]
# 100%|████████████████████████████████████████| 249/249 [00:01<00:00, 167.80it/s]
# 100%|████████████████████████████████████████| 249/249 [00:01<00:00, 186.44it/s]
# 100%|████████████████████████████████████████| 249/249 [00:01<00:00, 165.65it/s]
# 100%|████████████████████████████████████████| 249/249 [00:01<00:00, 194.10it/s]
# 100%|████████████████████████████████████████| 249/249 [00:01<00:00, 188.23it/s]
# 100%|████████████████████████████████████████| 249/249 [00:01<00:00, 193.72it/s]
# 100%|████████████████████████████████████████| 249/249 [00:01<00:00, 194.12it/s]
# 100%|████████████████████████████████████████| 249/249 [00:01<00:00, 207.82it/s]
# 100%|████████████████████████████████████████| 249/249 [00:01<00:00, 174.96it/s]
# 100%|████████████████████████████████████████| 249/249 [00:01<00:00, 178.96it/s]
# {'cell_cov': 0.474, 'jaccard': 0.69}
# for or summary creation, it took 0:00:17.422080
# /specific/disk1/home/kathyr/table_summarization_baselines/debug/../associations_rules_summary/utils_code.py:871: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   display(df.style.apply(style_spec, axis=None).set_precision(2).set_tooltips(create_tooltips_df(df)))
# <style type="text/css">
# #T_2c832_ .pd-t {
#   visibility: hidden;
#   position: absolute;
#   z-index: 1;
#   background-color: black;
#   color: white;
#   transform: translate(-20px, -20px);
# }
# #T_2c832_ #T_2c832_row0_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_2c832_ #T_2c832_row0_col1 .pd-t::after {
#   content: "Rule #239: {(mode = 1),(year = year_2),} ---> {(explicit = 0),}, support=0.14, confidence = 0.99, lift = 1.08";
# }
# #T_2c832_ #T_2c832_row0_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_2c832_ #T_2c832_row0_col2 .pd-t::after {
#   content: "Rule #239: {(mode = 1),(year = year_2),} ---> {(explicit = 0),}, support=0.14, confidence = 0.99, lift = 1.08";
# }
# #T_2c832_ #T_2c832_row0_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_2c832_ #T_2c832_row0_col4 .pd-t::after {
#   content: "Rule #239: {(mode = 1),(year = year_2),} ---> {(explicit = 0),}, support=0.14, confidence = 0.99, lift = 1.08";
# }
# #T_2c832_ #T_2c832_row2_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_2c832_ #T_2c832_row2_col1 .pd-t::after {
#   content: "Rule #241: {(mode = 1),(year = year_4),} ---> {(explicit = 0),}, support=0.1, confidence = 0.79, lift = 0.86";
# }
# #T_2c832_ #T_2c832_row2_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_2c832_ #T_2c832_row2_col2 .pd-t::after {
#   content: "Rule #241: {(mode = 1),(year = year_4),} ---> {(explicit = 0),}, support=0.1, confidence = 0.79, lift = 0.86";
# }
# #T_2c832_ #T_2c832_row2_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_2c832_ #T_2c832_row2_col4 .pd-t::after {
#   content: "Rule #241: {(mode = 1),(year = year_4),} ---> {(explicit = 0),}, support=0.1, confidence = 0.79, lift = 0.86";
# }
# #T_2c832_ #T_2c832_row3_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_2c832_ #T_2c832_row3_col1 .pd-t::after {
#   content: "Rule #5: {(mode = 1),} ---> {(acousticness = acousticness_1),}, support=0.14, confidence = 0.2, lift = 0.98";
# }
# #T_2c832_ #T_2c832_row3_col5:hover .pd-t {
#   visibility: visible;
# }
# #T_2c832_ #T_2c832_row3_col5 .pd-t::after {
#   content: "Rule #5: {(mode = 1),} ---> {(acousticness = acousticness_1),}, support=0.14, confidence = 0.2, lift = 0.98";
# }
# #T_2c832_ #T_2c832_row4_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_2c832_ #T_2c832_row4_col1 .pd-t::after {
#   content: "Rule #242: {(explicit = 0),(year = year_4),} ---> {(mode = 1),}, support=0.1, confidence = 0.69, lift = 0.98";
# }
# #T_2c832_ #T_2c832_row4_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_2c832_ #T_2c832_row4_col2 .pd-t::after {
#   content: "Rule #242: {(explicit = 0),(year = year_4),} ---> {(mode = 1),}, support=0.1, confidence = 0.69, lift = 0.98";
# }
# #T_2c832_ #T_2c832_row4_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_2c832_ #T_2c832_row4_col4 .pd-t::after {
#   content: "Rule #242: {(explicit = 0),(year = year_4),} ---> {(mode = 1),}, support=0.1, confidence = 0.69, lift = 0.98";
# }
# #T_2c832_ #T_2c832_row5_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_2c832_ #T_2c832_row5_col1 .pd-t::after {
#   content: "Rule #234: {(mode = 1),(valence = valence_3),} ---> {(explicit = 0),}, support=0.13, confidence = 0.92, lift = 1.01";
# }
# #T_2c832_ #T_2c832_row5_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_2c832_ #T_2c832_row5_col2 .pd-t::after {
#   content: "Rule #234: {(mode = 1),(valence = valence_3),} ---> {(explicit = 0),}, support=0.13, confidence = 0.92, lift = 1.01";
# }
# #T_2c832_ #T_2c832_row5_col8:hover .pd-t {
#   visibility: visible;
# }
# #T_2c832_ #T_2c832_row5_col8 .pd-t::after {
#   content: "Rule #234: {(mode = 1),(valence = valence_3),} ---> {(explicit = 0),}, support=0.13, confidence = 0.92, lift = 1.01";
# }
# #T_2c832_ #T_2c832_row6_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_2c832_ #T_2c832_row6_col1 .pd-t::after {
#   content: "Rule #232: {(mode = 1),(valence = valence_1),} ---> {(explicit = 0),}, support=0.13, confidence = 0.92, lift = 1.0";
# }
# #T_2c832_ #T_2c832_row6_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_2c832_ #T_2c832_row6_col2 .pd-t::after {
#   content: "Rule #232: {(mode = 1),(valence = valence_1),} ---> {(explicit = 0),}, support=0.13, confidence = 0.92, lift = 1.0";
# }
# #T_2c832_ #T_2c832_row6_col8:hover .pd-t {
#   visibility: visible;
# }
# #T_2c832_ #T_2c832_row6_col8 .pd-t::after {
#   content: "Rule #232: {(mode = 1),(valence = valence_1),} ---> {(explicit = 0),}, support=0.13, confidence = 0.92, lift = 1.0";
# }
# #T_2c832_ #T_2c832_row7_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_2c832_ #T_2c832_row7_col0 .pd-t::after {
#   content: "Rule #195: {(explicit = 0),(loudness = loudness_4),} ---> {(energy = energy_4),}, support=0.1, confidence = 0.63, lift = 3.15";
# }
# #T_2c832_ #T_2c832_row7_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_2c832_ #T_2c832_row7_col2 .pd-t::after {
#   content: "Rule #195: {(explicit = 0),(loudness = loudness_4),} ---> {(energy = energy_4),}, support=0.1, confidence = 0.63, lift = 3.15";
# }
# #T_2c832_ #T_2c832_row7_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_2c832_ #T_2c832_row7_col3 .pd-t::after {
#   content: "Rule #195: {(explicit = 0),(loudness = loudness_4),} ---> {(energy = energy_4),}, support=0.1, confidence = 0.63, lift = 3.15";
# }
# #T_2c832_ #T_2c832_row8_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_2c832_ #T_2c832_row8_col2 .pd-t::after {
#   content: "Rule #3: {(explicit = 0),} ---> {(acousticness = acousticness_1),}, support=0.17, confidence = 0.18, lift = 0.91";
# }
# #T_2c832_ #T_2c832_row8_col5:hover .pd-t {
#   visibility: visible;
# }
# #T_2c832_ #T_2c832_row8_col5 .pd-t::after {
#   content: "Rule #3: {(explicit = 0),} ---> {(acousticness = acousticness_1),}, support=0.17, confidence = 0.18, lift = 0.91";
# }
# #T_2c832_ #T_2c832_row9_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_2c832_ #T_2c832_row9_col3 .pd-t::after {
#   content: "Rule #0: {(energy = energy_4),} ---> {(acousticness = acousticness_0),}, support=0.11, confidence = 0.57, lift = 2.85";
# }
# #T_2c832_ #T_2c832_row9_col5:hover .pd-t {
#   visibility: visible;
# }
# #T_2c832_ #T_2c832_row9_col5 .pd-t::after {
#   content: "Rule #0: {(energy = energy_4),} ---> {(acousticness = acousticness_0),}, support=0.11, confidence = 0.57, lift = 2.85";
# }
# #T_2c832_row0_col1, #T_2c832_row0_col2, #T_2c832_row0_col4 {
#   background-color: pink;
# }
# #T_2c832_row2_col1, #T_2c832_row2_col2, #T_2c832_row2_col4 {
#   background-color: gray;
# }
# #T_2c832_row3_col1, #T_2c832_row3_col5 {
#   background-color: purple;
# }
# #T_2c832_row4_col1, #T_2c832_row4_col2, #T_2c832_row4_col4 {
#   background-color: lightblue;
# }
# #T_2c832_row5_col1, #T_2c832_row5_col2, #T_2c832_row5_col8 {
#   background-color: red;
# }
# #T_2c832_row6_col1, #T_2c832_row6_col2, #T_2c832_row6_col8 {
#   background-color: blue;
# }
# #T_2c832_row7_col0, #T_2c832_row7_col2, #T_2c832_row7_col3 {
#   background-color: orange;
# }
# #T_2c832_row8_col2, #T_2c832_row8_col5 {
#   background-color: yellow;
# }
# #T_2c832_row9_col3, #T_2c832_row9_col5 {
#   background-color: darkgrey;
# }
# </style>
# <table id="T_2c832_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >loudness</th>
#       <th class="col_heading level0 col1" >mode</th>
#       <th class="col_heading level0 col2" >explicit</th>
#       <th class="col_heading level0 col3" >energy</th>
#       <th class="col_heading level0 col4" >year</th>
#       <th class="col_heading level0 col5" >acousticness</th>
#       <th class="col_heading level0 col6" >key</th>
#       <th class="col_heading level0 col7" >speechiness</th>
#       <th class="col_heading level0 col8" >valence</th>
#       <th class="col_heading level0 col9" >danceability</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2c832_level0_row0" class="row_heading level0 row0" >84240</th>
#       <td id="T_2c832_row0_col0" class="data row0 col0" >-2.99<span class="pd-t"></span></td>
#       <td id="T_2c832_row0_col1" class="data row0 col1" >1<span class="pd-t"></span></td>
#       <td id="T_2c832_row0_col2" class="data row0 col2" >0<span class="pd-t"></span></td>
#       <td id="T_2c832_row0_col3" class="data row0 col3" >0.94<span class="pd-t"></span></td>
#       <td id="T_2c832_row0_col4" class="data row0 col4" >1983<span class="pd-t"></span></td>
#       <td id="T_2c8
