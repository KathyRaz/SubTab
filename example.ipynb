# %%
import pandas as pd



path_sample_df =  'input/spotify_dataset.csv'
full_df_a = pd.read_csv(path_sample_df)
if 'Unnamed: 0' in full_df_a.columns:
    full_df_a.drop(['Unnamed: 0'], axis=1, inplace=True)
if 'Unnamed: 0.1' in full_df_a.columns:
    full_df_a.drop([ 'Unnamed: 0.1'], axis=1, inplace=True)
if 'index' in full_df_a.columns:
    full_df_a.drop([ 'index'], axis=1, inplace=True)

# %%
from SubTub import SubTub
sdf = SubTub(full_df_a,use_rules=True, subtub_config={'rules':'rules_spotify.csv'})
sdf.display(full_df_a)
# Out:
# 100%|██████████| 55/55 [00:03<00:00, 13.91it/s]
# {'cell_cov': 0.267, 'jaccard': 0.77}
# for or summary creation, it took 0:00:24.862706
# <style type="text/css">
# #T_90ee4 .pd-t {
#   visibility: hidden;
#   position: absolute;
#   z-index: 1;
#   background-color: black;
#   color: white;
#   transform: translate(-20px, -20px);
# }
# #T_90ee4 #T_90ee4_row0_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_90ee4 #T_90ee4_row0_col4 .pd-t::after {
#   content: "Rule #213: {(loudness = loudness_4),(mode = 1),} ---> {(explicit = 0),}, support=0.11, confidence = 0.84, lift = 0.92";
# }
# #T_90ee4 #T_90ee4_row0_col8:hover .pd-t {
#   visibility: visible;
# }
# #T_90ee4 #T_90ee4_row0_col8 .pd-t::after {
#   content: "Rule #213: {(loudness = loudness_4),(mode = 1),} ---> {(explicit = 0),}, support=0.11, confidence = 0.84, lift = 0.92";
# }
# #T_90ee4 #T_90ee4_row0_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_90ee4 #T_90ee4_row0_col9 .pd-t::after {
#   content: "Rule #213: {(loudness = loudness_4),(mode = 1),} ---> {(explicit = 0),}, support=0.11, confidence = 0.84, lift = 0.92";
# }
# #T_90ee4 #T_90ee4_row1_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_90ee4 #T_90ee4_row1_col1 .pd-t::after {
#   content: "Rule #166: {(explicit = 0),(loudness = loudness_0),} ---> {(acousticness = acousticness_4),}, support=0.1, confidence = 0.54, lift = 2.71";
# }
# #T_90ee4 #T_90ee4_row1_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_90ee4 #T_90ee4_row1_col4 .pd-t::after {
#   content: "Rule #166: {(explicit = 0),(loudness = loudness_0),} ---> {(acousticness = acousticness_4),}, support=0.1, confidence = 0.54, lift = 2.71";
# }
# #T_90ee4 #T_90ee4_row1_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_90ee4 #T_90ee4_row1_col9 .pd-t::after {
#   content: "Rule #166: {(explicit = 0),(loudness = loudness_0),} ---> {(acousticness = acousticness_4),}, support=0.1, confidence = 0.54, lift = 2.71";
# }
# #T_90ee4 #T_90ee4_row2_col6:hover .pd-t {
#   visibility: visible;
# }
# #T_90ee4 #T_90ee4_row2_col6 .pd-t::after {
#   content: "Rule #215: {(mode = 1),(popularity = popularity_1),} ---> {(explicit = 0),}, support=0.15, confidence = 1.0, lift = 1.09";
# }
# #T_90ee4 #T_90ee4_row2_col8:hover .pd-t {
#   visibility: visible;
# }
# #T_90ee4 #T_90ee4_row2_col8 .pd-t::after {
#   content: "Rule #215: {(mode = 1),(popularity = popularity_1),} ---> {(explicit = 0),}, support=0.15, confidence = 1.0, lift = 1.09";
# }
# #T_90ee4 #T_90ee4_row2_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_90ee4 #T_90ee4_row2_col9 .pd-t::after {
#   content: "Rule #215: {(mode = 1),(popularity = popularity_1),} ---> {(explicit = 0),}, support=0.15, confidence = 1.0, lift = 1.09";
# }
# #T_90ee4 #T_90ee4_row3_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_90ee4 #T_90ee4_row3_col1 .pd-t::after {
#   content: "Rule #3: {(explicit = 0),} ---> {(acousticness = acousticness_1),}, support=0.17, confidence = 0.18, lift = 0.91";
# }
# #T_90ee4 #T_90ee4_row3_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_90ee4 #T_90ee4_row3_col9 .pd-t::after {
#   content: "Rule #3: {(explicit = 0),} ---> {(acousticness = acousticness_1),}, support=0.17, confidence = 0.18, lift = 0.91";
# }
# #T_90ee4 #T_90ee4_row4_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_90ee4 #T_90ee4_row4_col1 .pd-t::after {
#   content: "Rule #158: {(explicit = 0),(mode = 1),} ---> {(acousticness = acousticness_0),}, support=0.11, confidence = 0.17, lift = 0.85";
# }
# #T_90ee4 #T_90ee4_row4_col8:hover .pd-t {
#   visibility: visible;
# }
# #T_90ee4 #T_90ee4_row4_col8 .pd-t::after {
#   content: "Rule #158: {(explicit = 0),(mode = 1),} ---> {(acousticness = acousticness_0),}, support=0.11, confidence = 0.17, lift = 0.85";
# }
# #T_90ee4 #T_90ee4_row4_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_90ee4 #T_90ee4_row4_col9 .pd-t::after {
#   content: "Rule #158: {(explicit = 0),(mode = 1),} ---> {(acousticness = acousticness_0),}, support=0.11, confidence = 0.17, lift = 0.85";
# }
# #T_90ee4 #T_90ee4_row6_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_90ee4 #T_90ee4_row6_col1 .pd-t::after {
#   content: "Rule #161: {(explicit = 0),(mode = 1),} ---> {(acousticness = acousticness_1),}, support=0.12, confidence = 0.18, lift = 0.91";
# }
# #T_90ee4 #T_90ee4_row6_col8:hover .pd-t {
#   visibility: visible;
# }
# #T_90ee4 #T_90ee4_row6_col8 .pd-t::after {
#   content: "Rule #161: {(explicit = 0),(mode = 1),} ---> {(acousticness = acousticness_1),}, support=0.12, confidence = 0.18, lift = 0.91";
# }
# #T_90ee4 #T_90ee4_row6_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_90ee4 #T_90ee4_row6_col9 .pd-t::after {
#   content: "Rule #161: {(explicit = 0),(mode = 1),} ---> {(acousticness = acousticness_1),}, support=0.12, confidence = 0.18, lift = 0.91";
# }
# #T_90ee4 #T_90ee4_row7_col6:hover .pd-t {
#   visibility: visible;
# }
# #T_90ee4 #T_90ee4_row7_col6 .pd-t::after {
#   content: "Rule #216: {(mode = 1),(popularity = popularity_2),} ---> {(explicit = 0),}, support=0.14, confidence = 0.97, lift = 1.05";
# }
# #T_90ee4 #T_90ee4_row7_col8:hover .pd-t {
#   visibility: visible;
# }
# #T_90ee4 #T_90ee4_row7_col8 .pd-t::after {
#   content: "Rule #216: {(mode = 1),(popularity = popularity_2),} ---> {(explicit = 0),}, support=0.14, confidence = 0.97, lift = 1.05";
# }
# #T_90ee4 #T_90ee4_row7_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_90ee4 #T_90ee4_row7_col9 .pd-t::after {
#   content: "Rule #216: {(mode = 1),(popularity = popularity_2),} ---> {(explicit = 0),}, support=0.14, confidence = 0.97, lift = 1.05";
# }
# #T_90ee4 #T_90ee4_row8_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_90ee4 #T_90ee4_row8_col4 .pd-t::after {
#   content: "Rule #209: {(loudness = loudness_0),(mode = 1),} ---> {(explicit = 0),}, support=0.13, confidence = 0.95, lift = 1.04";
# }
# #T_90ee4 #T_90ee4_row8_col8:hover .pd-t {
#   visibility: visible;
# }
# #T_90ee4 #T_90ee4_row8_col8 .pd-t::after {
#   content: "Rule #209: {(loudness = loudness_0),(mode = 1),} ---> {(explicit = 0),}, support=0.13, confidence = 0.95, lift = 1.04";
# }
# #T_90ee4 #T_90ee4_row8_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_90ee4 #T_90ee4_row8_col9 .pd-t::after {
#   content: "Rule #209: {(loudness = loudness_0),(mode = 1),} ---> {(explicit = 0),}, support=0.13, confidence = 0.95, lift = 1.04";
# }
# #T_90ee4 #T_90ee4_row9_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_90ee4 #T_90ee4_row9_col1 .pd-t::after {
#   content: "Rule #162: {(explicit = 0),(mode = 1),} ---> {(acousticness = acousticness_2),}, support=0.14, confidence = 0.21, lift = 1.04";
# }
# #T_90ee4 #T_90ee4_row9_col8:hover .pd-t {
#   visibility: visible;
# }
# #T_90ee4 #T_90ee4_row9_col8 .pd-t::after {
#   content: "Rule #162: {(explicit = 0),(mode = 1),} ---> {(acousticness = acousticness_2),}, support=0.14, confidence = 0.21, lift = 1.04";
# }
# #T_90ee4 #T_90ee4_row9_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_90ee4 #T_90ee4_row9_col9 .pd-t::after {
#   content: "Rule #162: {(explicit = 0),(mode = 1),} ---> {(acousticness = acousticness_2),}, support=0.14, confidence = 0.21, lift = 1.04";
# }
# #T_90ee4_row0_col4, #T_90ee4_row0_col8, #T_90ee4_row0_col9 {
#   background-color: yellow;
# }
# #T_90ee4_row1_col1, #T_90ee4_row1_col4, #T_90ee4_row1_col9 {
#   background-color: blue;
# }
# #T_90ee4_row2_col6, #T_90ee4_row2_col8, #T_90ee4_row2_col9 {
#   background-color: darkgrey;
# }
# #T_90ee4_row3_col1, #T_90ee4_row3_col9 {
#   background-color: pink;
# }
# #T_90ee4_row4_col1, #T_90ee4_row4_col8, #T_90ee4_row4_col9 {
#   background-color: red;
# }
# #T_90ee4_row6_col1, #T_90ee4_row6_col8, #T_90ee4_row6_col9 {
#   background-color: gray;
# }
# #T_90ee4_row7_col6, #T_90ee4_row7_col8, #T_90ee4_row7_col9 {
#   background-color: green;
# }
# #T_90ee4_row8_col4, #T_90ee4_row8_col8, #T_90ee4_row8_col9 {
#   background-color: orange;
# }
# #T_90ee4_row9_col1, #T_90ee4_row9_col8, #T_90ee4_row9_col9 {
#   background-color: purple;
# }
# </style>
# <table id="T_90ee4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_90ee4_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_90ee4_level0_col1" class="col_heading level0 col1" >acousticness</th>
#       <th id="T_90ee4_level0_col2" class="col_heading level0 col2" >release_date</th>
#       <th id="T_90ee4_level0_col3" class="col_heading level0 col3" >duration_ms</th>
#       <th id="T_90ee4_level0_col4" class="col_heading level0 col4" >loudness</th>
#       <th id="T_90ee4_level0_col

# %%
df1 = full_df_a[full_df_a['popularity']>70]

# %%
df1
# Out:
#         acousticness                           artists  danceability  \
# 6754          0.5870                          ['Gala']         0.704
# 7606          0.0251                   ['Mon Laferte']         0.394
# 7845          0.2800               ['Imagine Dragons']         0.301
# 7883          0.0988                         ['TWICE']         0.574
# 7895          0.2390  ['Clean Bandit', 'Zara Larsson']         0.715
# ...              ...                               ...           ...
# 169877        0.0181       ['Agust D', 'Kim Jong Wan']         0.560
# 169885        0.8090                 ['Justin Bieber']         0.566
# 169892        0.1990                      ['CHUNG HA']         0.636
# 169894        0.5920                    ['Noah Cyrus']         0.618
# 169904        0.1730            ['DripReport', 'Tyga']         0.875
#
#         duration_ms  energy  explicit                      id  \
# 6754         213394   0.861         0  3u5N55tHf7hXATSQrjBh2q
# 7606         278547   0.475         0  4skuEIloXWuxxgekKupkEH
# 7845         230289   0.672         0  31VOknKjFrEX47bZXzqcoF
# 7883         208240   0.909         0  1IX47gefluXmKX4PrTBCRM
# 7895         212733   0.605         0  72gv4zhNvRVdQA0eOenCal
# ...             ...     ...       ...                     ...
# 169877       292079   0.735         1  5qJF3xMbNjsPuqQDRkfUl1
# 169885       136907   0.438         0  5Py8zRKGkZvgHniVVtvNCN
# 169892       217239   0.841         0  3As0OA5B06BxLfADvYyG8L
# 169894       190183   0.428         0  0gySkOOewOdZtHG8stPEB8
# 169904       163800   0.443         1  4KppkflX7I3vJQk7urOJaS
#
#         instrumentalness  key  liveness  loudness  mode  \
# 6754            0.061500    2    0.0992    -4.221     0
# 7606            0.007490   10    0.1120    -7.935     1
# 7845            0.000031    2    0.0609    -4.497     1
# 7883            0.000000    8    0.2640    -1.572     1
# 7895            0.000014    0    0.1890    -5.128     0
# ...                  ...  ...       ...       ...   ...
# 169877          0.000009    0    0.0571    -6.344     1
# 169885          0.000000    0    0.2120    -7.564     0
# 169892          0.000395    2    0.0836    -1.927     0
# 169894          0.000000    7    0.1920    -8.500     0
# 169904          0.000032    1    0.0891    -7.461     1
#
#                                                name  popularity release_date  \
# 6754                              Freed From Desire          72   2007-04-18
# 7606                             Tu Falta De Querer          71   2015-08-21
# 7845                                     Next To Me          71   2017-06-23
# 7883                                   What is Love          72   2018-07-09
# 7895                  Symphony (feat. Zara Larsson)          74   2018-11-30
# ...                                             ...         ...          ...
# 169877  Dear my friend (feat. Kim Jong Wan of NELL)          72   2020-05-22
# 169885                                All Around Me          72   2020-02-14
# 169892                                 Stay Tonight          74   2020-04-27
# 169894                                  Young & Sad          71   2020-05-15
# 169904                Skechers (feat. Tyga) - Remix          75   2020-05-15
#
#         speechiness    tempo  valence  year
# 6754         0.0493  128.990    0.636  2007
# 7606         0.0280  129.995    0.441  2015
# 7845         0.0623  169.497    0.384  2017
# 7883         0.0655  169.964    0.565  2018
# 7895         0.0428  122.956    0.454  2018
# ...             ...      ...      ...   ...
# 169877       0.0638  148.026    0.270  2020
# 169885       0.0367  117.127    0.692  2020
# 169892       0.0548  121.022    0.506  2020
# 169894       0.0380  142.021    0.359  2020
# 169904       0.1430  100.012    0.306  2020
#
# [3816 rows x 19 columns]

# %%
sdf.display(df1)
# Out:
# for creating new table vectors, it took 0:00:00.798500
# for summary creation, it took 0:00:00.327914
# 100%|██████████| 46/46 [00:00<00:00, 73.87it/s]
# {'cell_cov': 0.472, 'jaccard': 0.73}
# for or summary creation, it took 0:00:14.175221
# <style type="text/css">
# #T_48bc2 .pd-t {
#   visibility: hidden;
#   position: absolute;
#   z-index: 1;
#   background-color: black;
#   color: white;
#   transform: translate(-20px, -20px);
# }
# #T_48bc2 #T_48bc2_row0_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_48bc2 #T_48bc2_row0_col2 .pd-t::after {
#   content: "Rule #129: {(year = year_4),} ---> {(loudness = loudness_4),}, support=0.11, confidence = 0.54, lift = 2.7";
# }
# #T_48bc2 #T_48bc2_row0_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_48bc2 #T_48bc2_row0_col4 .pd-t::after {
#   content: "Rule #129: {(year = year_4),} ---> {(loudness = loudness_4),}, support=0.11, confidence = 0.54, lift = 2.7";
# }
# #T_48bc2 #T_48bc2_row1_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_48bc2 #T_48bc2_row1_col1 .pd-t::after {
#   content: "Rule #6: {(explicit = 0),} ---> {(acousticness = acousticness_2),}, support=0.19, confidence = 0.2, lift = 1.01";
# }
# #T_48bc2 #T_48bc2_row1_col8:hover .pd-t {
#   visibility: visible;
# }
# #T_48bc2 #T_48bc2_row1_col8 .pd-t::after {
#   content: "Rule #6: {(explicit = 0),} ---> {(acousticness = acousticness_2),}, support=0.19, confidence = 0.2, lift = 1.01";
# }
# #T_48bc2 #T_48bc2_row2_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_48bc2 #T_48bc2_row2_col1 .pd-t::after {
#   content: "Rule #3: {(explicit = 0),} ---> {(acousticness = acousticness_1),}, support=0.17, confidence = 0.18, lift = 0.91";
# }
# #T_48bc2 #T_48bc2_row2_col8:hover .pd-t {
#   visibility: visible;
# }
# #T_48bc2 #T_48bc2_row2_col8 .pd-t::after {
#   content: "Rule #3: {(explicit = 0),} ---> {(acousticness = acousticness_1),}, support=0.17, confidence = 0.18, lift = 0.91";
# }
# #T_48bc2 #T_48bc2_row3_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_48bc2 #T_48bc2_row3_col1 .pd-t::after {
#   content: "Rule #10: {(explicit = 0),} ---> {(acousticness = acousticness_3),}, support=0.2, confidence = 0.22, lift = 1.07";
# }
# #T_48bc2 #T_48bc2_row3_col8:hover .pd-t {
#   visibility: visible;
# }
# #T_48bc2 #T_48bc2_row3_col8 .pd-t::after {
#   content: "Rule #10: {(explicit = 0),} ---> {(acousticness = acousticness_3),}, support=0.2, confidence = 0.22, lift = 1.07";
# }
# #T_48bc2 #T_48bc2_row4_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_48bc2 #T_48bc2_row4_col1 .pd-t::after {
#   content: "Rule #24: {(explicit = 0),} ---> {(danceability = danceability_2),}, support=0.19, confidence = 0.21, lift = 1.04";
# }
# #T_48bc2 #T_48bc2_row4_col6:hover .pd-t {
#   visibility: visible;
# }
# #T_48bc2 #T_48bc2_row4_col6 .pd-t::after {
#   content: "Rule #24: {(explicit = 0),} ---> {(danceability = danceability_2),}, support=0.19, confidence = 0.21, lift = 1.04";
# }
# #T_48bc2 #T_48bc2_row5_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_48bc2 #T_48bc2_row5_col3 .pd-t::after {
#   content: "Rule #0: {(energy = energy_4),} ---> {(acousticness = acousticness_0),}, support=0.11, confidence = 0.57, lift = 2.85";
# }
# #T_48bc2 #T_48bc2_row5_col8:hover .pd-t {
#   visibility: visible;
# }
# #T_48bc2 #T_48bc2_row5_col8 .pd-t::after {
#   content: "Rule #0: {(energy = energy_4),} ---> {(acousticness = acousticness_0),}, support=0.11, confidence = 0.57, lift = 2.85";
# }
# #T_48bc2 #T_48bc2_row6_col7:hover .pd-t {
#   visibility: visible;
# }
# #T_48bc2 #T_48bc2_row6_col7 .pd-t::after {
#   content: "Rule #111: {(speechiness = speechiness_4),} ---> {(instrumentalness = instrumentalness_0),}, support=0.11, confidence = 0.57, lift = 1.42";
# }
# #T_48bc2 #T_48bc2_row6_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_48bc2 #T_48bc2_row6_col9 .pd-t::after {
#   content: "Rule #111: {(speechiness = speechiness_4),} ---> {(instrumentalness = instrumentalness_0),}, support=0.11, confidence = 0.57, lift = 1.42";
# }
# #T_48bc2 #T_48bc2_row7_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_48bc2 #T_48bc2_row7_col1 .pd-t::after {
#   content: "Rule #195: {(explicit = 0),(loudness = loudness_4),} ---> {(energy = energy_4),}, support=0.1, confidence = 0.63, lift = 3.15";
# }
# #T_48bc2 #T_48bc2_row7_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_48bc2 #T_48bc2_row7_col2 .pd-t::after {
#   content: "Rule #195: {(explicit = 0),(loudness = loudness_4),} ---> {(energy = energy_4),}, support=0.1, confidence = 0.63, lift = 3.15";
# }
# #T_48bc2 #T_48bc2_row7_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_48bc2 #T_48bc2_row7_col3 .pd-t::after {
#   content: "Rule #195: {(explicit = 0),(loudness = loudness_4),} ---> {(energy = energy_4),}, support=0.1, confidence = 0.63, lift = 3.15";
# }
# #T_48bc2 #T_48bc2_row8_col6:hover .pd-t {
#   visibility: visible;
# }
# #T_48bc2 #T_48bc2_row8_col6 .pd-t::after {
#   content: "Rule #29: {(instrumentalness = instrumentalness_0),} ---> {(danceability = danceability_4),}, support=0.1, confidence = 0.25, lift = 1.28";
# }
# #T_48bc2 #T_48bc2_row8_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_48bc2 #T_48bc2_row8_col9 .pd-t::after {
#   content: "Rule #29: {(instrumentalness = instrumentalness_0),} ---> {(danceability = danceability_4),}, support=0.1, confidence = 0.25, lift = 1.28";
# }
# #T_48bc2 #T_48bc2_row9_col8:hover .pd-t {
#   visibility: visible;
# }
# #T_48bc2 #T_48bc2_row9_col8 .pd-t::after {
#   content: "Rule #4: {(instrumentalness = instrumentalness_0),} ---> {(acousticness = acousticness_1),}, support=0.11, confidence = 0.26, lift = 1.32";
# }
# #T_48bc2 #T_48bc2_row9_col9:hover .pd-t {
#   visibility: visible;
# }
# #T_48bc2 #T_48bc2_row9_col9 .pd-t::after {
#   content: "Rule #4: {(instrumentalness = instrumentalness_0),} ---> {(acousticness = acousticness_1),}, support=0.11, confidence = 0.26, lift = 1.32";
# }
# #T_48bc2_row0_col2, #T_48bc2_row0_col4 {
#   background-color: lightblue;
# }
# #T_48bc2_row1_col1, #T_48bc2_row1_col8 {
#   background-color: gray;
# }
# #T_48bc2_row2_col1, #T_48bc2_row2_col8 {
#   background-color: blue;
# }
# #T_48bc2_row3_col1, #T_48bc2_row3_col8 {
#   background-color: purple;
# }
# #T_48bc2_row4_col1, #T_48bc2_row4_col6 {
#   background-color: yellow;
# }
# #T_48bc2_row5_col3, #T_48bc2_row5_col8 {
#   background-color: darkgrey;
# }
# #T_48bc2_row6_col7, #T_48bc2_row6_col9 {
#   background-color: green;
# }
# #T_48bc2_row7_col1, #T_48bc2_row7_col2, #T_48bc2_row7_col3 {
#   background-color: pink;
# }
# #T_48bc2_row8_col6, #T_48bc2_row8_col9 {
#   background-color: orange;
# }
# #T_48bc2_row9_col8, #T_48bc2_row9_col9 {
#   background-color: red;
# }
# </style>
# <table id="T_48bc2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_48bc2_level0_col0" class="col_heading level0 col0" >key</th>
#       <th id="T_48bc2_level0_col1" class="col_heading level0 col1" >explicit</th>
#       <th id="T_48bc2_level0_col2" class="col_heading level0 col2" >loudness</th>
#       <th id="T_48bc2_level0_col3" class="col_heading level0 col3" >energy</th>
#       <th id="T_48bc2_level0_col4" class="col_heading level0 col4" >year</th>
#       <th id="T_48bc2_level0_col5" class="col_heading level0 col5" >valence</th>
#       <th id="T_48bc2_level0_col6" class="col_heading level0 col6" >danceability</th>
#       <th id="T_48bc2_level0_col7" class="col_heading level0 col7" >speechiness</th>
#       <th id="T_48bc2_level0_col8" class="col_heading level0 col8" >acousticness</th>
#       <th id="T_48bc2_level0_col9" class="col_heading level0 col9" >instrumentalness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_48bc2_level0_row0" class="row_heading level0 row0" >7915</th>
#       <td id="T_48bc2_row0_col0" class="data row0 col0" >5<span class="pd-t"></span></td>
#       <td id="T_48bc2_row0_col1" class="data row0 col1" >1<span class="pd-t"></span></td>
#       <td id="T_48bc2_row0_col2" class="data row0 col2" >-5.92<span class="pd-t"></span></td>
#       <td id="T_48bc2_row0_col3" class="data row0 col3" >0.59<span class="pd-t"></span></td>
#       <td id="T_48bc2_row0_col4" class="data row0 col4" >2018<span class="pd-t"></span></td>
#       <td id="T_48bc2_row0_col5" class="data row0 col5" >0.34<span class="pd-t"></span></td>
#       <td id="T_48bc2_row0_col6" class="data row0 col6" >0.50<span class="pd-t"></span></td>
#       <td id="T_48bc2_row0_col7" class="data row0 col7" >0.44<span class="pd-t"></span></td>
#       <td id="T_48bc2_row0_col8" class="data row0 col8" >0.02<span class="pd-t"></span></td>
#       <td id="T_4
